# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('final_cleaned_hand_accel-sub04.csv-sub04')
gyro = pd.read_csv('final_cleaned_hand_gyro-sub04.csv-sub04')

# %%
accel
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                0          1614633910007185     0.174624     0.711864
# 1                1          1614633910023184     0.118471     0.714427
# 2                2          1614633910039184     0.048402     0.692088
# 3                3          1614633910055183    -0.015808     0.679759
# 4                4          1614633910071182    -0.068299     0.647898
# ...            ...                       ...          ...          ...
# 183792      183792          1614639684927994    -0.068910    -1.143267
# 183793      183793          1614639684943992    -0.083314    -1.155474
# 183794      183794          1614639684959991    -0.110536    -1.144732
# 183795      183795          1614639684975989    -0.135195    -1.120439
# 183796      183796          1614639684991987    -0.150088    -1.087358
#
#         Accel Z (g)             Activity_Label
# 0         -0.738354  Forward and backward step
# 1         -0.759594  Forward and backward step
# 2         -0.791089  Forward and backward step
# 3         -0.780346  Forward and backward step
# 4         -0.772900  Forward and backward step
# ...             ...                        ...
# 183792    -0.006897        Punch_down_Up_Hooks
# 183793     0.032898        Punch_down_Up_Hooks
# 183794     0.087221        Punch_down_Up_Hooks
# 183795     0.113466        Punch_down_Up_Hooks
# 183796     0.117006        Punch_down_Up_Hooks
#
# [183797 rows x 6 columns]

# %%
gyro
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Gyro X (°/s)  Gyro Y (°/s)  \
# 0                0          1614633910007185      3.265431    -17.730983
# 1                1          1614633910023184     -5.218585    -19.806210
# 2                2          1614633910039184    -12.848096    -19.989319
# 3                3          1614633910055183    -22.980087    -19.928283
# 4                4          1614633910071182    -30.670634    -23.956664
# ...            ...                       ...           ...           ...
# 183813      183813          1614639684927994    129.976349     51.911192
# 183814      183814          1614639684943992    134.798199     73.579004
# 183815      183815          1614639684959991    134.187839     81.940948
# 183816      183816          1614639684975989    132.478828     73.273823
# 183817      183817          1614639684991987    131.502251     53.803311
#
#         Gyro Z (°/s)             Activity_Label
# 0        -142.854963  Forward and backward step
# 1        -134.981308  Forward and backward step
# 2        -131.136034  Forward and backward step
# 3        -130.647745  Forward and backward step
# 4        -131.074998  Forward and backward step
# ...              ...                        ...
# 183813     15.045396        Punch_down_Up_Hooks
# 183814      6.317235        Punch_down_Up_Hooks
# 183815     -2.532998        Punch_down_Up_Hooks
# 183816     -9.063859        Punch_down_Up_Hooks
# 183817    -15.533684        Punch_down_Up_Hooks
#
# [183818 rows x 6 columns]

# %%
inner_df = accel.join(gyro.set_index('Timestamp (microseconds)'), on='Timestamp (microseconds)', how='inner', lsuffix='_left', rsuffix='_right')

# %%
inner_df
# Out:
#         Unnamed: 0_left  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                     0          1614633910007185     0.174624     0.711864
# 1                     1          1614633910023184     0.118471     0.714427
# 2                     2          1614633910039184     0.048402     0.692088
# 3                     3          1614633910055183    -0.015808     0.679759
# 4                     4          1614633910071182    -0.068299     0.647898
# ...                 ...                       ...          ...          ...
# 183792           183792          1614639684927994    -0.068910    -1.143267
# 183793           183793          1614639684943992    -0.083314    -1.155474
# 183794           183794          1614639684959991    -0.110536    -1.144732
# 183795           183795          1614639684975989    -0.135195    -1.120439
# 183796           183796          1614639684991987    -0.150088    -1.087358
#
#         Accel Z (g)        Activity_Label_left  Unnamed: 0_right  \
# 0         -0.738354  Forward and backward step                 0
# 1         -0.759594  Forward and backward step                 1
# 2         -0.791089  Forward and backward step                 2
# 3         -0.780346  Forward and backward step                 3
# 4         -0.772900  Forward and backward step                 4
# ...             ...                        ...               ...
# 183792    -0.006897        Punch_down_Up_Hooks            183813
# 183793     0.032898        Punch_down_Up_Hooks            183814
# 183794     0.087221        Punch_down_Up_Hooks            183815
# 183795     0.113466        Punch_down_Up_Hooks            183816
# 183796     0.117006        Punch_down_Up_Hooks            183817
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0           3.265431    -17.730983   -142.854963  Forward and backward step
# 1          -5.218585    -19.806210   -134.981308  Forward and backward step
# 2         -12.848096    -19.989319   -131.136034  Forward and backward step
# 3         -22.980087    -19.928283   -130.647745  Forward and backward step
# 4         -30.670634    -23.956664   -131.074998  Forward and backward step
# ...              ...           ...           ...                        ...
# 183792    129.976349     51.911192     15.045396        Punch_down_Up_Hooks
# 183793    134.798199     73.579004      6.317235        Punch_down_Up_Hooks
# 183794    134.187839     81.940948     -2.532998        Punch_down_Up_Hooks
# 183795    132.478828     73.273823     -9.063859        Punch_down_Up_Hooks
# 183796    131.502251     53.803311    -15.533684        Punch_down_Up_Hooks
#
# [228923 rows x 11 columns]

# %%
inner_df.drop(['Activity_Label_left','Unnamed: 0_left','Unnamed: 0_right'], axis=1, inplace=True)

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614633910007185     0.174624     0.711864    -0.738354
# 1               1614633910023184     0.118471     0.714427    -0.759594
# 2               1614633910039184     0.048402     0.692088    -0.791089
# 3               1614633910055183    -0.015808     0.679759    -0.780346
# 4               1614633910071182    -0.068299     0.647898    -0.772900
# ...                          ...          ...          ...          ...
# 183792          1614639684927994    -0.068910    -1.143267    -0.006897
# 183793          1614639684943992    -0.083314    -1.155474     0.032898
# 183794          1614639684959991    -0.110536    -1.144732     0.087221
# 183795          1614639684975989    -0.135195    -1.120439     0.113466
# 183796          1614639684991987    -0.150088    -1.087358     0.117006
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0           3.265431    -17.730983   -142.854963  Forward and backward step
# 1          -5.218585    -19.806210   -134.981308  Forward and backward step
# 2         -12.848096    -19.989319   -131.136034  Forward and backward step
# 3         -22.980087    -19.928283   -130.647745  Forward and backward step
# 4         -30.670634    -23.956664   -131.074998  Forward and backward step
# ...              ...           ...           ...                        ...
# 183792    129.976349     51.911192     15.045396        Punch_down_Up_Hooks
# 183793    134.798199     73.579004      6.317235        Punch_down_Up_Hooks
# 183794    134.187839     81.940948     -2.532998        Punch_down_Up_Hooks
# 183795    132.478828     73.273823     -9.063859        Punch_down_Up_Hooks
# 183796    131.502251     53.803311    -15.533684        Punch_down_Up_Hooks
#
# [228923 rows x 8 columns]

# %%
ts = inner_df['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
inner_df['Time_elapse'] = ts1.tolist()

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614633910007185     0.174624     0.711864    -0.738354
# 1               1614633910023184     0.118471     0.714427    -0.759594
# 2               1614633910039184     0.048402     0.692088    -0.791089
# 3               1614633910055183    -0.015808     0.679759    -0.780346
# 4               1614633910071182    -0.068299     0.647898    -0.772900
# ...                          ...          ...          ...          ...
# 183792          1614639684927994    -0.068910    -1.143267    -0.006897
# 183793          1614639684943992    -0.083314    -1.155474     0.032898
# 183794          1614639684959991    -0.110536    -1.144732     0.087221
# 183795          1614639684975989    -0.135195    -1.120439     0.113466
# 183796          1614639684991987    -0.150088    -1.087358     0.117006
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right  \
# 0           3.265431    -17.730983   -142.854963  Forward and backward step
# 1          -5.218585    -19.806210   -134.981308  Forward and backward step
# 2         -12.848096    -19.989319   -131.136034  Forward and backward step
# 3         -22.980087    -19.928283   -130.647745  Forward and backward step
# 4         -30.670634    -23.956664   -131.074998  Forward and backward step
# ...              ...           ...           ...                        ...
# 183792    129.976349     51.911192     15.045396        Punch_down_Up_Hooks
# 183793    134.798199     73.579004      6.317235        Punch_down_Up_Hooks
# 183794    134.187839     81.940948     -2.532998        Punch_down_Up_Hooks
# 183795    132.478828     73.273823     -9.063859        Punch_down_Up_Hooks
# 183796    131.502251     53.803311    -15.533684        Punch_down_Up_Hooks
#
#         Time_elapse
# 0          0.000000
# 1          0.015999
# 2          0.031999
# 3          0.047998
# 4          0.063997
# ...             ...
# 183792  5774.920809
# 183793  5774.936807
# 183794  5774.952806
# 183795  5774.968804
# 183796  5774.984802
#
# [228923 rows x 9 columns]

# %%
# inner_df.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)

# %%
# inner_df

# %%
inner_df.to_csv('sub04_hand_accel+gyro.csv', index = False)
