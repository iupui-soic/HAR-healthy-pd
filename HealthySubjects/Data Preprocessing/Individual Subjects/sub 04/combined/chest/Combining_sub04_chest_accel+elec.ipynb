# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('final_cleaned_chest_accel-sub04.csv-sub04')
elec = pd.read_csv('final_cleaned_chest_elec-sub04.csv-sub04')

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614633910025304    -0.110292     0.843336
# 1               1          1614633910057215    -0.106386     0.881910
# 2               2          1614633910089126    -0.137148     0.936599
# 3               3          1614633910121037    -0.130312     0.969802
# 4               4          1614633910152948    -0.148867     1.073320
# ...           ...                       ...          ...          ...
# 92081       92081          1614639684847475    -0.947707     1.002029
# 92082       92082          1614639684879489    -0.825635     0.193423
# 92083       92083          1614639684911502    -0.547799     1.012772
# 92084       92084          1614639684943516    -0.352972     1.110430
# 92085       92085          1614639684975530    -0.530220     0.649973
#
#        Accel Z (g)             Activity_Label
# 0         0.309148  Forward and backward step
# 1         0.356512  Forward and backward step
# 2         0.358953  Forward and backward step
# 3         0.360906  Forward and backward step
# 4         0.389227  Forward and backward step
# ...            ...                        ...
# 92081     0.366766        Punch_down_Up_Hooks
# 92082     0.100160        Punch_down_Up_Hooks
# 92083     0.276432        Punch_down_Up_Hooks
# 92084     0.335515        Punch_down_Up_Hooks
# 92085     0.151919        Punch_down_Up_Hooks
#
# [92086 rows x 6 columns]

# %%
elec
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Sample (V)  \
# 0                0          1614633910003668    0.001831
# 1                1          1614633910007676    0.001831
# 2                2          1614633910011684    0.001837
# 3                3          1614633910015691    0.001831
# 4                4          1614633910019699    0.001831
# ...            ...                       ...         ...
# 733789      733789          1614639684981923    0.000514
# 733790      733790          1614639684985930    0.000489
# 733791      733791          1614639684989936    0.000483
# 733792      733792          1614639684993943    0.000471
# 733793      733793          1614639684997950    0.000465
#
#                    Activity_Label
# 0       Forward and backward step
# 1       Forward and backward step
# 2       Forward and backward step
# 3       Forward and backward step
# 4       Forward and backward step
# ...                           ...
# 733789        Punch_down_Up_Hooks
# 733790        Punch_down_Up_Hooks
# 733791        Punch_down_Up_Hooks
# 733792        Punch_down_Up_Hooks
# 733793        Punch_down_Up_Hooks
#
# [733794 rows x 4 columns]

# %%
elec_ts = elec['Timestamp (microseconds)'].to_numpy()

# %%
elec_ts
# Out:
# array([1614633910003668, 1614633910007676, 1614633910011684, ...,
#        1614639684989936, 1614639684993943, 1614639684997950])

# %%
accel_ts = accel['Timestamp (microseconds)'].to_numpy()

# %%
accel_ts
# Out:
# array([1614633910025304, 1614633910057215, 1614633910089126, ...,
#        1614639684911502, 1614639684943516, 1614639684975530])

# %%
for i in range(len(accel_ts)):
    accel.at[i, 'Sample (V)'] = elec['Sample (V)'].iloc[np.argmin(abs(accel_ts[i] - elec_ts))]

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614633910025304    -0.110292     0.843336
# 1               1          1614633910057215    -0.106386     0.881910
# 2               2          1614633910089126    -0.137148     0.936599
# 3               3          1614633910121037    -0.130312     0.969802
# 4               4          1614633910152948    -0.148867     1.073320
# ...           ...                       ...          ...          ...
# 92081       92081          1614639684847475    -0.947707     1.002029
# 92082       92082          1614639684879489    -0.825635     0.193423
# 92083       92083          1614639684911502    -0.547799     1.012772
# 92084       92084          1614639684943516    -0.352972     1.110430
# 92085       92085          1614639684975530    -0.530220     0.649973
#
#        Accel Z (g)             Activity_Label  Sample (V)
# 0         0.309148  Forward and backward step    0.001837
# 1         0.356512  Forward and backward step    0.001856
# 2         0.358953  Forward and backward step    0.001862
# 3         0.360906  Forward and backward step    0.001856
# 4         0.389227  Forward and backward step    0.001837
# ...            ...                        ...         ...
# 92081     0.366766        Punch_down_Up_Hooks    0.001640
# 92082     0.100160        Punch_down_Up_Hooks    0.001536
# 92083     0.276432        Punch_down_Up_Hooks    0.001025
# 92084     0.335515        Punch_down_Up_Hooks    0.000662
# 92085     0.151919        Punch_down_Up_Hooks    0.000563
#
# [92086 rows x 7 columns]

# %%
ts = accel['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
accel['Time_elapse'] = ts1.tolist()

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614633910025304    -0.110292     0.843336
# 1               1          1614633910057215    -0.106386     0.881910
# 2               2          1614633910089126    -0.137148     0.936599
# 3               3          1614633910121037    -0.130312     0.969802
# 4               4          1614633910152948    -0.148867     1.073320
# ...           ...                       ...          ...          ...
# 92081       92081          1614639684847475    -0.947707     1.002029
# 92082       92082          1614639684879489    -0.825635     0.193423
# 92083       92083          1614639684911502    -0.547799     1.012772
# 92084       92084          1614639684943516    -0.352972     1.110430
# 92085       92085          1614639684975530    -0.530220     0.649973
#
#        Accel Z (g)             Activity_Label  Sample (V)  Time_elapse
# 0         0.309148  Forward and backward step    0.001837     0.000000
# 1         0.356512  Forward and backward step    0.001856     0.031911
# 2         0.358953  Forward and backward step    0.001862     0.063822
# 3         0.360906  Forward and backward step    0.001856     0.095733
# 4         0.389227  Forward and backward step    0.001837     0.127644
# ...            ...                        ...         ...          ...
# 92081     0.366766        Punch_down_Up_Hooks    0.001640  5774.822171
# 92082     0.100160        Punch_down_Up_Hooks    0.001536  5774.854185
# 92083     0.276432        Punch_down_Up_Hooks    0.001025  5774.886198
# 92084     0.335515        Punch_down_Up_Hooks    0.000662  5774.918212
# 92085     0.151919        Punch_down_Up_Hooks    0.000563  5774.950226
#
# [92086 rows x 8 columns]

# %%
accel.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
accel
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1614633910025304    -0.110292     0.843336     0.309148
# 1              1614633910057215    -0.106386     0.881910     0.356512
# 2              1614633910089126    -0.137148     0.936599     0.358953
# 3              1614633910121037    -0.130312     0.969802     0.360906
# 4              1614633910152948    -0.148867     1.073320     0.389227
# ...                         ...          ...          ...          ...
# 92081          1614639684847475    -0.947707     1.002029     0.366766
# 92082          1614639684879489    -0.825635     0.193423     0.100160
# 92083          1614639684911502    -0.547799     1.012772     0.276432
# 92084          1614639684943516    -0.352972     1.110430     0.335515
# 92085          1614639684975530    -0.530220     0.649973     0.151919
#
#                   Activity_Label  Sample (V)  Time_elapse
# 0      Forward and backward step    0.001837     0.000000
# 1      Forward and backward step    0.001856     0.031911
# 2      Forward and backward step    0.001862     0.063822
# 3      Forward and backward step    0.001856     0.095733
# 4      Forward and backward step    0.001837     0.127644
# ...                          ...         ...          ...
# 92081        Punch_down_Up_Hooks    0.001640  5774.822171
# 92082        Punch_down_Up_Hooks    0.001536  5774.854185
# 92083        Punch_down_Up_Hooks    0.001025  5774.886198
# 92084        Punch_down_Up_Hooks    0.000662  5774.918212
# 92085        Punch_down_Up_Hooks    0.000563  5774.950226
#
# [92086 rows x 7 columns]

# %%
#accel.to_csv('sub01_chest_accel+elec.csv', index = False)

# %%
# accel.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)
#accel

# %%
accel.to_csv('sub04_chest_accel+elec.csv', index = False)
