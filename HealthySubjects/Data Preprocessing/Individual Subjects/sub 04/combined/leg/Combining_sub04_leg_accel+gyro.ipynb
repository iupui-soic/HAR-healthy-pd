# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('final_cleaned_leg_accel-sub04.csv-sub04')
gyro = pd.read_csv('final_cleaned_leg_gyro-sub04.csv-sub04')

# %%
accel
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                0          1614633910014967    -1.015213    -0.095155
# 1                1          1614633910030943    -1.052323    -0.124941
# 2                2          1614633910046918    -1.062211    -0.153262
# 3                3          1614633910062893    -1.078325    -0.183780
# 4                4          1614633910078869    -1.061601    -0.144228
# ...            ...                       ...          ...          ...
# 184080      184080          1614639684925018    -1.159747     0.256046
# 184081      184081          1614639684940994    -1.175616     0.290349
# 184082      184082          1614639684956970    -1.159380     0.272160
# 184083      184083          1614639684972946    -1.124956     0.182925
# 184084      184084          1614639684988922    -1.116289     0.154971
#
#         Accel Z (g)             Activity_Label
# 0          0.065003  Forward and backward step
# 1          0.064637  Forward and backward step
# 2          0.050355  Forward and backward step
# 3          0.051698  Forward and backward step
# 4          0.026795  Forward and backward step
# ...             ...                        ...
# 184080    -0.021790        Punch_down_Up_Hooks
# 184081     0.067201        Punch_down_Up_Hooks
# 184082     0.104677        Punch_down_Up_Hooks
# 184083     0.207462        Punch_down_Up_Hooks
# 184084     0.336858        Punch_down_Up_Hooks
#
# [184085 rows x 6 columns]

# %%
gyro
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Gyro X (°/s)  Gyro Y (°/s)  \
# 0                0          1614633910014967     14.129854    -23.651484
# 1                1          1614633910030943     15.960937    -23.529412
# 2                2          1614633910046918     18.280308    -27.801938
# 3                3          1614633910062893     22.552834    -32.745861
# 4                4          1614633910078869     26.581216    -35.553521
# ...            ...                       ...           ...           ...
# 184082      184082          1614639684925018     -4.303044    -73.884184
# 184083      184083          1614639684940994      1.495384    -87.129015
# 184084      184084          1614639684956970      7.660029    -98.725872
# 184085      184085          1614639684972946     15.350576   -108.430610
# 184086      184086          1614639684988922     29.022660   -115.510796
#
#         Gyro Z (°/s)             Activity_Label
# 0           5.157549  Forward and backward step
# 1           5.706874  Forward and backward step
# 2           7.293812  Forward and backward step
# 3           9.857328  Forward and backward step
# 4          12.603952  Forward and backward step
# ...              ...                        ...
# 184082      6.622416        Punch_down_Up_Hooks
# 184083      7.232776        Punch_down_Up_Hooks
# 184084      6.317235        Punch_down_Up_Hooks
# 184085      5.889982        Punch_down_Up_Hooks
# 184086      6.317235        Punch_down_Up_Hooks
#
# [184087 rows x 6 columns]

# %%
inner_df = accel.join(gyro.set_index('Timestamp (microseconds)'), on='Timestamp (microseconds)', how='inner', lsuffix='_left', rsuffix='_right')

# %%
inner_df
# Out:
#         Unnamed: 0_left  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                     0          1614633910014967    -1.015213    -0.095155
# 1                     1          1614633910030943    -1.052323    -0.124941
# 2                     2          1614633910046918    -1.062211    -0.153262
# 3                     3          1614633910062893    -1.078325    -0.183780
# 4                     4          1614633910078869    -1.061601    -0.144228
# ...                 ...                       ...          ...          ...
# 184080           184080          1614639684925018    -1.159747     0.256046
# 184081           184081          1614639684940994    -1.175616     0.290349
# 184082           184082          1614639684956970    -1.159380     0.272160
# 184083           184083          1614639684972946    -1.124956     0.182925
# 184084           184084          1614639684988922    -1.116289     0.154971
#
#         Accel Z (g)        Activity_Label_left  Unnamed: 0_right  \
# 0          0.065003  Forward and backward step                 0
# 1          0.064637  Forward and backward step                 1
# 2          0.050355  Forward and backward step                 2
# 3          0.051698  Forward and backward step                 3
# 4          0.026795  Forward and backward step                 4
# ...             ...                        ...               ...
# 184080    -0.021790        Punch_down_Up_Hooks            184082
# 184081     0.067201        Punch_down_Up_Hooks            184083
# 184082     0.104677        Punch_down_Up_Hooks            184084
# 184083     0.207462        Punch_down_Up_Hooks            184085
# 184084     0.336858        Punch_down_Up_Hooks            184086
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          14.129854    -23.651484      5.157549  Forward and backward step
# 1          15.960937    -23.529412      5.706874  Forward and backward step
# 2          18.280308    -27.801938      7.293812  Forward and backward step
# 3          22.552834    -32.745861      9.857328  Forward and backward step
# 4          26.581216    -35.553521     12.603952  Forward and backward step
# ...              ...           ...           ...                        ...
# 184080     -4.303044    -73.884184      6.622416        Punch_down_Up_Hooks
# 184081      1.495384    -87.129015      7.232776        Punch_down_Up_Hooks
# 184082      7.660029    -98.725872      6.317235        Punch_down_Up_Hooks
# 184083     15.350576   -108.430610      5.889982        Punch_down_Up_Hooks
# 184084     29.022660   -115.510796      6.317235        Punch_down_Up_Hooks
#
# [229277 rows x 11 columns]

# %%
inner_df.drop(['Activity_Label_left','Unnamed: 0_left','Unnamed: 0_right'], axis=1, inplace=True)

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614633910014967    -1.015213    -0.095155     0.065003
# 1               1614633910030943    -1.052323    -0.124941     0.064637
# 2               1614633910046918    -1.062211    -0.153262     0.050355
# 3               1614633910062893    -1.078325    -0.183780     0.051698
# 4               1614633910078869    -1.061601    -0.144228     0.026795
# ...                          ...          ...          ...          ...
# 184080          1614639684925018    -1.159747     0.256046    -0.021790
# 184081          1614639684940994    -1.175616     0.290349     0.067201
# 184082          1614639684956970    -1.159380     0.272160     0.104677
# 184083          1614639684972946    -1.124956     0.182925     0.207462
# 184084          1614639684988922    -1.116289     0.154971     0.336858
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          14.129854    -23.651484      5.157549  Forward and backward step
# 1          15.960937    -23.529412      5.706874  Forward and backward step
# 2          18.280308    -27.801938      7.293812  Forward and backward step
# 3          22.552834    -32.745861      9.857328  Forward and backward step
# 4          26.581216    -35.553521     12.603952  Forward and backward step
# ...              ...           ...           ...                        ...
# 184080     -4.303044    -73.884184      6.622416        Punch_down_Up_Hooks
# 184081      1.495384    -87.129015      7.232776        Punch_down_Up_Hooks
# 184082      7.660029    -98.725872      6.317235        Punch_down_Up_Hooks
# 184083     15.350576   -108.430610      5.889982        Punch_down_Up_Hooks
# 184084     29.022660   -115.510796      6.317235        Punch_down_Up_Hooks
#
# [229277 rows x 8 columns]

# %%
ts = inner_df['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
inner_df['Time_elapse'] = ts1.tolist()

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614633910014967    -1.015213    -0.095155     0.065003
# 1               1614633910030943    -1.052323    -0.124941     0.064637
# 2               1614633910046918    -1.062211    -0.153262     0.050355
# 3               1614633910062893    -1.078325    -0.183780     0.051698
# 4               1614633910078869    -1.061601    -0.144228     0.026795
# ...                          ...          ...          ...          ...
# 184080          1614639684925018    -1.159747     0.256046    -0.021790
# 184081          1614639684940994    -1.175616     0.290349     0.067201
# 184082          1614639684956970    -1.159380     0.272160     0.104677
# 184083          1614639684972946    -1.124956     0.182925     0.207462
# 184084          1614639684988922    -1.116289     0.154971     0.336858
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right  \
# 0          14.129854    -23.651484      5.157549  Forward and backward step
# 1          15.960937    -23.529412      5.706874  Forward and backward step
# 2          18.280308    -27.801938      7.293812  Forward and backward step
# 3          22.552834    -32.745861      9.857328  Forward and backward step
# 4          26.581216    -35.553521     12.603952  Forward and backward step
# ...              ...           ...           ...                        ...
# 184080     -4.303044    -73.884184      6.622416        Punch_down_Up_Hooks
# 184081      1.495384    -87.129015      7.232776        Punch_down_Up_Hooks
# 184082      7.660029    -98.725872      6.317235        Punch_down_Up_Hooks
# 184083     15.350576   -108.430610      5.889982        Punch_down_Up_Hooks
# 184084     29.022660   -115.510796      6.317235        Punch_down_Up_Hooks
#
#         Time_elapse
# 0          0.000000
# 1          0.015976
# 2          0.031951
# 3          0.047926
# 4          0.063902
# ...             ...
# 184080  5774.910051
# 184081  5774.926027
# 184082  5774.942003
# 184083  5774.957979
# 184084  5774.973955
#
# [229277 rows x 9 columns]

# %%
# inner_df.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)

# %%
# inner_df

# %%
inner_df.to_csv('sub04_leg_accel+gyro.csv', index = False)
