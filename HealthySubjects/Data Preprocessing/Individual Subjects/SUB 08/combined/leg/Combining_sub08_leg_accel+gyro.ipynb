# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('/Users/shreyasaswar/HARDataset/EXTRACTION/SUB 08/leg/cleaned/final_cleaned_leg_accel.csv')
gyro = pd.read_csv('/Users/shreyasaswar/HARDataset/EXTRACTION/SUB 08/leg/cleaned/final_cleaned_leg_gyro.csv')

# %%
accel
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                0          1614726944006908    -1.033890     0.067079
# 1                1          1614726944022883    -1.084062     0.089906
# 2                2          1614726944038859    -1.089433     0.000427
# 3                3          1614726944054834    -1.043290    -0.074037
# 4                4          1614726944070809    -1.030472    -0.083192
# ...            ...                       ...          ...          ...
# 107914      107914          1614730333926016    -0.951492     0.728710
# 107915      107915          1614730333941991    -0.915846     0.808667
# 107916      107916          1614730333957965    -0.823682     0.652415
# 107917      107917          1614730333973940    -0.968582     0.489448
# 107918      107918          1614730333989915    -1.035843     0.110414
#
#         Accel Z (g)             Activity_Label
# 0         -0.145693  Forward and backward step
# 1         -0.155093  Forward and backward step
# 2         -0.065370  Forward and backward step
# 3         -0.001404  Forward and backward step
# 4          0.066712  Forward and backward step
# ...             ...                        ...
# 107914     0.423896        Punch_down_Up_Hooks
# 107915     0.225650        Punch_down_Up_Hooks
# 107916     0.090761        Punch_down_Up_Hooks
# 107917    -0.004578        Punch_down_Up_Hooks
# 107918     0.166812        Punch_down_Up_Hooks
#
# [107919 rows x 6 columns]

# %%
gyro
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Gyro X (°/s)  Gyro Y (°/s)  \
# 0                0          1614726944006908     -9.735256     -1.495384
# 1                1          1614726944022883     -5.523766     -3.509575
# 2                2          1614726944038859    -11.200122     -4.913405
# 3                3          1614726944054834     -5.157549     -5.645838
# 4                4          1614726944070809      1.434348     -6.195163
# ...            ...                       ...           ...           ...
# 107914      107914          1614730333926016    257.175555     33.356222
# 107915      107915          1614730333941991    205.172808     24.383917
# 107916      107916          1614730333957965     61.738003     18.341344
# 107917      107917          1614730333973940      2.838178     12.481880
# 107918      107918          1614730333989915    -22.735943      4.913405
#
#         Gyro Z (°/s)             Activity_Label
# 0          -1.678492  Forward and backward step
# 1          -0.396735  Forward and backward step
# 2           2.166781  Forward and backward step
# 3           3.814755  Forward and backward step
# 4           4.242008  Forward and backward step
# ...              ...                        ...
# 107914    -24.505989        Punch_down_Up_Hooks
# 107915     -5.828946        Punch_down_Up_Hooks
# 107916    -43.915465        Punch_down_Up_Hooks
# 107917    -54.047456        Punch_down_Up_Hooks
# 107918    -35.431449        Punch_down_Up_Hooks
#
# [107919 rows x 6 columns]

# %%
inner_df = accel.join(gyro.set_index('Timestamp (microseconds)'), on='Timestamp (microseconds)', how='inner', lsuffix='_left', rsuffix='_right')

# %%
inner_df
# Out:
#         Unnamed: 0_left  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                     0          1614726944006908    -1.033890     0.067079
# 1                     1          1614726944022883    -1.084062     0.089906
# 2                     2          1614726944038859    -1.089433     0.000427
# 3                     3          1614726944054834    -1.043290    -0.074037
# 4                     4          1614726944070809    -1.030472    -0.083192
# ...                 ...                       ...          ...          ...
# 107914           107914          1614730333926016    -0.951492     0.728710
# 107915           107915          1614730333941991    -0.915846     0.808667
# 107916           107916          1614730333957965    -0.823682     0.652415
# 107917           107917          1614730333973940    -0.968582     0.489448
# 107918           107918          1614730333989915    -1.035843     0.110414
#
#         Accel Z (g)        Activity_Label_left  Unnamed: 0_right  \
# 0         -0.145693  Forward and backward step                 0
# 1         -0.155093  Forward and backward step                 1
# 2         -0.065370  Forward and backward step                 2
# 3         -0.001404  Forward and backward step                 3
# 4          0.066712  Forward and backward step                 4
# ...             ...                        ...               ...
# 107914     0.423896        Punch_down_Up_Hooks            107914
# 107915     0.225650        Punch_down_Up_Hooks            107915
# 107916     0.090761        Punch_down_Up_Hooks            107916
# 107917    -0.004578        Punch_down_Up_Hooks            107917
# 107918     0.166812        Punch_down_Up_Hooks            107918
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          -9.735256     -1.495384     -1.678492  Forward and backward step
# 1          -5.523766     -3.509575     -0.396735  Forward and backward step
# 2         -11.200122     -4.913405      2.166781  Forward and backward step
# 3          -5.157549     -5.645838      3.814755  Forward and backward step
# 4           1.434348     -6.195163      4.242008  Forward and backward step
# ...              ...           ...           ...                        ...
# 107914    257.175555     33.356222    -24.505989        Punch_down_Up_Hooks
# 107915    205.172808     24.383917     -5.828946        Punch_down_Up_Hooks
# 107916     61.738003     18.341344    -43.915465        Punch_down_Up_Hooks
# 107917      2.838178     12.481880    -54.047456        Punch_down_Up_Hooks
# 107918    -22.735943      4.913405    -35.431449        Punch_down_Up_Hooks
#
# [107919 rows x 11 columns]

# %%
inner_df.drop(['Activity_Label_left','Unnamed: 0_left','Unnamed: 0_right'], axis=1, inplace=True)

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614726944006908    -1.033890     0.067079    -0.145693
# 1               1614726944022883    -1.084062     0.089906    -0.155093
# 2               1614726944038859    -1.089433     0.000427    -0.065370
# 3               1614726944054834    -1.043290    -0.074037    -0.001404
# 4               1614726944070809    -1.030472    -0.083192     0.066712
# ...                          ...          ...          ...          ...
# 107914          1614730333926016    -0.951492     0.728710     0.423896
# 107915          1614730333941991    -0.915846     0.808667     0.225650
# 107916          1614730333957965    -0.823682     0.652415     0.090761
# 107917          1614730333973940    -0.968582     0.489448    -0.004578
# 107918          1614730333989915    -1.035843     0.110414     0.166812
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          -9.735256     -1.495384     -1.678492  Forward and backward step
# 1          -5.523766     -3.509575     -0.396735  Forward and backward step
# 2         -11.200122     -4.913405      2.166781  Forward and backward step
# 3          -5.157549     -5.645838      3.814755  Forward and backward step
# 4           1.434348     -6.195163      4.242008  Forward and backward step
# ...              ...           ...           ...                        ...
# 107914    257.175555     33.356222    -24.505989        Punch_down_Up_Hooks
# 107915    205.172808     24.383917     -5.828946        Punch_down_Up_Hooks
# 107916     61.738003     18.341344    -43.915465        Punch_down_Up_Hooks
# 107917      2.838178     12.481880    -54.047456        Punch_down_Up_Hooks
# 107918    -22.735943      4.913405    -35.431449        Punch_down_Up_Hooks
#
# [107919 rows x 8 columns]

# %%
ts = inner_df['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
inner_df['Time_elapse'] = ts1.tolist()

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614726944006908    -1.033890     0.067079    -0.145693
# 1               1614726944022883    -1.084062     0.089906    -0.155093
# 2               1614726944038859    -1.089433     0.000427    -0.065370
# 3               1614726944054834    -1.043290    -0.074037    -0.001404
# 4               1614726944070809    -1.030472    -0.083192     0.066712
# ...                          ...          ...          ...          ...
# 107914          1614730333926016    -0.951492     0.728710     0.423896
# 107915          1614730333941991    -0.915846     0.808667     0.225650
# 107916          1614730333957965    -0.823682     0.652415     0.090761
# 107917          1614730333973940    -0.968582     0.489448    -0.004578
# 107918          1614730333989915    -1.035843     0.110414     0.166812
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right  \
# 0          -9.735256     -1.495384     -1.678492  Forward and backward step
# 1          -5.523766     -3.509575     -0.396735  Forward and backward step
# 2         -11.200122     -4.913405      2.166781  Forward and backward step
# 3          -5.157549     -5.645838      3.814755  Forward and backward step
# 4           1.434348     -6.195163      4.242008  Forward and backward step
# ...              ...           ...           ...                        ...
# 107914    257.175555     33.356222    -24.505989        Punch_down_Up_Hooks
# 107915    205.172808     24.383917     -5.828946        Punch_down_Up_Hooks
# 107916     61.738003     18.341344    -43.915465        Punch_down_Up_Hooks
# 107917      2.838178     12.481880    -54.047456        Punch_down_Up_Hooks
# 107918    -22.735943      4.913405    -35.431449        Punch_down_Up_Hooks
#
#         Time_elapse
# 0          0.000000
# 1          0.015975
# 2          0.031951
# 3          0.047926
# 4          0.063901
# ...             ...
# 107914  3389.919108
# 107915  3389.935083
# 107916  3389.951057
# 107917  3389.967032
# 107918  3389.983007
#
# [107919 rows x 9 columns]

# %%
# inner_df.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)

# %%
# inner_df

# %%
inner_df.to_csv('sub08_leg_accel+gyro.csv', index = False)
