# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('/Users/shreyasaswar/HARDataset/EXTRACTION/SUB 08/Chest/cleaned/final_cleaned_chest_accel-sub08.csv-sub08')
elec = pd.read_csv('/Users/shreyasaswar/HARDataset/EXTRACTION/SUB 08/Chest/cleaned/final_cleaned_chest_elec-sub08.csv')

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614726944002170    -0.182559     0.945388
# 1               1          1614726944034077    -0.175723     0.980545
# 2               2          1614726944065983    -0.190372     1.039139
# 3               3          1614726944097890    -0.185489     1.004959
# 4               4          1614726944129797    -0.148379     0.956130
# ...           ...                       ...          ...          ...
# 54018       54018          1614730333844476    -0.657664     1.004471
# 54019       54019          1614730333876433    -0.070253     1.421958
# 54020       54020          1614730333908391     0.326726     1.550866
# 54021       54021          1614730333940348     0.307683     1.206622
# 54022       54022          1614730333972305     0.293034     0.953201
#
#        Accel Z (g)             Activity_Label
# 0         0.263737  Forward and backward step
# 1         0.264225  Forward and backward step
# 2         0.292058  Forward and backward step
# 3         0.270573  Forward and backward step
# 4         0.212467  Forward and backward step
# ...            ...                        ...
# 54018     0.164126        Punch_down_Up_Hooks
# 54019     0.047913        Punch_down_Up_Hooks
# 54020     0.091371        Punch_down_Up_Hooks
# 54021     0.066957        Punch_down_Up_Hooks
# 54022     0.048890        Punch_down_Up_Hooks
#
# [54023 rows x 6 columns]

# %%
elec
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Sample (V)  \
# 0                0          1614726944003392    0.001991
# 1                1          1614726944007400    0.002003
# 2                2          1614726944011408    0.001997
# 3                3          1614726944015417    0.001985
# 4                4          1614726944019425    0.001985
# ...            ...                       ...         ...
# 430120      430120          1614730333981639    0.001689
# 430121      430121          1614730333985646    0.001702
# 430122      430122          1614730333989654    0.001714
# 430123      430123          1614730333993662    0.001708
# 430124      430124          1614730333997670    0.001708
#
#                    Activity_Label
# 0       Forward and backward step
# 1       Forward and backward step
# 2       Forward and backward step
# 3       Forward and backward step
# 4       Forward and backward step
# ...                           ...
# 430120        Punch_down_Up_Hooks
# 430121        Punch_down_Up_Hooks
# 430122        Punch_down_Up_Hooks
# 430123        Punch_down_Up_Hooks
# 430124        Punch_down_Up_Hooks
#
# [430125 rows x 4 columns]

# %%
elec_ts = elec['Timestamp (microseconds)'].to_numpy()

# %%
elec_ts
# Out:
# array([1614726944003392, 1614726944007400, 1614726944011408, ...,
#        1614730333989654, 1614730333993662, 1614730333997670])

# %%
accel_ts = accel['Timestamp (microseconds)'].to_numpy()

# %%
accel_ts
# Out:
# array([1614726944002170, 1614726944034077, 1614726944065983, ...,
#        1614730333908391, 1614730333940348, 1614730333972305])

# %%
for i in range(len(accel_ts)):
    accel.at[i, 'Sample (V)'] = elec['Sample (V)'].iloc[np.argmin(abs(accel_ts[i] - elec_ts))]

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614726944002170    -0.182559     0.945388
# 1               1          1614726944034077    -0.175723     0.980545
# 2               2          1614726944065983    -0.190372     1.039139
# 3               3          1614726944097890    -0.185489     1.004959
# 4               4          1614726944129797    -0.148379     0.956130
# ...           ...                       ...          ...          ...
# 54018       54018          1614730333844476    -0.657664     1.004471
# 54019       54019          1614730333876433    -0.070253     1.421958
# 54020       54020          1614730333908391     0.326726     1.550866
# 54021       54021          1614730333940348     0.307683     1.206622
# 54022       54022          1614730333972305     0.293034     0.953201
#
#        Accel Z (g)             Activity_Label  Sample (V)
# 0         0.263737  Forward and backward step    0.001991
# 1         0.264225  Forward and backward step    0.001954
# 2         0.292058  Forward and backward step    0.001929
# 3         0.270573  Forward and backward step    0.001936
# 4         0.212467  Forward and backward step    0.001954
# ...            ...                        ...         ...
# 54018     0.164126        Punch_down_Up_Hooks    0.001609
# 54019     0.047913        Punch_down_Up_Hooks    0.001634
# 54020     0.091371        Punch_down_Up_Hooks    0.001579
# 54021     0.066957        Punch_down_Up_Hooks    0.001585
# 54022     0.048890        Punch_down_Up_Hooks    0.001677
#
# [54023 rows x 7 columns]

# %%
ts = accel['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
accel['Time_elapse'] = ts1.tolist()

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614726944002170    -0.182559     0.945388
# 1               1          1614726944034077    -0.175723     0.980545
# 2               2          1614726944065983    -0.190372     1.039139
# 3               3          1614726944097890    -0.185489     1.004959
# 4               4          1614726944129797    -0.148379     0.956130
# ...           ...                       ...          ...          ...
# 54018       54018          1614730333844476    -0.657664     1.004471
# 54019       54019          1614730333876433    -0.070253     1.421958
# 54020       54020          1614730333908391     0.326726     1.550866
# 54021       54021          1614730333940348     0.307683     1.206622
# 54022       54022          1614730333972305     0.293034     0.953201
#
#        Accel Z (g)             Activity_Label  Sample (V)  Time_elapse
# 0         0.263737  Forward and backward step    0.001991     0.000000
# 1         0.264225  Forward and backward step    0.001954     0.031907
# 2         0.292058  Forward and backward step    0.001929     0.063813
# 3         0.270573  Forward and backward step    0.001936     0.095720
# 4         0.212467  Forward and backward step    0.001954     0.127627
# ...            ...                        ...         ...          ...
# 54018     0.164126        Punch_down_Up_Hooks    0.001609  3389.842306
# 54019     0.047913        Punch_down_Up_Hooks    0.001634  3389.874263
# 54020     0.091371        Punch_down_Up_Hooks    0.001579  3389.906221
# 54021     0.066957        Punch_down_Up_Hooks    0.001585  3389.938178
# 54022     0.048890        Punch_down_Up_Hooks    0.001677  3389.970135
#
# [54023 rows x 8 columns]

# %%
accel.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
accel
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1614726944002170    -0.182559     0.945388     0.263737
# 1              1614726944034077    -0.175723     0.980545     0.264225
# 2              1614726944065983    -0.190372     1.039139     0.292058
# 3              1614726944097890    -0.185489     1.004959     0.270573
# 4              1614726944129797    -0.148379     0.956130     0.212467
# ...                         ...          ...          ...          ...
# 54018          1614730333844476    -0.657664     1.004471     0.164126
# 54019          1614730333876433    -0.070253     1.421958     0.047913
# 54020          1614730333908391     0.326726     1.550866     0.091371
# 54021          1614730333940348     0.307683     1.206622     0.066957
# 54022          1614730333972305     0.293034     0.953201     0.048890
#
#                   Activity_Label  Sample (V)  Time_elapse
# 0      Forward and backward step    0.001991     0.000000
# 1      Forward and backward step    0.001954     0.031907
# 2      Forward and backward step    0.001929     0.063813
# 3      Forward and backward step    0.001936     0.095720
# 4      Forward and backward step    0.001954     0.127627
# ...                          ...         ...          ...
# 54018        Punch_down_Up_Hooks    0.001609  3389.842306
# 54019        Punch_down_Up_Hooks    0.001634  3389.874263
# 54020        Punch_down_Up_Hooks    0.001579  3389.906221
# 54021        Punch_down_Up_Hooks    0.001585  3389.938178
# 54022        Punch_down_Up_Hooks    0.001677  3389.970135
#
# [54023 rows x 7 columns]

# %%
#accel.to_csv('sub01_chest_accel+elec.csv', index = False)

# %%
# accel.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)
#accel

# %%
accel.to_csv('sub08_chest_accel+elec.csv', index = False)
