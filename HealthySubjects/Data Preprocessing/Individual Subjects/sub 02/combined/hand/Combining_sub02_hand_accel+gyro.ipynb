# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('final_cleaned_hand_accel-sub02.csv-sub02')
gyro = pd.read_csv('final_cleaned_hand_gyro-sub02.csv-sub02')

# %%
accel
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                0          1614546102015663     0.080995     0.311711
# 1                1          1614546102031656     0.108095     0.311467
# 2                2          1614546102047649     0.135073     0.295476
# 3                3          1614546102063642     0.163394     0.294621
# 4                4          1614546102079635     0.194278     0.295476
# ...            ...                       ...          ...          ...
# 141531      141531          1614549803922413    -0.959182     0.693553
# 141532      141532          1614549803938406    -1.002518     0.694896
# 141533      141533          1614549803954399    -0.948318     0.664012
# 141534      141534          1614549803970391    -0.807446     0.605661
# 141535      141535          1614549803986384    -0.639719     0.569039
#
#         Accel Z (g)             Activity_Label
# 0         -0.857130  Forward and backward step
# 1         -0.860548  Forward and backward step
# 2         -0.872267  Forward and backward step
# 3         -0.914015  Forward and backward step
# 4         -0.977615  Forward and backward step
# ...             ...                        ...
# 141531    -0.325750        Punch_down_Up_Hooks
# 141532    -0.343816        Punch_down_Up_Hooks
# 141533    -0.325994        Punch_down_Up_Hooks
# 141534    -0.269841        Punch_down_Up_Hooks
# 141535    -0.200504        Punch_down_Up_Hooks
#
# [141536 rows x 6 columns]

# %%
gyro
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Gyro X (°/s)  Gyro Y (°/s)  \
# 0                0          1614546102015663     12.542916     -3.204395
# 1                1          1614546102031656     11.139086     -2.594034
# 2                2          1614546102047649      9.185931     -1.861601
# 3                3          1614546102063642      6.500343     -1.068132
# 4                4          1614546102079635      3.997864     -3.143359
# ...            ...                       ...           ...           ...
# 141534      141534          1614549803922413     22.858015    -19.256886
# 141535      141535          1614549803938406     19.012741    -29.571984
# 141536      141536          1614549803954399     27.435721    -39.581903
# 141537      141537          1614549803970391     47.089342    -46.601053
# 141538      141538          1614549803986384     65.033951    -48.310063
#
#         Gyro Z (°/s)             Activity_Label
# 0          55.024033  Forward and backward step
# 1          54.779889  Forward and backward step
# 2          54.413672  Forward and backward step
# 3          55.939574  Forward and backward step
# 4          58.014801  Forward and backward step
# ...              ...                        ...
# 141534     26.947433        Punch_down_Up_Hooks
# 141535     17.853056        Punch_down_Up_Hooks
# 141536     11.566339        Punch_down_Up_Hooks
# 141537      9.246967        Punch_down_Up_Hooks
# 141538     10.406653        Punch_down_Up_Hooks
#
# [141539 rows x 6 columns]

# %%
inner_df = accel.join(gyro.set_index('Timestamp (microseconds)'), on='Timestamp (microseconds)', how='inner', lsuffix='_left', rsuffix='_right')

# %%
inner_df
# Out:
#         Unnamed: 0_left  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                     0          1614546102015663     0.080995     0.311711
# 1                     1          1614546102031656     0.108095     0.311467
# 2                     2          1614546102047649     0.135073     0.295476
# 3                     3          1614546102063642     0.163394     0.294621
# 4                     4          1614546102079635     0.194278     0.295476
# ...                 ...                       ...          ...          ...
# 141531           141531          1614549803922413    -0.959182     0.693553
# 141532           141532          1614549803938406    -1.002518     0.694896
# 141533           141533          1614549803954399    -0.948318     0.664012
# 141534           141534          1614549803970391    -0.807446     0.605661
# 141535           141535          1614549803986384    -0.639719     0.569039
#
#         Accel Z (g)        Activity_Label_left  Unnamed: 0_right  \
# 0         -0.857130  Forward and backward step                 0
# 1         -0.860548  Forward and backward step                 1
# 2         -0.872267  Forward and backward step                 2
# 3         -0.914015  Forward and backward step                 3
# 4         -0.977615  Forward and backward step                 4
# ...             ...                        ...               ...
# 141531    -0.325750        Punch_down_Up_Hooks            141534
# 141532    -0.343816        Punch_down_Up_Hooks            141535
# 141533    -0.325994        Punch_down_Up_Hooks            141536
# 141534    -0.269841        Punch_down_Up_Hooks            141537
# 141535    -0.200504        Punch_down_Up_Hooks            141538
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          12.542916     -3.204395     55.024033  Forward and backward step
# 1          11.139086     -2.594034     54.779889  Forward and backward step
# 2           9.185931     -1.861601     54.413672  Forward and backward step
# 3           6.500343     -1.068132     55.939574  Forward and backward step
# 4           3.997864     -3.143359     58.014801  Forward and backward step
# ...              ...           ...           ...                        ...
# 141531     22.858015    -19.256886     26.947433        Punch_down_Up_Hooks
# 141532     19.012741    -29.571984     17.853056        Punch_down_Up_Hooks
# 141533     27.435721    -39.581903     11.566339        Punch_down_Up_Hooks
# 141534     47.089342    -46.601053      9.246967        Punch_down_Up_Hooks
# 141535     65.033951    -48.310063     10.406653        Punch_down_Up_Hooks
#
# [178676 rows x 11 columns]

# %%
inner_df.drop(['Activity_Label_left','Unnamed: 0_left','Unnamed: 0_right'], axis=1, inplace=True)

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614546102015663     0.080995     0.311711    -0.857130
# 1               1614546102031656     0.108095     0.311467    -0.860548
# 2               1614546102047649     0.135073     0.295476    -0.872267
# 3               1614546102063642     0.163394     0.294621    -0.914015
# 4               1614546102079635     0.194278     0.295476    -0.977615
# ...                          ...          ...          ...          ...
# 141531          1614549803922413    -0.959182     0.693553    -0.325750
# 141532          1614549803938406    -1.002518     0.694896    -0.343816
# 141533          1614549803954399    -0.948318     0.664012    -0.325994
# 141534          1614549803970391    -0.807446     0.605661    -0.269841
# 141535          1614549803986384    -0.639719     0.569039    -0.200504
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          12.542916     -3.204395     55.024033  Forward and backward step
# 1          11.139086     -2.594034     54.779889  Forward and backward step
# 2           9.185931     -1.861601     54.413672  Forward and backward step
# 3           6.500343     -1.068132     55.939574  Forward and backward step
# 4           3.997864     -3.143359     58.014801  Forward and backward step
# ...              ...           ...           ...                        ...
# 141531     22.858015    -19.256886     26.947433        Punch_down_Up_Hooks
# 141532     19.012741    -29.571984     17.853056        Punch_down_Up_Hooks
# 141533     27.435721    -39.581903     11.566339        Punch_down_Up_Hooks
# 141534     47.089342    -46.601053      9.246967        Punch_down_Up_Hooks
# 141535     65.033951    -48.310063     10.406653        Punch_down_Up_Hooks
#
# [178676 rows x 8 columns]

# %%
ts = inner_df['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
inner_df['Time_elapse'] = ts1.tolist()

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614546102015663     0.080995     0.311711    -0.857130
# 1               1614546102031656     0.108095     0.311467    -0.860548
# 2               1614546102047649     0.135073     0.295476    -0.872267
# 3               1614546102063642     0.163394     0.294621    -0.914015
# 4               1614546102079635     0.194278     0.295476    -0.977615
# ...                          ...          ...          ...          ...
# 141531          1614549803922413    -0.959182     0.693553    -0.325750
# 141532          1614549803938406    -1.002518     0.694896    -0.343816
# 141533          1614549803954399    -0.948318     0.664012    -0.325994
# 141534          1614549803970391    -0.807446     0.605661    -0.269841
# 141535          1614549803986384    -0.639719     0.569039    -0.200504
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right  \
# 0          12.542916     -3.204395     55.024033  Forward and backward step
# 1          11.139086     -2.594034     54.779889  Forward and backward step
# 2           9.185931     -1.861601     54.413672  Forward and backward step
# 3           6.500343     -1.068132     55.939574  Forward and backward step
# 4           3.997864     -3.143359     58.014801  Forward and backward step
# ...              ...           ...           ...                        ...
# 141531     22.858015    -19.256886     26.947433        Punch_down_Up_Hooks
# 141532     19.012741    -29.571984     17.853056        Punch_down_Up_Hooks
# 141533     27.435721    -39.581903     11.566339        Punch_down_Up_Hooks
# 141534     47.089342    -46.601053      9.246967        Punch_down_Up_Hooks
# 141535     65.033951    -48.310063     10.406653        Punch_down_Up_Hooks
#
#         Time_elapse
# 0          0.000000
# 1          0.015993
# 2          0.031986
# 3          0.047979
# 4          0.063972
# ...             ...
# 141531  3701.906750
# 141532  3701.922743
# 141533  3701.938736
# 141534  3701.954728
# 141535  3701.970721
#
# [178676 rows x 9 columns]

# %%
# inner_df.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)

# %%
# inner_df

# %%
inner_df.to_csv('sub02_hand_accel+gyro.csv', index = False)
