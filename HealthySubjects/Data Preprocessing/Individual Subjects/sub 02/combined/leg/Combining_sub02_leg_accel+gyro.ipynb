# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('final_cleaned_leg_accel-sub02.csv-sub02')
gyro = pd.read_csv('final_cleaned_leg_gyro-sub02.csv-sub02')

# %%
accel
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                0          1614546102005397    -1.057572     0.135073
# 1                1          1614546102021373    -1.159258     0.139834
# 2                2          1614546102037348    -1.135698     0.081971
# 3                3          1614546102053324    -1.156695     0.112123
# 4                4          1614546102069299    -1.146197     0.190249
# ...            ...                       ...          ...          ...
# 138239      138239          1614549803934398    -0.000916    -0.001404
# 138240      138240          1614549803950372    -0.001038    -0.000549
# 138241      138241          1614549803966347    -0.002747    -0.001648
# 138242      138242          1614549803982321    -0.001160    -0.000183
# 138243      138243          1614549803998296    -0.001404     0.001526
#
#         Accel Z (g)             Activity_Label
# 0         -0.047913  Forward and backward step
# 1         -0.132876  Forward and backward step
# 2         -0.238590  Forward and backward step
# 3         -0.397772  Forward and backward step
# 4         -0.445014  Forward and backward step
# ...             ...                        ...
# 138239     1.020951        Punch_down_Up_Hooks
# 138240     1.021683        Punch_down_Up_Hooks
# 138241     1.020462        Punch_down_Up_Hooks
# 138242     1.021439        Punch_down_Up_Hooks
# 138243     1.021317        Punch_down_Up_Hooks
#
# [138244 rows x 6 columns]

# %%
gyro
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Gyro X (°/s)  Gyro Y (°/s)  \
# 0                0          1614546102005397     24.811170    -13.275349
# 1                1          1614546102021373     23.285267    -17.975128
# 2                2          1614546102037348     21.698329    -25.482567
# 3                3          1614546102053324     27.801938    -36.774243
# 4                4          1614546102069299     47.272450    -50.446326
# ...            ...                       ...           ...           ...
# 138243      138243          1614549803934398      0.457771     -1.373312
# 138244      138244          1614549803950372      0.457771     -1.373312
# 138245      138245          1614549803966347      0.457771     -1.434348
# 138246      138246          1614549803982321      0.457771     -1.373312
# 138247      138247          1614549803998296      0.457771     -1.373312
#
#         Gyro Z (°/s)             Activity_Label
# 0           7.476921  Forward and backward step
# 1           9.430076  Forward and backward step
# 2          11.627375  Forward and backward step
# 3           9.185931  Forward and backward step
# 4           8.880751  Forward and backward step
# ...              ...                        ...
# 138243     -0.579843        Punch_down_Up_Hooks
# 138244     -0.518807        Punch_down_Up_Hooks
# 138245     -0.579843        Punch_down_Up_Hooks
# 138246     -0.579843        Punch_down_Up_Hooks
# 138247     -0.579843        Punch_down_Up_Hooks
#
# [138248 rows x 6 columns]

# %%
inner_df = accel.join(gyro.set_index('Timestamp (microseconds)'), on='Timestamp (microseconds)', how='inner', lsuffix='_left', rsuffix='_right')

# %%
inner_df
# Out:
#         Unnamed: 0_left  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                     0          1614546102005397    -1.057572     0.135073
# 1                     1          1614546102021373    -1.159258     0.139834
# 2                     2          1614546102037348    -1.135698     0.081971
# 3                     3          1614546102053324    -1.156695     0.112123
# 4                     4          1614546102069299    -1.146197     0.190249
# ...                 ...                       ...          ...          ...
# 138239           138239          1614549803934398    -0.000916    -0.001404
# 138240           138240          1614549803950372    -0.001038    -0.000549
# 138241           138241          1614549803966347    -0.002747    -0.001648
# 138242           138242          1614549803982321    -0.001160    -0.000183
# 138243           138243          1614549803998296    -0.001404     0.001526
#
#         Accel Z (g)        Activity_Label_left  Unnamed: 0_right  \
# 0         -0.047913  Forward and backward step                 0
# 1         -0.132876  Forward and backward step                 1
# 2         -0.238590  Forward and backward step                 2
# 3         -0.397772  Forward and backward step                 3
# 4         -0.445014  Forward and backward step                 4
# ...             ...                        ...               ...
# 138239     1.020951        Punch_down_Up_Hooks            138243
# 138240     1.021683        Punch_down_Up_Hooks            138244
# 138241     1.020462        Punch_down_Up_Hooks            138245
# 138242     1.021439        Punch_down_Up_Hooks            138246
# 138243     1.021317        Punch_down_Up_Hooks            138247
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          24.811170    -13.275349      7.476921  Forward and backward step
# 1          23.285267    -17.975128      9.430076  Forward and backward step
# 2          21.698329    -25.482567     11.627375  Forward and backward step
# 3          27.801938    -36.774243      9.185931  Forward and backward step
# 4          47.272450    -50.446326      8.880751  Forward and backward step
# ...              ...           ...           ...                        ...
# 138239      0.457771     -1.373312     -0.579843        Punch_down_Up_Hooks
# 138240      0.457771     -1.373312     -0.518807        Punch_down_Up_Hooks
# 138241      0.457771     -1.434348     -0.579843        Punch_down_Up_Hooks
# 138242      0.457771     -1.373312     -0.579843        Punch_down_Up_Hooks
# 138243      0.457771     -1.373312     -0.579843        Punch_down_Up_Hooks
#
# [175424 rows x 11 columns]

# %%
inner_df.drop(['Activity_Label_left','Unnamed: 0_left','Unnamed: 0_right'], axis=1, inplace=True)

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614546102005397    -1.057572     0.135073    -0.047913
# 1               1614546102021373    -1.159258     0.139834    -0.132876
# 2               1614546102037348    -1.135698     0.081971    -0.238590
# 3               1614546102053324    -1.156695     0.112123    -0.397772
# 4               1614546102069299    -1.146197     0.190249    -0.445014
# ...                          ...          ...          ...          ...
# 138239          1614549803934398    -0.000916    -0.001404     1.020951
# 138240          1614549803950372    -0.001038    -0.000549     1.021683
# 138241          1614549803966347    -0.002747    -0.001648     1.020462
# 138242          1614549803982321    -0.001160    -0.000183     1.021439
# 138243          1614549803998296    -0.001404     0.001526     1.021317
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          24.811170    -13.275349      7.476921  Forward and backward step
# 1          23.285267    -17.975128      9.430076  Forward and backward step
# 2          21.698329    -25.482567     11.627375  Forward and backward step
# 3          27.801938    -36.774243      9.185931  Forward and backward step
# 4          47.272450    -50.446326      8.880751  Forward and backward step
# ...              ...           ...           ...                        ...
# 138239      0.457771     -1.373312     -0.579843        Punch_down_Up_Hooks
# 138240      0.457771     -1.373312     -0.518807        Punch_down_Up_Hooks
# 138241      0.457771     -1.434348     -0.579843        Punch_down_Up_Hooks
# 138242      0.457771     -1.373312     -0.579843        Punch_down_Up_Hooks
# 138243      0.457771     -1.373312     -0.579843        Punch_down_Up_Hooks
#
# [175424 rows x 8 columns]

# %%
ts = inner_df['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
inner_df['Time_elapse'] = ts1.tolist()

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614546102005397    -1.057572     0.135073    -0.047913
# 1               1614546102021373    -1.159258     0.139834    -0.132876
# 2               1614546102037348    -1.135698     0.081971    -0.238590
# 3               1614546102053324    -1.156695     0.112123    -0.397772
# 4               1614546102069299    -1.146197     0.190249    -0.445014
# ...                          ...          ...          ...          ...
# 138239          1614549803934398    -0.000916    -0.001404     1.020951
# 138240          1614549803950372    -0.001038    -0.000549     1.021683
# 138241          1614549803966347    -0.002747    -0.001648     1.020462
# 138242          1614549803982321    -0.001160    -0.000183     1.021439
# 138243          1614549803998296    -0.001404     0.001526     1.021317
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right  \
# 0          24.811170    -13.275349      7.476921  Forward and backward step
# 1          23.285267    -17.975128      9.430076  Forward and backward step
# 2          21.698329    -25.482567     11.627375  Forward and backward step
# 3          27.801938    -36.774243      9.185931  Forward and backward step
# 4          47.272450    -50.446326      8.880751  Forward and backward step
# ...              ...           ...           ...                        ...
# 138239      0.457771     -1.373312     -0.579843        Punch_down_Up_Hooks
# 138240      0.457771     -1.373312     -0.518807        Punch_down_Up_Hooks
# 138241      0.457771     -1.434348     -0.579843        Punch_down_Up_Hooks
# 138242      0.457771     -1.373312     -0.579843        Punch_down_Up_Hooks
# 138243      0.457771     -1.373312     -0.579843        Punch_down_Up_Hooks
#
#         Time_elapse
# 0          0.000000
# 1          0.015976
# 2          0.031951
# 3          0.047927
# 4          0.063902
# ...             ...
# 138239  3701.929001
# 138240  3701.944975
# 138241  3701.960950
# 138242  3701.976924
# 138243  3701.992899
#
# [175424 rows x 9 columns]

# %%
# inner_df.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)

# %%
# inner_df

# %%
inner_df.to_csv('sub02_leg_accel+gyro.csv', index = False)
