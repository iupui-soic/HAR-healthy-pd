# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('final_cleaned_chest_accel-sub03.csv-sub03')
elec = pd.read_csv('final_cleaned_chest_elec-sub03.csv-sub03')

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614622480011963     0.157290     0.597726
# 1               1          1614622480043810     0.137270     0.908766
# 2               2          1614622480075657    -0.105409     1.708095
# 3               3          1614622480107504     0.027893     0.978103
# 4               4          1614622480139351    -0.080507     0.722728
# ...           ...                       ...          ...          ...
# 54603       54603          1614627969856521    -0.423774     0.815015
# 54604       54604          1614627969888368    -0.282170     0.624094
# 54605       54605          1614627969920215    -0.325628     0.516670
# 54606       54606          1614627969952062    -0.081971     0.357488
# 54607       54607          1614627969983909     0.010803     0.518624
#
#        Accel Z (g)             Activity_Label
# 0         0.218814  Forward and backward step
# 1         0.219303  Forward and backward step
# 2         1.329671  Forward and backward step
# 3         0.469795  Forward and backward step
# 4         0.263249  Forward and backward step
# ...            ...                        ...
# 54603    -0.248478        Punch_down_Up_Hooks
# 54604    -0.616159        Punch_down_Up_Hooks
# 54605    -0.259220        Punch_down_Up_Hooks
# 54606    -0.280705        Punch_down_Up_Hooks
# 54607    -0.363714        Punch_down_Up_Hooks
#
# [54608 rows x 6 columns]

# %%
elec
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Sample (V)  \
# 0                0          1614622480002534   -0.010743
# 1                1          1614622480006538   -0.010743
# 2                2          1614622480010542   -0.010749
# 3                3          1614622480014546   -0.010718
# 4                4          1614622480018550   -0.010669
# ...            ...                       ...         ...
# 433866      433866          1614627969981168   -0.001597
# 433867      433867          1614627969985175   -0.001591
# 433868      433868          1614627969989182   -0.001517
# 433869      433869          1614627969993189   -0.001609
# 433870      433870          1614627969997196   -0.001603
#
#                    Activity_Label
# 0       Forward and backward step
# 1       Forward and backward step
# 2       Forward and backward step
# 3       Forward and backward step
# 4       Forward and backward step
# ...                           ...
# 433866        Punch_down_Up_Hooks
# 433867        Punch_down_Up_Hooks
# 433868        Punch_down_Up_Hooks
# 433869        Punch_down_Up_Hooks
# 433870        Punch_down_Up_Hooks
#
# [433871 rows x 4 columns]

# %%
elec_ts = elec['Timestamp (microseconds)'].to_numpy()

# %%
elec_ts
# Out:
# array([1614622480002534, 1614622480006538, 1614622480010542, ...,
#        1614627969989182, 1614627969993189, 1614627969997196])

# %%
accel_ts = accel['Timestamp (microseconds)'].to_numpy()

# %%
accel_ts
# Out:
# array([1614622480011963, 1614622480043810, 1614622480075657, ...,
#        1614627969920215, 1614627969952062, 1614627969983909])

# %%
for i in range(len(accel_ts)):
    accel.at[i, 'Sample (V)'] = elec['Sample (V)'].iloc[np.argmin(abs(accel_ts[i] - elec_ts))]

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614622480011963     0.157290     0.597726
# 1               1          1614622480043810     0.137270     0.908766
# 2               2          1614622480075657    -0.105409     1.708095
# 3               3          1614622480107504     0.027893     0.978103
# 4               4          1614622480139351    -0.080507     0.722728
# ...           ...                       ...          ...          ...
# 54603       54603          1614627969856521    -0.423774     0.815015
# 54604       54604          1614627969888368    -0.282170     0.624094
# 54605       54605          1614627969920215    -0.325628     0.516670
# 54606       54606          1614627969952062    -0.081971     0.357488
# 54607       54607          1614627969983909     0.010803     0.518624
#
#        Accel Z (g)             Activity_Label  Sample (V)
# 0         0.218814  Forward and backward step   -0.010749
# 1         0.219303  Forward and backward step   -0.010620
# 2         1.329671  Forward and backward step   -0.010656
# 3         0.469795  Forward and backward step   -0.010681
# 4         0.263249  Forward and backward step   -0.010693
# ...            ...                        ...         ...
# 54603    -0.248478        Punch_down_Up_Hooks   -0.000822
# 54604    -0.616159        Punch_down_Up_Hooks   -0.001320
# 54605    -0.259220        Punch_down_Up_Hooks   -0.001548
# 54606    -0.280705        Punch_down_Up_Hooks   -0.001474
# 54607    -0.363714        Punch_down_Up_Hooks   -0.001591
#
# [54608 rows x 7 columns]

# %%
ts = accel['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
accel['Time_elapse'] = ts1.tolist()

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614622480011963     0.157290     0.597726
# 1               1          1614622480043810     0.137270     0.908766
# 2               2          1614622480075657    -0.105409     1.708095
# 3               3          1614622480107504     0.027893     0.978103
# 4               4          1614622480139351    -0.080507     0.722728
# ...           ...                       ...          ...          ...
# 54603       54603          1614627969856521    -0.423774     0.815015
# 54604       54604          1614627969888368    -0.282170     0.624094
# 54605       54605          1614627969920215    -0.325628     0.516670
# 54606       54606          1614627969952062    -0.081971     0.357488
# 54607       54607          1614627969983909     0.010803     0.518624
#
#        Accel Z (g)             Activity_Label  Sample (V)  Time_elapse
# 0         0.218814  Forward and backward step   -0.010749     0.000000
# 1         0.219303  Forward and backward step   -0.010620     0.031847
# 2         1.329671  Forward and backward step   -0.010656     0.063694
# 3         0.469795  Forward and backward step   -0.010681     0.095541
# 4         0.263249  Forward and backward step   -0.010693     0.127388
# ...            ...                        ...         ...          ...
# 54603    -0.248478        Punch_down_Up_Hooks   -0.000822  5489.844558
# 54604    -0.616159        Punch_down_Up_Hooks   -0.001320  5489.876405
# 54605    -0.259220        Punch_down_Up_Hooks   -0.001548  5489.908252
# 54606    -0.280705        Punch_down_Up_Hooks   -0.001474  5489.940099
# 54607    -0.363714        Punch_down_Up_Hooks   -0.001591  5489.971946
#
# [54608 rows x 8 columns]

# %%
accel.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
accel
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1614622480011963     0.157290     0.597726     0.218814
# 1              1614622480043810     0.137270     0.908766     0.219303
# 2              1614622480075657    -0.105409     1.708095     1.329671
# 3              1614622480107504     0.027893     0.978103     0.469795
# 4              1614622480139351    -0.080507     0.722728     0.263249
# ...                         ...          ...          ...          ...
# 54603          1614627969856521    -0.423774     0.815015    -0.248478
# 54604          1614627969888368    -0.282170     0.624094    -0.616159
# 54605          1614627969920215    -0.325628     0.516670    -0.259220
# 54606          1614627969952062    -0.081971     0.357488    -0.280705
# 54607          1614627969983909     0.010803     0.518624    -0.363714
#
#                   Activity_Label  Sample (V)  Time_elapse
# 0      Forward and backward step   -0.010749     0.000000
# 1      Forward and backward step   -0.010620     0.031847
# 2      Forward and backward step   -0.010656     0.063694
# 3      Forward and backward step   -0.010681     0.095541
# 4      Forward and backward step   -0.010693     0.127388
# ...                          ...         ...          ...
# 54603        Punch_down_Up_Hooks   -0.000822  5489.844558
# 54604        Punch_down_Up_Hooks   -0.001320  5489.876405
# 54605        Punch_down_Up_Hooks   -0.001548  5489.908252
# 54606        Punch_down_Up_Hooks   -0.001474  5489.940099
# 54607        Punch_down_Up_Hooks   -0.001591  5489.971946
#
# [54608 rows x 7 columns]

# %%
#accel.to_csv('sub01_chest_accel+elec.csv', index = False)

# %%
# accel.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)
#accel

# %%
accel.to_csv('sub03_chest_accel+elec.csv', index = False)
