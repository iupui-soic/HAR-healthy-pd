# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('final_cleaned_hand_accel-sub03.csv-sub03')
gyro = pd.read_csv('final_cleaned_hand_gyro-sub03.csv-sub03')

# %%
accel
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                0          1614622480005655    -0.161318     0.541573
# 1                1          1614622480021648    -0.130312     0.595895
# 2                2          1614622480037641    -0.134340     0.572091
# 3                3          1614622480053633    -0.195132     0.525704
# 4                4          1614622480069626    -0.301335     0.408881
# ...            ...                       ...          ...          ...
# 108648      108648          1614627969929834    -0.026307    -0.065492
# 108649      108649          1614627969945826    -0.024720    -0.065614
# 108650      108650          1614627969961819    -0.026184    -0.066102
# 108651      108651          1614627969977813    -0.026307    -0.065492
# 108652      108652          1614627969993806    -0.024842    -0.066346
#
#         Accel Z (g)             Activity_Label
# 0         -0.548043  Forward and backward step
# 1         -0.642405  Forward and backward step
# 2         -0.816358  Forward and backward step
# 3         -1.000809  Forward and backward step
# 4         -1.181964  Forward and backward step
# ...             ...                        ...
# 108648    -0.990311        Punch_down_Up_Hooks
# 108649    -0.990188        Punch_down_Up_Hooks
# 108650    -0.987137        Punch_down_Up_Hooks
# 108651    -0.988846        Punch_down_Up_Hooks
# 108652    -0.989822        Punch_down_Up_Hooks
#
# [108653 rows x 6 columns]

# %%
gyro
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Gyro X (°/s)  Gyro Y (°/s)  \
# 0                0          1614622480005655     79.194324     40.558480
# 1                1          1614622480021648     41.962310     50.446326
# 2                2          1614622480037641     -6.134127     59.052415
# 3                3          1614622480053633    -48.249027     65.461204
# 4                4          1614622480069626    -91.828794     67.780575
# ...            ...                       ...           ...           ...
# 108666      108666          1614627969929834      0.701915     -1.007095
# 108667      108667          1614627969945826      0.762951     -1.007095
# 108668      108668          1614627969961819      0.701915     -1.007095
# 108669      108669          1614627969977813      0.701915     -1.007095
# 108670      108670          1614627969993806      0.701915     -1.007095
#
#         Gyro Z (°/s)             Activity_Label
# 0         -41.840238  Forward and backward step
# 1         -52.155337  Forward and backward step
# 2         -61.310750  Forward and backward step
# 3         -70.344091  Forward and backward step
# 4         -74.677653  Forward and backward step
# ...              ...                        ...
# 108666     -0.640879        Punch_down_Up_Hooks
# 108667     -0.701915        Punch_down_Up_Hooks
# 108668     -0.701915        Punch_down_Up_Hooks
# 108669     -0.701915        Punch_down_Up_Hooks
# 108670     -0.701915        Punch_down_Up_Hooks
#
# [108671 rows x 6 columns]

# %%
inner_df = accel.join(gyro.set_index('Timestamp (microseconds)'), on='Timestamp (microseconds)', how='inner', lsuffix='_left', rsuffix='_right')

# %%
inner_df
# Out:
#         Unnamed: 0_left  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                     0          1614622480005655    -0.161318     0.541573
# 1                     1          1614622480021648    -0.130312     0.595895
# 2                     2          1614622480037641    -0.134340     0.572091
# 3                     3          1614622480053633    -0.195132     0.525704
# 4                     4          1614622480069626    -0.301335     0.408881
# ...                 ...                       ...          ...          ...
# 108648           108648          1614627969929834    -0.026307    -0.065492
# 108649           108649          1614627969945826    -0.024720    -0.065614
# 108650           108650          1614627969961819    -0.026184    -0.066102
# 108651           108651          1614627969977813    -0.026307    -0.065492
# 108652           108652          1614627969993806    -0.024842    -0.066346
#
#         Accel Z (g)        Activity_Label_left  Unnamed: 0_right  \
# 0         -0.548043  Forward and backward step                 0
# 1         -0.642405  Forward and backward step                 1
# 2         -0.816358  Forward and backward step                 2
# 3         -1.000809  Forward and backward step                 3
# 4         -1.181964  Forward and backward step                 4
# ...             ...                        ...               ...
# 108648    -0.990311        Punch_down_Up_Hooks            108666
# 108649    -0.990188        Punch_down_Up_Hooks            108667
# 108650    -0.987137        Punch_down_Up_Hooks            108668
# 108651    -0.988846        Punch_down_Up_Hooks            108669
# 108652    -0.989822        Punch_down_Up_Hooks            108670
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          79.194324     40.558480    -41.840238  Forward and backward step
# 1          41.962310     50.446326    -52.155337  Forward and backward step
# 2          -6.134127     59.052415    -61.310750  Forward and backward step
# 3         -48.249027     65.461204    -70.344091  Forward and backward step
# 4         -91.828794     67.780575    -74.677653  Forward and backward step
# ...              ...           ...           ...                        ...
# 108648      0.701915     -1.007095     -0.640879        Punch_down_Up_Hooks
# 108649      0.762951     -1.007095     -0.701915        Punch_down_Up_Hooks
# 108650      0.701915     -1.007095     -0.701915        Punch_down_Up_Hooks
# 108651      0.701915     -1.007095     -0.701915        Punch_down_Up_Hooks
# 108652      0.701915     -1.007095     -0.701915        Punch_down_Up_Hooks
#
# [108653 rows x 11 columns]

# %%
inner_df.drop(['Activity_Label_left','Unnamed: 0_left','Unnamed: 0_right'], axis=1, inplace=True)

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614622480005655    -0.161318     0.541573    -0.548043
# 1               1614622480021648    -0.130312     0.595895    -0.642405
# 2               1614622480037641    -0.134340     0.572091    -0.816358
# 3               1614622480053633    -0.195132     0.525704    -1.000809
# 4               1614622480069626    -0.301335     0.408881    -1.181964
# ...                          ...          ...          ...          ...
# 108648          1614627969929834    -0.026307    -0.065492    -0.990311
# 108649          1614627969945826    -0.024720    -0.065614    -0.990188
# 108650          1614627969961819    -0.026184    -0.066102    -0.987137
# 108651          1614627969977813    -0.026307    -0.065492    -0.988846
# 108652          1614627969993806    -0.024842    -0.066346    -0.989822
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          79.194324     40.558480    -41.840238  Forward and backward step
# 1          41.962310     50.446326    -52.155337  Forward and backward step
# 2          -6.134127     59.052415    -61.310750  Forward and backward step
# 3         -48.249027     65.461204    -70.344091  Forward and backward step
# 4         -91.828794     67.780575    -74.677653  Forward and backward step
# ...              ...           ...           ...                        ...
# 108648      0.701915     -1.007095     -0.640879        Punch_down_Up_Hooks
# 108649      0.762951     -1.007095     -0.701915        Punch_down_Up_Hooks
# 108650      0.701915     -1.007095     -0.701915        Punch_down_Up_Hooks
# 108651      0.701915     -1.007095     -0.701915        Punch_down_Up_Hooks
# 108652      0.701915     -1.007095     -0.701915        Punch_down_Up_Hooks
#
# [108653 rows x 8 columns]

# %%
ts = inner_df['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
inner_df['Time_elapse'] = ts1.tolist()

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614622480005655    -0.161318     0.541573    -0.548043
# 1               1614622480021648    -0.130312     0.595895    -0.642405
# 2               1614622480037641    -0.134340     0.572091    -0.816358
# 3               1614622480053633    -0.195132     0.525704    -1.000809
# 4               1614622480069626    -0.301335     0.408881    -1.181964
# ...                          ...          ...          ...          ...
# 108648          1614627969929834    -0.026307    -0.065492    -0.990311
# 108649          1614627969945826    -0.024720    -0.065614    -0.990188
# 108650          1614627969961819    -0.026184    -0.066102    -0.987137
# 108651          1614627969977813    -0.026307    -0.065492    -0.988846
# 108652          1614627969993806    -0.024842    -0.066346    -0.989822
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right  \
# 0          79.194324     40.558480    -41.840238  Forward and backward step
# 1          41.962310     50.446326    -52.155337  Forward and backward step
# 2          -6.134127     59.052415    -61.310750  Forward and backward step
# 3         -48.249027     65.461204    -70.344091  Forward and backward step
# 4         -91.828794     67.780575    -74.677653  Forward and backward step
# ...              ...           ...           ...                        ...
# 108648      0.701915     -1.007095     -0.640879        Punch_down_Up_Hooks
# 108649      0.762951     -1.007095     -0.701915        Punch_down_Up_Hooks
# 108650      0.701915     -1.007095     -0.701915        Punch_down_Up_Hooks
# 108651      0.701915     -1.007095     -0.701915        Punch_down_Up_Hooks
# 108652      0.701915     -1.007095     -0.701915        Punch_down_Up_Hooks
#
#         Time_elapse
# 0          0.000000
# 1          0.015993
# 2          0.031986
# 3          0.047978
# 4          0.063971
# ...             ...
# 108648  5489.924179
# 108649  5489.940171
# 108650  5489.956164
# 108651  5489.972158
# 108652  5489.988151
#
# [108653 rows x 9 columns]

# %%
# inner_df.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)

# %%
# inner_df

# %%
inner_df.to_csv('sub03_hand_accel+gyro.csv', index = False)
