# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('final_cleaned_leg_accel-sub03.csv-sub03')
gyro = pd.read_csv('final_cleaned_leg_gyro-sub03.csv-sub03')

# %%
accel
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                0          1614622480002407    -1.001907    -0.267887
# 1                1          1614622480018382    -0.904494     0.172183
# 2                2          1614622480034358    -0.753368     0.304753
# 3                3          1614622480050333    -0.574777     0.139345
# 4                4          1614622480066309    -0.435492     0.008484
# ...            ...                       ...          ...          ...
# 108680      108680          1614627969927669    -0.910597     0.420844
# 108681      108681          1614627969943668    -0.925124     0.417548
# 108682      108682          1614627969959667    -0.904494     0.429633
# 108683      108683          1614627969975667    -0.899367     0.445380
# 108684      108684          1614627969991666    -0.923171     0.438666
#
#         Accel Z (g)             Activity_Label
# 0          0.573556  Forward and backward step
# 1          0.620554  Forward and backward step
# 2          0.631662  Forward and backward step
# 3          0.573678  Forward and backward step
# 4          0.635203  Forward and backward step
# ...             ...                        ...
# 108680     0.077455        Punch_down_Up_Hooks
# 108681     0.087953        Punch_down_Up_Hooks
# 108682     0.085023        Punch_down_Up_Hooks
# 108683     0.052308        Punch_down_Up_Hooks
# 108684     0.038025        Punch_down_Up_Hooks
#
# [108685 rows x 6 columns]

# %%
gyro
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Gyro X (°/s)  Gyro Y (°/s)  \
# 0                0          1614622480002407     43.427176   -118.989853
# 1                1          1614622480018382     47.211414   -136.690318
# 2                2          1614622480034358     28.961624   -146.028840
# 3                3          1614622480050333     -5.401694   -141.939422
# 4                4          1614622480066309    -31.403067   -127.168688
# ...            ...                       ...           ...           ...
# 108681      108681          1614627969927669     -6.622416      3.631647
# 108682      108682          1614627969943668     -6.439307      2.777142
# 108683      108683          1614627969959667     -5.523766      0.640879
# 108684      108684          1614627969975667     -3.570611     -0.885023
# 108685      108685          1614627969991666     -4.791333     -2.899214
#
#         Gyro Z (°/s)             Activity_Label
# 0         -54.474708  Forward and backward step
# 1         -49.469749  Forward and backward step
# 2         -50.507362  Forward and backward step
# 3         -58.258946  Forward and backward step
# 4         -57.709621  Forward and backward step
# ...              ...                        ...
# 108681      2.838178        Punch_down_Up_Hooks
# 108682      2.594034        Punch_down_Up_Hooks
# 108683      2.471962        Punch_down_Up_Hooks
# 108684      2.899214        Punch_down_Up_Hooks
# 108685      1.556420        Punch_down_Up_Hooks
#
# [108686 rows x 6 columns]

# %%
inner_df = accel.join(gyro.set_index('Timestamp (microseconds)'), on='Timestamp (microseconds)', how='inner', lsuffix='_left', rsuffix='_right')

# %%
inner_df
# Out:
#         Unnamed: 0_left  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                     0          1614622480002407    -1.001907    -0.267887
# 1                     1          1614622480018382    -0.904494     0.172183
# 2                     2          1614622480034358    -0.753368     0.304753
# 3                     3          1614622480050333    -0.574777     0.139345
# 4                     4          1614622480066309    -0.435492     0.008484
# ...                 ...                       ...          ...          ...
# 108680           108680          1614627969927669    -0.910597     0.420844
# 108681           108681          1614627969943668    -0.925124     0.417548
# 108682           108682          1614627969959667    -0.904494     0.429633
# 108683           108683          1614627969975667    -0.899367     0.445380
# 108684           108684          1614627969991666    -0.923171     0.438666
#
#         Accel Z (g)        Activity_Label_left  Unnamed: 0_right  \
# 0          0.573556  Forward and backward step                 0
# 1          0.620554  Forward and backward step                 1
# 2          0.631662  Forward and backward step                 2
# 3          0.573678  Forward and backward step                 3
# 4          0.635203  Forward and backward step                 4
# ...             ...                        ...               ...
# 108680     0.077455        Punch_down_Up_Hooks            108681
# 108681     0.087953        Punch_down_Up_Hooks            108682
# 108682     0.085023        Punch_down_Up_Hooks            108683
# 108683     0.052308        Punch_down_Up_Hooks            108684
# 108684     0.038025        Punch_down_Up_Hooks            108685
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          43.427176   -118.989853    -54.474708  Forward and backward step
# 1          47.211414   -136.690318    -49.469749  Forward and backward step
# 2          28.961624   -146.028840    -50.507362  Forward and backward step
# 3          -5.401694   -141.939422    -58.258946  Forward and backward step
# 4         -31.403067   -127.168688    -57.709621  Forward and backward step
# ...              ...           ...           ...                        ...
# 108680     -6.622416      3.631647      2.838178        Punch_down_Up_Hooks
# 108681     -6.439307      2.777142      2.594034        Punch_down_Up_Hooks
# 108682     -5.523766      0.640879      2.471962        Punch_down_Up_Hooks
# 108683     -3.570611     -0.885023      2.899214        Punch_down_Up_Hooks
# 108684     -4.791333     -2.899214      1.556420        Punch_down_Up_Hooks
#
# [108685 rows x 11 columns]

# %%
inner_df.drop(['Activity_Label_left','Unnamed: 0_left','Unnamed: 0_right'], axis=1, inplace=True)

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614622480002407    -1.001907    -0.267887     0.573556
# 1               1614622480018382    -0.904494     0.172183     0.620554
# 2               1614622480034358    -0.753368     0.304753     0.631662
# 3               1614622480050333    -0.574777     0.139345     0.573678
# 4               1614622480066309    -0.435492     0.008484     0.635203
# ...                          ...          ...          ...          ...
# 108680          1614627969927669    -0.910597     0.420844     0.077455
# 108681          1614627969943668    -0.925124     0.417548     0.087953
# 108682          1614627969959667    -0.904494     0.429633     0.085023
# 108683          1614627969975667    -0.899367     0.445380     0.052308
# 108684          1614627969991666    -0.923171     0.438666     0.038025
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          43.427176   -118.989853    -54.474708  Forward and backward step
# 1          47.211414   -136.690318    -49.469749  Forward and backward step
# 2          28.961624   -146.028840    -50.507362  Forward and backward step
# 3          -5.401694   -141.939422    -58.258946  Forward and backward step
# 4         -31.403067   -127.168688    -57.709621  Forward and backward step
# ...              ...           ...           ...                        ...
# 108680     -6.622416      3.631647      2.838178        Punch_down_Up_Hooks
# 108681     -6.439307      2.777142      2.594034        Punch_down_Up_Hooks
# 108682     -5.523766      0.640879      2.471962        Punch_down_Up_Hooks
# 108683     -3.570611     -0.885023      2.899214        Punch_down_Up_Hooks
# 108684     -4.791333     -2.899214      1.556420        Punch_down_Up_Hooks
#
# [108685 rows x 8 columns]

# %%
ts = inner_df['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
inner_df['Time_elapse'] = ts1.tolist()

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614622480002407    -1.001907    -0.267887     0.573556
# 1               1614622480018382    -0.904494     0.172183     0.620554
# 2               1614622480034358    -0.753368     0.304753     0.631662
# 3               1614622480050333    -0.574777     0.139345     0.573678
# 4               1614622480066309    -0.435492     0.008484     0.635203
# ...                          ...          ...          ...          ...
# 108680          1614627969927669    -0.910597     0.420844     0.077455
# 108681          1614627969943668    -0.925124     0.417548     0.087953
# 108682          1614627969959667    -0.904494     0.429633     0.085023
# 108683          1614627969975667    -0.899367     0.445380     0.052308
# 108684          1614627969991666    -0.923171     0.438666     0.038025
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right  \
# 0          43.427176   -118.989853    -54.474708  Forward and backward step
# 1          47.211414   -136.690318    -49.469749  Forward and backward step
# 2          28.961624   -146.028840    -50.507362  Forward and backward step
# 3          -5.401694   -141.939422    -58.258946  Forward and backward step
# 4         -31.403067   -127.168688    -57.709621  Forward and backward step
# ...              ...           ...           ...                        ...
# 108680     -6.622416      3.631647      2.838178        Punch_down_Up_Hooks
# 108681     -6.439307      2.777142      2.594034        Punch_down_Up_Hooks
# 108682     -5.523766      0.640879      2.471962        Punch_down_Up_Hooks
# 108683     -3.570611     -0.885023      2.899214        Punch_down_Up_Hooks
# 108684     -4.791333     -2.899214      1.556420        Punch_down_Up_Hooks
#
#         Time_elapse
# 0          0.000000
# 1          0.015975
# 2          0.031951
# 3          0.047926
# 4          0.063902
# ...             ...
# 108680  5489.925262
# 108681  5489.941261
# 108682  5489.957260
# 108683  5489.973260
# 108684  5489.989259
#
# [108685 rows x 9 columns]

# %%
# inner_df.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)

# %%
# inner_df

# %%
inner_df.to_csv('sub03_leg_accel+gyro.csv', index = False)
