# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('/Users/shreyasaswar/HARDataset/EXTRACTION/SUB 07/chest/cleaned/final_cleaned_chest_accel.csv-sub07')
elec = pd.read_csv('/Users/shreyasaswar/HARDataset/EXTRACTION/SUB 07/chest/cleaned/final_cleaned_chest_elec.csv-sub07')

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614720421010882    -0.112734     0.893629
# 1               1          1614720421042813    -0.108827     0.918532
# 2               2          1614720421074745    -0.114687     0.911696
# 3               3          1614720421106676    -0.085878     0.933669
# 4               4          1614720421138608    -0.094179     0.896559
# ...           ...                       ...          ...          ...
# 54351       54351          1614724259860031     0.072328     0.247623
# 54352       54352          1614724259892024     0.030335     0.353094
# 54353       54353          1614724259924016    -0.174746     0.696361
# 54354       54354          1614724259956009    -0.294377     1.357504
# 54355       54355          1614724259988001    -0.246525     1.092851
#
#        Accel Z (g)             Activity_Label
# 0         0.390204  Forward and backward step
# 1         0.396063  Forward and backward step
# 2         0.422919  Forward and backward step
# 3         0.417060  Forward and backward step
# 4         0.433173  Forward and backward step
# ...            ...                        ...
# 54351    -0.000916        Punch_down_Up_Hooks
# 54352     0.085512        Punch_down_Up_Hooks
# 54353    -0.011658        Punch_down_Up_Hooks
# 54354    -0.079530        Punch_down_Up_Hooks
# 54355     0.295476        Punch_down_Up_Hooks
#
# [54356 rows x 6 columns]

# %%
elec
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Sample (V)  \
# 0                0          1614720421001216    0.001874
# 1                1          1614720421005224    0.001893
# 2                2          1614720421009232    0.001893
# 3                3          1614720421013239    0.001899
# 4                4          1614720421017247    0.001929
# ...            ...                       ...         ...
# 432841      432841          1614724259980772    0.001776
# 432842      432842          1614724259984779    0.001794
# 432843      432843          1614724259988786    0.001825
# 432844      432844          1614724259992794    0.001819
# 432845      432845          1614724259996801    0.001806
#
#                    Activity_Label
# 0       Forward and backward step
# 1       Forward and backward step
# 2       Forward and backward step
# 3       Forward and backward step
# 4       Forward and backward step
# ...                           ...
# 432841        Punch_down_Up_Hooks
# 432842        Punch_down_Up_Hooks
# 432843        Punch_down_Up_Hooks
# 432844        Punch_down_Up_Hooks
# 432845        Punch_down_Up_Hooks
#
# [432846 rows x 4 columns]

# %%
elec_ts = elec['Timestamp (microseconds)'].to_numpy()

# %%
elec_ts
# Out:
# array([1614720421001216, 1614720421005224, 1614720421009232, ...,
#        1614724259988786, 1614724259992794, 1614724259996801])

# %%
accel_ts = accel['Timestamp (microseconds)'].to_numpy()

# %%
accel_ts
# Out:
# array([1614720421010882, 1614720421042813, 1614720421074745, ...,
#        1614724259924016, 1614724259956009, 1614724259988001])

# %%
for i in range(len(accel_ts)):
    accel.at[i, 'Sample (V)'] = elec['Sample (V)'].iloc[np.argmin(abs(accel_ts[i] - elec_ts))]

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614720421010882    -0.112734     0.893629
# 1               1          1614720421042813    -0.108827     0.918532
# 2               2          1614720421074745    -0.114687     0.911696
# 3               3          1614720421106676    -0.085878     0.933669
# 4               4          1614720421138608    -0.094179     0.896559
# ...           ...                       ...          ...          ...
# 54351       54351          1614724259860031     0.072328     0.247623
# 54352       54352          1614724259892024     0.030335     0.353094
# 54353       54353          1614724259924016    -0.174746     0.696361
# 54354       54354          1614724259956009    -0.294377     1.357504
# 54355       54355          1614724259988001    -0.246525     1.092851
#
#        Accel Z (g)             Activity_Label  Sample (V)
# 0         0.390204  Forward and backward step    0.001893
# 1         0.396063  Forward and backward step    0.001899
# 2         0.422919  Forward and backward step    0.001917
# 3         0.417060  Forward and backward step    0.001893
# 4         0.433173  Forward and backward step    0.001893
# ...            ...                        ...         ...
# 54351    -0.000916        Punch_down_Up_Hooks    0.001843
# 54352     0.085512        Punch_down_Up_Hooks    0.001806
# 54353    -0.011658        Punch_down_Up_Hooks    0.001948
# 54354    -0.079530        Punch_down_Up_Hooks    0.001874
# 54355     0.295476        Punch_down_Up_Hooks    0.001825
#
# [54356 rows x 7 columns]

# %%
ts = accel['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
accel['Time_elapse'] = ts1.tolist()

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614720421010882    -0.112734     0.893629
# 1               1          1614720421042813    -0.108827     0.918532
# 2               2          1614720421074745    -0.114687     0.911696
# 3               3          1614720421106676    -0.085878     0.933669
# 4               4          1614720421138608    -0.094179     0.896559
# ...           ...                       ...          ...          ...
# 54351       54351          1614724259860031     0.072328     0.247623
# 54352       54352          1614724259892024     0.030335     0.353094
# 54353       54353          1614724259924016    -0.174746     0.696361
# 54354       54354          1614724259956009    -0.294377     1.357504
# 54355       54355          1614724259988001    -0.246525     1.092851
#
#        Accel Z (g)             Activity_Label  Sample (V)  Time_elapse
# 0         0.390204  Forward and backward step    0.001893     0.000000
# 1         0.396063  Forward and backward step    0.001899     0.031931
# 2         0.422919  Forward and backward step    0.001917     0.063863
# 3         0.417060  Forward and backward step    0.001893     0.095794
# 4         0.433173  Forward and backward step    0.001893     0.127726
# ...            ...                        ...         ...          ...
# 54351    -0.000916        Punch_down_Up_Hooks    0.001843  3838.849149
# 54352     0.085512        Punch_down_Up_Hooks    0.001806  3838.881142
# 54353    -0.011658        Punch_down_Up_Hooks    0.001948  3838.913134
# 54354    -0.079530        Punch_down_Up_Hooks    0.001874  3838.945127
# 54355     0.295476        Punch_down_Up_Hooks    0.001825  3838.977119
#
# [54356 rows x 8 columns]

# %%
accel.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
accel
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1614720421010882    -0.112734     0.893629     0.390204
# 1              1614720421042813    -0.108827     0.918532     0.396063
# 2              1614720421074745    -0.114687     0.911696     0.422919
# 3              1614720421106676    -0.085878     0.933669     0.417060
# 4              1614720421138608    -0.094179     0.896559     0.433173
# ...                         ...          ...          ...          ...
# 54351          1614724259860031     0.072328     0.247623    -0.000916
# 54352          1614724259892024     0.030335     0.353094     0.085512
# 54353          1614724259924016    -0.174746     0.696361    -0.011658
# 54354          1614724259956009    -0.294377     1.357504    -0.079530
# 54355          1614724259988001    -0.246525     1.092851     0.295476
#
#                   Activity_Label  Sample (V)  Time_elapse
# 0      Forward and backward step    0.001893     0.000000
# 1      Forward and backward step    0.001899     0.031931
# 2      Forward and backward step    0.001917     0.063863
# 3      Forward and backward step    0.001893     0.095794
# 4      Forward and backward step    0.001893     0.127726
# ...                          ...         ...          ...
# 54351        Punch_down_Up_Hooks    0.001843  3838.849149
# 54352        Punch_down_Up_Hooks    0.001806  3838.881142
# 54353        Punch_down_Up_Hooks    0.001948  3838.913134
# 54354        Punch_down_Up_Hooks    0.001874  3838.945127
# 54355        Punch_down_Up_Hooks    0.001825  3838.977119
#
# [54356 rows x 7 columns]

# %%
#accel.to_csv('sub01_chest_accel+elec.csv', index = False)

# %%
# accel.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)
#accel

# %%
accel.to_csv('sub07_chest_accel+elec.csv', index = False)
