# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('/Users/shreyasaswar/HARDataset/EXTRACTION/SUB\ 07/hand/cleaned/final_cleaned_hand_accel.csv-sub07')
gyro = pd.read_csv('/Users/shreyasaswar/HARDataset/EXTRACTION/SUB\ 07/hand/cleaned/final_cleaned_hand_gyro.csv-sub07')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/q7/2hlrtt8s33n8vg4p3xcc4z3m0000gn/T/ipykernel_8500/581783187.py in <module>
#       1 accel = pd.read_csv('/Users/shreyasaswar/HARDataset/EXTRACTION/SUB 07/hand/cleaned/final_cleaned_hand_accel.csv-sub07')
# ----> 2 gyro = pd.read_csv('/Users/shreyasaswar/HARDataset/EXTRACTION/SUB 07/hand/cleaned/final_cleaned_hand_elec.csv-sub07')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/shreyasaswar/HARDataset/EXTRACTION/SUB 07/hand/cleaned/final_cleaned_hand_elec.csv-sub07'

# %%
accel

# %%
gyro

# %%
inner_df = accel.join(gyro.set_index('Timestamp (microseconds)'), on='Timestamp (microseconds)', how='inner', lsuffix='_left', rsuffix='_right')

# %%
inner_df
# Out:
#         Unnamed: 0_left  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                     0          1614642696013219    -0.007752     0.613474
# 1                     1          1614642696029217     0.089296     0.548287
# 2                     2          1614642696045216     0.175601     0.534249
# 3                     3          1614642696061214     0.263127     0.519234
# 4                     4          1614642696077212     0.321721     0.503609
# ...                 ...                       ...          ...          ...
# 108743           108743          1614646535926178    -0.923781     0.981155
# 108744           108744          1614646535942176    -0.794263     0.829419
# 108745           108745          1614646535958175    -0.718090     0.703197
# 108746           108746          1614646535974174    -0.665599     0.661936
# 108747           108747          1614646535990173    -0.660716     0.684764
#
#         Accel Z (g)        Activity_Label_left  Unnamed: 0_right  \
# 0         -0.545602  Forward and backward step                 0
# 1         -0.474800  Forward and backward step                 1
# 2         -0.429877  Forward and backward step                 2
# 3         -0.392157  Forward and backward step                 3
# 4         -0.352605  Forward and backward step                 4
# ...             ...                        ...               ...
# 108743    -0.478096        Punch_down_Up_Hooks            108751
# 108744    -0.471260        Punch_down_Up_Hooks            108752
# 108745    -0.507149        Punch_down_Up_Hooks            108753
# 108746    -0.543038        Punch_down_Up_Hooks            108754
# 108747    -0.533272        Punch_down_Up_Hooks            108755
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          20.538643      6.256199    -47.882811  Forward and backward step
# 1          17.120623     10.528725    -41.596094  Forward and backward step
# 2          14.984360     11.139086    -38.727398  Forward and backward step
# 3          14.801251      9.063859    -35.492485  Forward and backward step
# 4          19.073777      5.096513    -29.694057  Forward and backward step
# ...              ...           ...           ...                        ...
# 108743    -29.816129     54.169528     -4.608225        Punch_down_Up_Hooks
# 108744    -51.728084     56.427863     -1.434348        Punch_down_Up_Hooks
# 108745    -65.827420     54.718853    -17.242695        Punch_down_Up_Hooks
# 108746    -56.549935     48.798352    -33.722438        Punch_down_Up_Hooks
# 108747    -30.243381     38.971542    -44.647898        Punch_down_Up_Hooks
#
# [108748 rows x 11 columns]

# %%
inner_df.drop(['Activity_Label_left','Unnamed: 0_left','Unnamed: 0_right'], axis=1, inplace=True)

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614642696013219    -0.007752     0.613474    -0.545602
# 1               1614642696029217     0.089296     0.548287    -0.474800
# 2               1614642696045216     0.175601     0.534249    -0.429877
# 3               1614642696061214     0.263127     0.519234    -0.392157
# 4               1614642696077212     0.321721     0.503609    -0.352605
# ...                          ...          ...          ...          ...
# 108743          1614646535926178    -0.923781     0.981155    -0.478096
# 108744          1614646535942176    -0.794263     0.829419    -0.471260
# 108745          1614646535958175    -0.718090     0.703197    -0.507149
# 108746          1614646535974174    -0.665599     0.661936    -0.543038
# 108747          1614646535990173    -0.660716     0.684764    -0.533272
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          20.538643      6.256199    -47.882811  Forward and backward step
# 1          17.120623     10.528725    -41.596094  Forward and backward step
# 2          14.984360     11.139086    -38.727398  Forward and backward step
# 3          14.801251      9.063859    -35.492485  Forward and backward step
# 4          19.073777      5.096513    -29.694057  Forward and backward step
# ...              ...           ...           ...                        ...
# 108743    -29.816129     54.169528     -4.608225        Punch_down_Up_Hooks
# 108744    -51.728084     56.427863     -1.434348        Punch_down_Up_Hooks
# 108745    -65.827420     54.718853    -17.242695        Punch_down_Up_Hooks
# 108746    -56.549935     48.798352    -33.722438        Punch_down_Up_Hooks
# 108747    -30.243381     38.971542    -44.647898        Punch_down_Up_Hooks
#
# [108748 rows x 8 columns]

# %%
ts = inner_df['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
inner_df['Time_elapse'] = ts1.tolist()

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614642696013219    -0.007752     0.613474    -0.545602
# 1               1614642696029217     0.089296     0.548287    -0.474800
# 2               1614642696045216     0.175601     0.534249    -0.429877
# 3               1614642696061214     0.263127     0.519234    -0.392157
# 4               1614642696077212     0.321721     0.503609    -0.352605
# ...                          ...          ...          ...          ...
# 108743          1614646535926178    -0.923781     0.981155    -0.478096
# 108744          1614646535942176    -0.794263     0.829419    -0.471260
# 108745          1614646535958175    -0.718090     0.703197    -0.507149
# 108746          1614646535974174    -0.665599     0.661936    -0.543038
# 108747          1614646535990173    -0.660716     0.684764    -0.533272
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right  \
# 0          20.538643      6.256199    -47.882811  Forward and backward step
# 1          17.120623     10.528725    -41.596094  Forward and backward step
# 2          14.984360     11.139086    -38.727398  Forward and backward step
# 3          14.801251      9.063859    -35.492485  Forward and backward step
# 4          19.073777      5.096513    -29.694057  Forward and backward step
# ...              ...           ...           ...                        ...
# 108743    -29.816129     54.169528     -4.608225        Punch_down_Up_Hooks
# 108744    -51.728084     56.427863     -1.434348        Punch_down_Up_Hooks
# 108745    -65.827420     54.718853    -17.242695        Punch_down_Up_Hooks
# 108746    -56.549935     48.798352    -33.722438        Punch_down_Up_Hooks
# 108747    -30.243381     38.971542    -44.647898        Punch_down_Up_Hooks
#
#         Time_elapse
# 0          0.000000
# 1          0.015998
# 2          0.031997
# 3          0.047995
# 4          0.063993
# ...             ...
# 108743  3839.912959
# 108744  3839.928957
# 108745  3839.944956
# 108746  3839.960955
# 108747  3839.976954
#
# [108748 rows x 9 columns]

# %%
# inner_df.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)

# %%
# inner_df

# %%
inner_df.to_csv('sub04_hand_accel+gyro.csv', index = False)
