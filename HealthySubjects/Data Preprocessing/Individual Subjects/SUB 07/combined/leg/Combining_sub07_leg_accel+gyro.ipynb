# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('/Users/shreyasaswar/HARDataset/EXTRACTION/SUB 07/leg/cleaned/final_cleaned_leg_accel.csv-sub07')
gyro = pd.read_csv('/Users/shreyasaswar/HARDataset/EXTRACTION/SUB 07/leg/cleaned/final_cleaned_leg_gyro.csv-sub07')

# %%
accel
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                0          1614720421004891    -0.998123    -0.018494
# 1                1          1614720421020867    -1.002274    -0.028992
# 2                2          1614720421036842    -0.992874     0.017151
# 3                3          1614720421052818    -0.991409     0.027039
# 4                4          1614720421068793    -1.006424    -0.013001
# ...            ...                       ...          ...          ...
# 108596      108596          1614724259934551    -1.631312     1.161089
# 108597      108597          1614724259950527    -1.092485     1.054276
# 108598      108598          1614724259966502    -0.513008     0.960281
# 108599      108599          1614724259982478    -0.122621     0.615549
# 108600      108600          1614724259998453     0.307561     0.000793
#
#         Accel Z (g)             Activity_Label
# 0          0.114199  Forward and backward step
# 1          0.121523  Forward and backward step
# 2          0.096620  Forward and backward step
# 3          0.097597  Forward and backward step
# 4          0.101747  Forward and backward step
# ...             ...                        ...
# 108596    -0.496895        Punch_down_Up_Hooks
# 108597    -0.096986        Punch_down_Up_Hooks
# 108598     0.388861        Punch_down_Up_Hooks
# 108599     0.855299        Punch_down_Up_Hooks
# 108600     0.797681        Punch_down_Up_Hooks
#
# [108601 rows x 6 columns]

# %%
gyro
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Gyro X (°/s)  Gyro Y (°/s)  \
# 0                0          1614720421004891     -1.861601     -1.861601
# 1                1          1614720421020867     -1.861601     -2.532998
# 2                2          1614720421036842      0.640879     -3.143359
# 3                3          1614720421052818     -0.946059     -3.570611
# 4                4          1614720421068793     -4.180972     -3.936828
# ...            ...                       ...           ...           ...
# 108596      108596          1614724259934551     10.772869   -128.999771
# 108597      108597          1614724259950527     -9.369039   -147.188525
# 108598      108598          1614724259966502    -21.454185   -155.367361
# 108599      108599          1614724259982478    -40.741588   -168.062867
# 108600      108600          1614724259998453   -116.060121   -138.765545
#
#         Gyro Z (°/s)             Activity_Label
# 0          -1.739528  Forward and backward step
# 1          -1.739528  Forward and backward step
# 2          -1.861601  Forward and backward step
# 3          -1.617456  Forward and backward step
# 4          -1.922637  Forward and backward step
# ...              ...                        ...
# 108596     34.882124        Punch_down_Up_Hooks
# 108597     39.948119        Punch_down_Up_Hooks
# 108598     59.357595        Punch_down_Up_Hooks
# 108599     99.580377        Punch_down_Up_Hooks
# 108600    149.691005        Punch_down_Up_Hooks
#
# [108601 rows x 6 columns]

# %%
inner_df = accel.join(gyro.set_index('Timestamp (microseconds)'), on='Timestamp (microseconds)', how='inner', lsuffix='_left', rsuffix='_right')

# %%
inner_df
# Out:
#         Unnamed: 0_left  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                     0          1614720421004891    -0.998123    -0.018494
# 1                     1          1614720421020867    -1.002274    -0.028992
# 2                     2          1614720421036842    -0.992874     0.017151
# 3                     3          1614720421052818    -0.991409     0.027039
# 4                     4          1614720421068793    -1.006424    -0.013001
# ...                 ...                       ...          ...          ...
# 108596           108596          1614724259934551    -1.631312     1.161089
# 108597           108597          1614724259950527    -1.092485     1.054276
# 108598           108598          1614724259966502    -0.513008     0.960281
# 108599           108599          1614724259982478    -0.122621     0.615549
# 108600           108600          1614724259998453     0.307561     0.000793
#
#         Accel Z (g)        Activity_Label_left  Unnamed: 0_right  \
# 0          0.114199  Forward and backward step                 0
# 1          0.121523  Forward and backward step                 1
# 2          0.096620  Forward and backward step                 2
# 3          0.097597  Forward and backward step                 3
# 4          0.101747  Forward and backward step                 4
# ...             ...                        ...               ...
# 108596    -0.496895        Punch_down_Up_Hooks            108596
# 108597    -0.096986        Punch_down_Up_Hooks            108597
# 108598     0.388861        Punch_down_Up_Hooks            108598
# 108599     0.855299        Punch_down_Up_Hooks            108599
# 108600     0.797681        Punch_down_Up_Hooks            108600
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          -1.861601     -1.861601     -1.739528  Forward and backward step
# 1          -1.861601     -2.532998     -1.739528  Forward and backward step
# 2           0.640879     -3.143359     -1.861601  Forward and backward step
# 3          -0.946059     -3.570611     -1.617456  Forward and backward step
# 4          -4.180972     -3.936828     -1.922637  Forward and backward step
# ...              ...           ...           ...                        ...
# 108596     10.772869   -128.999771     34.882124        Punch_down_Up_Hooks
# 108597     -9.369039   -147.188525     39.948119        Punch_down_Up_Hooks
# 108598    -21.454185   -155.367361     59.357595        Punch_down_Up_Hooks
# 108599    -40.741588   -168.062867     99.580377        Punch_down_Up_Hooks
# 108600   -116.060121   -138.765545    149.691005        Punch_down_Up_Hooks
#
# [108601 rows x 11 columns]

# %%
inner_df.drop(['Activity_Label_left','Unnamed: 0_left','Unnamed: 0_right'], axis=1, inplace=True)

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614720421004891    -0.998123    -0.018494     0.114199
# 1               1614720421020867    -1.002274    -0.028992     0.121523
# 2               1614720421036842    -0.992874     0.017151     0.096620
# 3               1614720421052818    -0.991409     0.027039     0.097597
# 4               1614720421068793    -1.006424    -0.013001     0.101747
# ...                          ...          ...          ...          ...
# 108596          1614724259934551    -1.631312     1.161089    -0.496895
# 108597          1614724259950527    -1.092485     1.054276    -0.096986
# 108598          1614724259966502    -0.513008     0.960281     0.388861
# 108599          1614724259982478    -0.122621     0.615549     0.855299
# 108600          1614724259998453     0.307561     0.000793     0.797681
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          -1.861601     -1.861601     -1.739528  Forward and backward step
# 1          -1.861601     -2.532998     -1.739528  Forward and backward step
# 2           0.640879     -3.143359     -1.861601  Forward and backward step
# 3          -0.946059     -3.570611     -1.617456  Forward and backward step
# 4          -4.180972     -3.936828     -1.922637  Forward and backward step
# ...              ...           ...           ...                        ...
# 108596     10.772869   -128.999771     34.882124        Punch_down_Up_Hooks
# 108597     -9.369039   -147.188525     39.948119        Punch_down_Up_Hooks
# 108598    -21.454185   -155.367361     59.357595        Punch_down_Up_Hooks
# 108599    -40.741588   -168.062867     99.580377        Punch_down_Up_Hooks
# 108600   -116.060121   -138.765545    149.691005        Punch_down_Up_Hooks
#
# [108601 rows x 8 columns]

# %%
ts = inner_df['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
inner_df['Time_elapse'] = ts1.tolist()

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614720421004891    -0.998123    -0.018494     0.114199
# 1               1614720421020867    -1.002274    -0.028992     0.121523
# 2               1614720421036842    -0.992874     0.017151     0.096620
# 3               1614720421052818    -0.991409     0.027039     0.097597
# 4               1614720421068793    -1.006424    -0.013001     0.101747
# ...                          ...          ...          ...          ...
# 108596          1614724259934551    -1.631312     1.161089    -0.496895
# 108597          1614724259950527    -1.092485     1.054276    -0.096986
# 108598          1614724259966502    -0.513008     0.960281     0.388861
# 108599          1614724259982478    -0.122621     0.615549     0.855299
# 108600          1614724259998453     0.307561     0.000793     0.797681
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right  \
# 0          -1.861601     -1.861601     -1.739528  Forward and backward step
# 1          -1.861601     -2.532998     -1.739528  Forward and backward step
# 2           0.640879     -3.143359     -1.861601  Forward and backward step
# 3          -0.946059     -3.570611     -1.617456  Forward and backward step
# 4          -4.180972     -3.936828     -1.922637  Forward and backward step
# ...              ...           ...           ...                        ...
# 108596     10.772869   -128.999771     34.882124        Punch_down_Up_Hooks
# 108597     -9.369039   -147.188525     39.948119        Punch_down_Up_Hooks
# 108598    -21.454185   -155.367361     59.357595        Punch_down_Up_Hooks
# 108599    -40.741588   -168.062867     99.580377        Punch_down_Up_Hooks
# 108600   -116.060121   -138.765545    149.691005        Punch_down_Up_Hooks
#
#         Time_elapse
# 0          0.000000
# 1          0.015976
# 2          0.031951
# 3          0.047927
# 4          0.063902
# ...             ...
# 108596  3838.929660
# 108597  3838.945636
# 108598  3838.961611
# 108599  3838.977587
# 108600  3838.993562
#
# [108601 rows x 9 columns]

# %%
# inner_df.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)

# %%
# inner_df

# %%
inner_df.to_csv('sub07_leg_accel+gyro.csv', index = False)
