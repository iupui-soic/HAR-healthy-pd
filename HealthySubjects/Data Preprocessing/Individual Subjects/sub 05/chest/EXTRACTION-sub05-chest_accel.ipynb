# %%
from datetime import datetime
import time
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv('chest_accel.csv-sub05')

# %%
df1
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)
# 0               1614642548795410    -0.087343     0.849683     0.447822
# 1               1614642548827403    -0.173770     0.880446     0.497627
# 2               1614642548859397    -0.216251     0.940017     0.502998
# 3               1614642548891390    -0.290471     1.048905     0.531319
# 4               1614642548923383    -0.226993     0.904372     0.430732
# ...                          ...          ...          ...          ...
# 127195          1614646614370397    -0.310002    -0.351019    -0.880812
# 127196          1614646614402406    -0.557565    -0.426215    -0.619089
# 127197          1614646614434416    -0.352972    -0.303655    -0.793896
# 127198          1614646614466426    -0.539986    -0.674266    -0.879835
# 127199          1614646614498435    -0.447700    -0.294865    -0.779248
#
# [127200 rows x 4 columns]

# %%
pd.Timestamp(df1['Timestamp (microseconds)'][0], unit='us')
# Out:
# Timestamp('2021-03-01 23:49:08.795410')

# %%
start = pd.Timestamp(year=2021, month=3, day=1, hour=23, minute=51, second=36)
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year=2021, month=3, day=1, hour=23, minute=52, second=36)
end_ts = int(end.timestamp() * 1e6)

DF1 = df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF1['Activity_Label'] = 'Forward and backward step'
DF1
# Out:
# <ipython-input-5-e9561541a177>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF1['Activity_Label'] = 'Forward and backward step'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 4605          1614642696005627     0.012757     0.305730     0.078187
# 4606          1614642696037588    -0.088808     0.727611     0.098207
# 4607          1614642696069548    -0.253849     1.064530     0.478584
# 4608          1614642696101509    -0.287053     0.930739     0.657298
# 4609          1614642696133469     0.204654     0.250065     0.299870
# ...                        ...          ...          ...          ...
# 6478          1614642755860478    -0.114199     0.988846     0.480049
# 6479          1614642755892433    -0.159121     0.865797     0.414618
# 6480          1614642755924347    -0.120546     0.771557     0.427802
# 6481          1614642755956302    -0.084901     0.817945     0.393133
# 6482          1614642755988257    -0.080995     0.820386     0.401923
#
#                  Activity_Label
# 4605  Forward and backward step
# 4606  Forward and backward step
# 4607  Forward and backward step
# 4608  Forward and backward step
# 4609  Forward and backward step
# ...                         ...
# 6478  Forward and backward step
# 6479  Forward and backward step
# 6480  Forward and backward step
# 6481  Forward and backward step
# 6482  Forward and backward step
#
# [1878 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=1, hour=23, minute=52, second=48)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=1, hour=23, minute=53, second=48)
end_ts=int(end.timestamp() * 1e6)

DF2= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF2['Activity_Label']='Sideward step'
DF2
# Out:
# <ipython-input-6-25854c32d455>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF2['Activity_Label']='Sideward step'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 6858          1614642768003317    -0.569284     1.681727     0.756420
# 6859          1614642768035271    -0.927199     1.386801     0.530831
# 6860          1614642768067226    -0.258244    -0.340764    -1.132769
# 6861          1614642768099181     1.037186    -0.275334    -1.740200
# 6862          1614642768131136     0.452216     1.211017     0.854078
# ...                        ...          ...          ...          ...
# 8732          1614642827868314    -0.204044     1.638270     0.193423
# 8733          1614642827900253     0.317449     1.393149     0.091371
# 8734          1614642827932192     0.400946     1.509850    -0.091737
# 8735          1614642827964131     0.050355     1.325277     0.641672
# 8736          1614642827996070    -0.447211     0.726146     0.669993
#
#      Activity_Label
# 6858  Sideward step
# 6859  Sideward step
# 6860  Sideward step
# 6861  Sideward step
# 6862  Sideward step
# ...             ...
# 8732  Sideward step
# 8733  Sideward step
# 8734  Sideward step
# 8735  Sideward step
# 8736  Sideward step
#
# [1879 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=1, hour=23, minute=54, second=53)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=1, hour=23, minute=55, second=53)
end_ts=int(end.timestamp() * 1e6)

DF3= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF3['Activity_Label']='Pushups'
DF3
# Out:
# <ipython-input-7-9aa91ac6d6ce>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF3['Activity_Label']='Pushups'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 10772          1614642893028091     0.217350     0.572824    -1.000931
# 10773          1614642893060032     0.153384     0.441962    -0.813916
# 10774          1614642893091972     0.128969     0.412665    -0.914015
# 10775          1614642893123912     0.466865     0.580148    -1.051713
# 10776          1614642893155853     0.093324     0.316960    -0.999466
# ...                         ...          ...          ...          ...
# 12645          1614642952852160    -0.602487     0.805249    -0.447700
# 12646          1614642952884103    -0.648875     1.065507    -1.074662
# 12647          1614642952916047    -0.108339     0.993729    -0.987747
# 12648          1614642952947990     0.158267     0.652415    -0.515572
# 12649          1614642952979933     0.067445     0.810132    -0.662547
#
#       Activity_Label
# 10772        Pushups
# 10773        Pushups
# 10774        Pushups
# 10775        Pushups
# 10776        Pushups
# ...              ...
# 12645        Pushups
# 12646        Pushups
# 12647        Pushups
# 12648        Pushups
# 12649        Pushups
#
# [1878 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=1, hour=23, minute=56, second=39)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=1, hour=23, minute=57, second=39)
end_ts=int(end.timestamp() * 1e6)

DF4= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF4['Activity_Label']='Hip raise step with punches in the air'
DF4
# Out:
# <ipython-input-8-d2f7630bf61a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF4['Activity_Label']='Hip raise step with punches in the air'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 14090          1614642999019846    -0.202579    -0.138125     0.855543
# 14091          1614642999051798    -0.155215    -0.241642     0.822339
# 14092          1614642999083751    -0.236759    -0.281682     0.972244
# 14093          1614642999115704    -0.101503    -0.448676     0.943923
# 14094          1614642999147657    -0.211368    -0.477974     1.046464
# ...                         ...          ...          ...          ...
# 15963          1614643058866510     0.200748    -0.519478     0.943923
# 15964          1614643058898460     0.242741    -0.521431     0.851148
# 15965          1614643058930410     0.148013    -0.503365     0.942947
# 15966          1614643058962360     0.112856    -0.511177     0.851637
# 15967          1614643058994310     0.006409    -0.475532     0.944900
#
#                                Activity_Label
# 14090  Hip raise step with punches in the air
# 14091  Hip raise step with punches in the air
# 14092  Hip raise step with punches in the air
# 14093  Hip raise step with punches in the air
# 14094  Hip raise step with punches in the air
# ...                                       ...
# 15963  Hip raise step with punches in the air
# 15964  Hip raise step with punches in the air
# 15965  Hip raise step with punches in the air
# 15966  Hip raise step with punches in the air
# 15967  Hip raise step with punches in the air
#
# [1878 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=1, hour=23, minute=58, second=58)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=1, hour=23, minute=59, second=58)
end_ts=int(end.timestamp() * 1e6)

DF5= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF5['Activity_Label']='Front and back scooter'
DF5
# Out:
# <ipython-input-9-2a715700a61f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF5['Activity_Label']='Front and back scooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 18441          1614643138019577    -0.170840     0.693431     0.312566
# 18442          1614643138051514    -0.089296     0.573800     0.256413
# 18443          1614643138083451    -0.164492     0.752026     0.203677
# 18444          1614643138115388    -0.017029     0.969802     0.199283
# 18445          1614643138147326     0.027405     1.263264     0.463935
# ...                         ...          ...          ...          ...
# 20315          1614643197845500    -0.080507     0.877516     0.468330
# 20316          1614643197877414    -0.075624     1.034257     0.461006
# 20317          1614643197909329    -0.072694     0.856519     0.214908
# 20318          1614643197941244    -0.215763     1.261311     0.034730
# 20319          1614643197973158     0.209049     0.648997    -0.231388
#
#                Activity_Label
# 18441  Front and back scooter
# 18442  Front and back scooter
# 18443  Front and back scooter
# 18444  Front and back scooter
# 18445  Front and back scooter
# ...                       ...
# 20315  Front and back scooter
# 20316  Front and back scooter
# 20317  Front and back scooter
# 20318  Front and back scooter
# 20319  Front and back scooter
#
# [1879 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=2, second=25)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=3, second=25)
end_ts=int(end.timestamp() * 1e6)

DF6= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF6['Activity_Label']='Belly Scooter'
DF6
# Out:
# <ipython-input-10-5b4fd6879356>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF6['Activity_Label']='Belly Scooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 24925          1614643345031125     0.192935     0.685130    -0.789990
# 24926          1614643345063070     0.102113     0.632883    -0.688426
# 24927          1614643345095015    -0.022400     0.651438    -0.932082
# 24928          1614643345126960    -0.063416     0.693431    -0.575143
# 24929          1614643345158906    -0.129335     0.778393    -0.734325
# ...                         ...          ...          ...          ...
# 26797          1614643404847832     0.173404     0.620188    -0.877882
# 26798          1614643404879789     0.473701     0.356512    -0.858350
# 26799          1614643404911746     0.364324     0.291569    -0.848096
# 26800          1614643404943725     0.362371     0.394598    -0.733349
# 26801          1614643404975682     0.255924     0.398993    -0.856397
#
#       Activity_Label
# 24925  Belly Scooter
# 24926  Belly Scooter
# 24927  Belly Scooter
# 24928  Belly Scooter
# 24929  Belly Scooter
# ...              ...
# 26797  Belly Scooter
# 26798  Belly Scooter
# 26799  Belly Scooter
# 26800  Belly Scooter
# 26801  Belly Scooter
#
# [1877 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=3, second=45)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=4, second=45)
end_ts=int(end.timestamp() * 1e6)

DF7= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF7['Activity_Label']='Circular Scooter'
DF7
# Out:
# <ipython-input-11-14cc1c1edf38>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF7['Activity_Label']='Circular Scooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 27428          1614643425010873    -0.342229     1.162188    -1.326131
# 27429          1614643425042827     0.191470     0.514717    -0.918898
# 27430          1614643425074780    -0.376898     1.661707    -0.046815
# 27431          1614643425106733     0.526436    -0.773388    -0.884718
# 27432          1614643425138687    -0.002380     0.793042    -0.685008
# ...                         ...          ...          ...          ...
# 29301          1614643484840713     0.145571     0.566476    -0.863233
# 29302          1614643484872650    -0.028260     0.566964    -0.606394
# 29303          1614643484904586    -0.164004     0.565988    -0.696727
# 29304          1614643484936523     0.078187     0.615793    -0.894972
# 29305          1614643484968460     0.035706     0.659739    -0.772412
#
#          Activity_Label
# 27428  Circular Scooter
# 27429  Circular Scooter
# 27430  Circular Scooter
# 27431  Circular Scooter
# 27432  Circular Scooter
# ...                 ...
# 29301  Circular Scooter
# 29302  Circular Scooter
# 29303  Circular Scooter
# 29304  Circular Scooter
# 29305  Circular Scooter
#
# [1878 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=6, second=58)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=7, second=58)
end_ts=int(end.timestamp() * 1e6)

DF8= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF8['Activity_Label']='Cycling Slow'
DF8
# Out:
# <ipython-input-12-81eeea766c0c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF8['Activity_Label']='Cycling Slow'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 33470          1614643618007527    -0.154238     0.913161    -0.098573
# 33471          1614643618039476    -0.130800     0.973220    -0.085878
# 33472          1614643618071426    -0.085878     1.042069    -0.094667
# 33473          1614643618103376    -0.145937     0.940017    -0.077577
# 33474          1614643618135325    -0.188418     0.889723    -0.075135
# ...                         ...          ...          ...          ...
# 35343          1614643677856132    -0.060487     1.039628    -0.092226
# 35344          1614643677888092     0.026429     1.013748    -0.055116
# 35345          1614643677920051    -0.083436     0.981033     0.158267
# 35346          1614643677952011    -0.088319     1.158282    -0.312444
# 35347          1614643677983970     0.083070     0.989334    -0.513619
#
#       Activity_Label
# 33470   Cycling Slow
# 33471   Cycling Slow
# 33472   Cycling Slow
# 33473   Cycling Slow
# 33474   Cycling Slow
# ...              ...
# 35343   Cycling Slow
# 35344   Cycling Slow
# 35345   Cycling Slow
# 35346   Cycling Slow
# 35347   Cycling Slow
#
# [1878 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=7, second=59)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=8, second=59)
end_ts=int(end.timestamp() * 1e6)

DF9= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF9['Activity_Label']='Cycling Fast'
DF9
# Out:
# <ipython-input-13-e864ea10ed90>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF9['Activity_Label']='Cycling Fast'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 35379          1614643679006745     0.009827     0.983963    -0.155215
# 35380          1614643679038705     0.057679     1.002518    -0.165957
# 35381          1614643679070665     0.034730     1.001053    -0.150820
# 35382          1614643679102625     0.020081     0.948318    -0.145449
# 35383          1614643679134585     0.062074     0.922438    -0.210880
# ...                         ...          ...          ...          ...
# 37251          1614643738856641     0.156313     1.030838    -0.377386
# 37252          1614643738888616     0.130922     0.898512    -0.268986
# 37253          1614643738920591     0.086000     0.706126    -0.265080
# 37254          1614643738952567     0.091371     0.712963    -0.540475
# 37255          1614643738984542     0.113344     0.890700    -0.724071
#
#       Activity_Label
# 35379   Cycling Fast
# 35380   Cycling Fast
# 35381   Cycling Fast
# 35382   Cycling Fast
# 35383   Cycling Fast
# ...              ...
# 37251   Cycling Fast
# 37252   Cycling Fast
# 37253   Cycling Fast
# 37254   Cycling Fast
# 37255   Cycling Fast
#
# [1877 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=10, second=43)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=11, second=43)
end_ts=int(end.timestamp() * 1e6)

DF10= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF10['Activity_Label']='Medicine_ball'
DF10
# Out:
# <ipython-input-14-185538fb6733>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF10['Activity_Label']='Medicine_ball'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 40510          1614643843007901     0.161685     0.921462     0.322332
# 40511          1614643843039847     0.086488     0.896559     0.359442
# 40512          1614643843071792     0.121645     0.735424     0.369207
# 40513          1614643843103738     0.225162     0.848219     0.304753
# 40514          1614643843135684     0.213443     0.982010     0.409247
# ...                         ...          ...          ...          ...
# 42384          1614643902847061     0.434150     0.707103     0.456123
# 42385          1614643902878988     0.433173     0.810132     0.398505
# 42386          1614643902910915     0.339422     0.795483     0.430732
# 42387          1614643902942842     0.409735     0.816480     0.442939
# 42388          1614643902974769     0.379950     0.812085     0.389227
#
#       Activity_Label
# 40510  Medicine_ball
# 40511  Medicine_ball
# 40512  Medicine_ball
# 40513  Medicine_ball
# 40514  Medicine_ball
# ...              ...
# 42384  Medicine_ball
# 42385  Medicine_ball
# 42386  Medicine_ball
# 42387  Medicine_ball
# 42388  Medicine_ball
#
# [1879 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=11, second=53)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=12, second=53)
end_ts=int(end.timestamp() * 1e6)

DF11= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF11['Activity_Label']='Medicine ball with burpies'
DF11
# Out:
# <ipython-input-16-4896ff752642>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF11['Activity_Label']='Medicine ball with burpies'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 42702          1614643913000758     0.646067     0.019593    -0.820264
# 42703          1614643913032687     0.848219    -0.028260    -0.568795
# 42704          1614643913064617     0.523507     0.176333    -0.733349
# 42705          1614643913096546     0.767651     0.953201    -0.941848
# 42706          1614643913128476     0.686107     0.312566    -0.716258
# ...                         ...          ...          ...          ...
# 44575          1614643972860285     0.816480    -0.719677    -0.795361
# 44576          1614643972892265     0.318425     0.224674    -0.794385
# 44577          1614643972924245     0.773022    -0.280217    -0.727977
# 44578          1614643972956225     0.539620    -0.439399    -0.953567
# 44579          1614643972988205     0.893141    -0.143008    -0.550729
#
#                    Activity_Label
# 42702  Medicine ball with burpies
# 42703  Medicine ball with burpies
# 42704  Medicine ball with burpies
# 42705  Medicine ball with burpies
# 42706  Medicine ball with burpies
# ...                           ...
# 44575  Medicine ball with burpies
# 44576  Medicine ball with burpies
# 44577  Medicine ball with burpies
# 44578  Medicine ball with burpies
# 44579  Medicine ball with burpies
#
# [1878 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=17, second=20)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=18, second=20)
end_ts=int(end.timestamp() * 1e6)

DF12= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF12['Activity_Label']='punch ball'
DF12
# Out:
# <ipython-input-18-8c2dcfc459b6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF12['Activity_Label']='punch ball'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 52898          1614644240003250    -0.066346     0.980545     0.269108
# 52899          1614644240035316    -0.073671     0.945388     0.257877
# 52900          1614644240067382    -0.082948     0.957595     0.269108
# 52901          1614644240099449    -0.119570     0.956130     0.276432
# 52902          1614644240131515    -0.133730     0.950271     0.283268
# ...                         ...          ...          ...          ...
# 54766          1614644299846722    -0.456977    -0.167422    -0.854444
# 54767          1614644299878742    -0.151308     0.070863    -1.008743
# 54768          1614644299910762     0.110414     0.261784    -1.015091
# 54769          1614644299942783     0.178286     0.310613    -0.843702
# 54770          1614644299974803     0.367742     0.149966    -0.710887
#
#       Activity_Label
# 52898     punch ball
# 52899     punch ball
# 52900     punch ball
# 52901     punch ball
# 52902     punch ball
# ...              ...
# 54766     punch ball
# 54767     punch ball
# 54768     punch ball
# 54769     punch ball
# 54770     punch ball
#
# [1873 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=19, second=13)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=20, second=13)
end_ts=int(end.timestamp() * 1e6)

DF13= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF13['Activity_Label']='Squarts Toe ups'
DF13
# Out:
# <ipython-input-19-fd04f2203726>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF13['Activity_Label']='Squarts Toe ups'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 56427          1614644353028047     0.105043     1.284260    -0.386175
# 56428          1614644353060066    -0.090272     1.215900    -0.093690
# 56429          1614644353092085     0.089906     0.924392    -0.025818
# 56430          1614644353124103     0.205142     0.837964    -0.643992
# 56431          1614644353156122     0.118227     0.881422    -0.491157
# ...                         ...          ...          ...          ...
# 58296          1614644412854896     0.233463     1.003006    -0.822705
# 58297          1614644412886900     0.272038     1.145098    -0.818799
# 58298          1614644412918904     0.177310     1.126543    -0.718700
# 58299          1614644412950908     0.158755     1.193927    -0.699657
# 58300          1614644412982912     0.158267     1.316976    -0.689891
#
#         Activity_Label
# 56427  Squarts Toe ups
# 56428  Squarts Toe ups
# 56429  Squarts Toe ups
# 56430  Squarts Toe ups
# 56431  Squarts Toe ups
# ...                ...
# 58296  Squarts Toe ups
# 58297  Squarts Toe ups
# 58298  Squarts Toe ups
# 58299  Squarts Toe ups
# 58300  Squarts Toe ups
#
# [1874 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=20, second=55)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=21, second=55)
end_ts=int(end.timestamp() * 1e6)

DF14= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF14['Activity_Label']='Weight lifts'
DF14
# Out:
# <ipython-input-20-950049b5159c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF14['Activity_Label']='Weight lifts'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 59614          1614644455025903     0.058167     0.752026    -0.178164
# 59615          1614644455057896     0.098695     0.738354    -0.279728
# 59616          1614644455089889     0.078187     0.729564    -0.350042
# 59617          1614644455121882     0.058656     0.675853    -0.405707
# 59618          1614644455153875     0.104555     0.673899    -0.471626
# ...                         ...          ...          ...          ...
# 61485          1614644514861865    -0.139590     0.887770     0.433661
# 61486          1614644514893839    -0.133730     0.932204     0.420966
# 61487          1614644514925812    -0.116152     0.903883     0.378485
# 61488          1614644514957786    -0.135683     0.956619     0.373114
# 61489          1614644514989760    -0.125429     0.899001     0.361883
#
#       Activity_Label
# 59614   Weight lifts
# 59615   Weight lifts
# 59616   Weight lifts
# 59617   Weight lifts
# 59618   Weight lifts
# ...              ...
# 61485   Weight lifts
# 61486   Weight lifts
# 61487   Weight lifts
# 61488   Weight lifts
# 61489   Weight lifts
#
# [1876 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=22, second=49)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=23, second=49)
end_ts=int(end.timestamp() * 1e6)

DF15= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF15['Activity_Label']='Heavy Weight lifts'
DF15
# Out:
# <ipython-input-21-18773cd91355>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF15['Activity_Label']='Heavy Weight lifts'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 63179          1614644569021904    -0.121523     1.049393     0.205631
# 63180          1614644569053877    -0.105409     0.958083     0.240787
# 63181          1614644569085849    -0.079042     0.951736     0.232486
# 63182          1614644569117821    -0.090761     0.981521     0.271061
# 63183          1614644569149794    -0.091249     0.968826     0.256901
# ...                         ...          ...          ...          ...
# 65050          1614644628845114     0.046448     0.990311     0.107485
# 65051          1614644628877087     0.038148     1.001053     0.112856
# 65052          1614644628909059     0.032288     0.989822     0.120668
# 65053          1614644628941032     0.029358     0.994217     0.117739
# 65054          1614644628973004     0.034730     0.988357     0.127016
#
#            Activity_Label
# 63179  Heavy Weight lifts
# 63180  Heavy Weight lifts
# 63181  Heavy Weight lifts
# 63182  Heavy Weight lifts
# 63183  Heavy Weight lifts
# ...                   ...
# 65050  Heavy Weight lifts
# 65051  Heavy Weight lifts
# 65052  Heavy Weight lifts
# 65053  Heavy Weight lifts
# 65054  Heavy Weight lifts
#
# [1876 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=24, second=45)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=25, second=45)
end_ts=int(end.timestamp() * 1e6)

DF16= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF16['Activity_Label']='Forward Lunges on Bosu'
DF16
# Out:
# <ipython-input-22-94083dc3f1f6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF16['Activity_Label']='Forward Lunges on Bosu'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 66807          1614644685008204     0.175845     0.825757     0.436103
# 66808          1614644685040168    -0.147402     0.971267     0.545480
# 66809          1614644685072133    -0.082460     1.090898     0.561105
# 66810          1614644685104097    -0.074647     0.864820     0.378973
# 66811          1614644685136061     0.013245     0.819409     0.391180
# ...                         ...          ...          ...          ...
# 68679          1614644744860079     0.214420     0.848219    -0.329534
# 68680          1614644744892151     0.154849     1.029374    -0.337346
# 68681          1614644744924127    -0.054627     0.973709    -0.107362
# 68682          1614644744956104     0.059632     0.793530    -0.231876
# 68683          1614644744988081     0.316472     0.801831    -0.582467
#
#                Activity_Label
# 66807  Forward Lunges on Bosu
# 66808  Forward Lunges on Bosu
# 66809  Forward Lunges on Bosu
# 66810  Forward Lunges on Bosu
# 66811  Forward Lunges on Bosu
# ...                       ...
# 68679  Forward Lunges on Bosu
# 68680  Forward Lunges on Bosu
# 68681  Forward Lunges on Bosu
# 68682  Forward Lunges on Bosu
# 68683  Forward Lunges on Bosu
#
# [1877 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=26, second=48)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=27, second=48)
end_ts=int(end.timestamp() * 1e6)

DF17= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF17['Activity_Label']='Split squart left on Bosu'
DF17
# Out:
# <ipython-input-23-62080580c548>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF17['Activity_Label']='Split squart left on Bosu'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 70654          1614644808008324    -0.088808     0.886793     0.270573
# 70655          1614644808040291    -0.065370     0.856031     0.207095
# 70656          1614644808072258    -0.074647     0.857008     0.185122
# 70657          1614644808104224    -0.032166     0.845777     0.158755
# 70658          1614644808136191    -0.035096     0.854078     0.140688
# ...                         ...          ...          ...          ...
# 72526          1614644867842165     0.138735     0.984451     0.204166
# 72527          1614644867874127     0.147036     0.968826     0.239811
# 72528          1614644867906089     0.125063     0.960525     0.267155
# 72529          1614644867938052     0.136782     0.962478     0.302312
# 72530          1614644867970014     0.149966     0.906813     0.303777
#
#                   Activity_Label
# 70654  Split squart left on Bosu
# 70655  Split squart left on Bosu
# 70656  Split squart left on Bosu
# 70657  Split squart left on Bosu
# 70658  Split squart left on Bosu
# ...                          ...
# 72526  Split squart left on Bosu
# 72527  Split squart left on Bosu
# 72528  Split squart left on Bosu
# 72529  Split squart left on Bosu
# 72530  Split squart left on Bosu
#
# [1877 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=28, second=0)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=29, second=0)
end_ts=int(end.timestamp() * 1e6)

DF18= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF18['Activity_Label']='Split squart right on Bosu'
DF18
# Out:
# <ipython-input-24-bdbb8cdde35b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF18['Activity_Label']='Split squart right on Bosu'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 72907          1614644880019466    -0.134218     0.949783     0.240299
# 72908          1614644880051427    -0.155215     1.005936     0.205142
# 72909          1614644880083389    -0.179629     0.974685     0.209537
# 72910          1614644880115351    -0.153750     1.023514     0.230533
# 72911          1614644880147313    -0.107851     0.988846     0.201236
# ...                         ...          ...          ...          ...
# 74780          1614644939871133     0.418036     1.030838    -0.977493
# 74781          1614644939903086     0.407294     0.845289    -1.090776
# 74782          1614644939935038     0.318914     0.721263    -0.967239
# 74783          1614644939966991     0.339910     0.666575    -1.001907
# 74784          1614644939998943     0.239811     0.661204    -0.945266
#
#                    Activity_Label
# 72907  Split squart right on Bosu
# 72908  Split squart right on Bosu
# 72909  Split squart right on Bosu
# 72910  Split squart right on Bosu
# 72911  Split squart right on Bosu
# ...                           ...
# 74780  Split squart right on Bosu
# 74781  Split squart right on Bosu
# 74782  Split squart right on Bosu
# 74783  Split squart right on Bosu
# 74784  Split squart right on Bosu
#
# [1878 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=30, second=32)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=31, second=32)
end_ts=int(end.timestamp() * 1e6)

DF19= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF19['Activity_Label']='plank pie on Bosu'
DF19
# Out:
# <ipython-input-25-f5483580dfe9>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF19['Activity_Label']='plank pie on Bosu'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 77665          1614645032030753     0.211490    -0.362737    -0.903761
# 77666          1614645032062688     0.153872    -0.394965    -0.893996
# 77667          1614645032094624     0.194888    -0.378851    -0.912551
# 77668          1614645032126560     0.133364    -0.437934    -0.844678
# 77669          1614645032158496     0.140200    -0.443305    -0.846632
# ...                         ...          ...          ...          ...
# 79539          1614645091857232     0.387762     0.260319    -0.962844
# 79540          1614645091889156     0.540108     0.339910    -0.964797
# 79541          1614645091921080     0.479561     0.217838    -1.004837
# 79542          1614645091953004     0.315984     0.533272    -1.046830
# 79543          1614645091984929     0.652903     0.176822    -0.985306
#
#           Activity_Label
# 77665  plank pie on Bosu
# 77666  plank pie on Bosu
# 77667  plank pie on Bosu
# 77668  plank pie on Bosu
# 77669  plank pie on Bosu
# ...                  ...
# 79539  plank pie on Bosu
# 79540  plank pie on Bosu
# 79541  plank pie on Bosu
# 79542  plank pie on Bosu
# 79543  plank pie on Bosu
#
# [1879 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=32, second=37)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=33, second=37)
end_ts=int(end.timestamp() * 1e6)

DF20= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF20['Activity_Label']='plank top on Bosu'
DF20
# Out:
# <ipython-input-26-82eaf00409de>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF20['Activity_Label']='plank top on Bosu'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 81579          1614645157003278     0.078187     0.078187    -1.030228
# 81580          1614645157035211     0.167056     0.113832    -0.975540
# 81581          1614645157067144     0.243229     0.362860    -0.966751
# 81582          1614645157099078     0.197818     0.260319    -0.718700
# 81583          1614645157131011     0.326726     0.081605    -1.020462
# ...                         ...          ...          ...          ...
# 83454          1614645216847881    -0.046815     0.972732     0.240299
# 83455          1614645216879797    -0.036561     0.964920     0.241276
# 83456          1614645216911712    -0.030213     0.967361     0.246647
# 83457          1614645216943628    -0.029236     0.957595     0.241764
# 83458          1614645216975544    -0.036561     0.973709     0.260807
#
#           Activity_Label
# 81579  plank top on Bosu
# 81580  plank top on Bosu
# 81581  plank top on Bosu
# 81582  plank top on Bosu
# 81583  plank top on Bosu
# ...                  ...
# 83454  plank top on Bosu
# 83455  plank top on Bosu
# 83456  plank top on Bosu
# 83457  plank top on Bosu
# 83458  plank top on Bosu
#
# [1880 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=34, second=57)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=35, second=57)
end_ts=int(end.timestamp() * 1e6)

DF21= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF21['Activity_Label']='dips on Bosu'
DF21
# Out:
# <ipython-input-27-f965cc1a2ab4>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF21['Activity_Label']='dips on Bosu'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 85965          1614645297015764     0.236393     0.353582    -0.877882
# 85966          1614645297047695     0.245182     0.314031    -0.894484
# 85967          1614645297079626     0.300847     0.324285    -0.963821
# 85968          1614645297111557     0.256413     0.313542    -0.957961
# 85969          1614645297143488     0.242252     0.260807    -0.895460
# ...                         ...          ...          ...          ...
# 87839          1614645356841348     0.436103     0.171939    -0.878859
# 87840          1614645356873077     0.414130     0.182193    -0.923781
# 87841          1614645356904992     0.422919     0.233463    -0.901320
# 87842          1614645356936907     0.438056     0.277409    -0.836866
# 87843          1614645356968823     0.356512     0.199283    -0.874464
#
#       Activity_Label
# 85965   dips on Bosu
# 85966   dips on Bosu
# 85967   dips on Bosu
# 85968   dips on Bosu
# 85969   dips on Bosu
# ...              ...
# 87839   dips on Bosu
# 87840   dips on Bosu
# 87841   dips on Bosu
# 87842   dips on Bosu
# 87843   dips on Bosu
#
# [1879 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=36, second=52)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=37, second=52)
end_ts=int(end.timestamp() * 1e6)

DF22= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF22['Activity_Label']='moveforward backward on Bosu'
DF22
# Out:
# <ipython-input-28-e9267ac5fbf7>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF22['Activity_Label']='moveforward backward on Bosu'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 89568          1614645412031047    -0.026795     0.827222     0.672435
# 89569          1614645412062974    -0.005798     0.807202     0.580148
# 89570          1614645412094901     0.002502     0.826734     0.618723
# 89571          1614645412126827    -0.001892     0.896559     0.614328
# 89572          1614645412158754    -0.076600     0.835035     0.626535
# ...                         ...          ...          ...          ...
# 91442          1614645471869509     0.068910    -0.092714     1.074296
# 91443          1614645471901447     0.024964    -0.072206     1.036210
# 91444          1614645471933385     0.008362    -0.030701     1.030350
# 91445          1614645471965324     0.006897     0.026917     1.025467
# 91446          1614645471997262     0.023987     0.020569     0.982986
#
#                      Activity_Label
# 89568  moveforward backward on Bosu
# 89569  moveforward backward on Bosu
# 89570  moveforward backward on Bosu
# 89571  moveforward backward on Bosu
# 89572  moveforward backward on Bosu
# ...                             ...
# 91442  moveforward backward on Bosu
# 91443  moveforward backward on Bosu
# 91444  moveforward backward on Bosu
# 91445  moveforward backward on Bosu
# 91446  moveforward backward on Bosu
#
# [1879 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=39, second=2)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=40, second=2)
end_ts=int(end.timestamp() * 1e6)

DF23= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF23['Activity_Label']='Left leg Hip ups on Bosu'
DF23
# Out:
# <ipython-input-29-eb7f55f1d151>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF23['Activity_Label']='Left leg Hip ups on Bosu'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 93638          1614645542008427    -0.156191    -0.317815     0.942947
# 93639          1614645542040367    -0.153262    -0.307561     0.907301
# 93640          1614645542072326    -0.308537    -0.396918     0.930739
# 93641          1614645542104266    -0.347601    -0.497017     0.909743
# 93642          1614645542136206    -0.086366    -0.410101     0.864332
# ...                         ...          ...          ...          ...
# 95512          1614645601852813    -0.228946    -0.320745     1.009354
# 95513          1614645601884742    -0.198184    -0.344671     0.948318
# 95514          1614645601916671    -0.205997    -0.310491     0.904860
# 95515          1614645601948600    -0.158633    -0.327092     1.014237
# 95516          1614645601980529    -0.220157    -0.367620     0.934646
#
#                  Activity_Label
# 93638  Left leg Hip ups on Bosu
# 93639  Left leg Hip ups on Bosu
# 93640  Left leg Hip ups on Bosu
# 93641  Left leg Hip ups on Bosu
# 93642  Left leg Hip ups on Bosu
# ...                         ...
# 95512  Left leg Hip ups on Bosu
# 95513  Left leg Hip ups on Bosu
# 95514  Left leg Hip ups on Bosu
# 95515  Left leg Hip ups on Bosu
# 95516  Left leg Hip ups on Bosu
#
# [1879 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=40, second=11)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=41, second=11)
end_ts=int(end.timestamp() * 1e6)

DF24= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF24['Activity_Label']='right leg Hip ups on Bosu'
DF24
# Out:
# <ipython-input-30-b2b9804ae980>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF24['Activity_Label']='right leg Hip ups on Bosu'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 95799          1614645611015573    -0.097597    -0.435492     0.917067
# 95800          1614645611047424    -0.218692    -0.485298     0.994705
# 95801          1614645611079351    -0.357366    -0.166445     0.953201
# 95802          1614645611111277    -0.379828    -0.330022     1.256916
# 95803          1614645611143204    -0.292912    -0.457465     1.028397
# ...                         ...          ...          ...          ...
# 97674          1614645670869860    -0.292424    -0.306584     0.906325
# 97675          1614645670901783    -0.303166    -0.295354     0.921462
# 97676          1614645670933706    -0.310002    -0.299748     0.942458
# 97677          1614645670965629    -0.310002    -0.300237     0.939040
# 97678          1614645670997552    -0.298772    -0.302190     0.924880
#
#                   Activity_Label
# 95799  right leg Hip ups on Bosu
# 95800  right leg Hip ups on Bosu
# 95801  right leg Hip ups on Bosu
# 95802  right leg Hip ups on Bosu
# 95803  right leg Hip ups on Bosu
# ...                          ...
# 97674  right leg Hip ups on Bosu
# 97675  right leg Hip ups on Bosu
# 97676  right leg Hip ups on Bosu
# 97677  right leg Hip ups on Bosu
# 97678  right leg Hip ups on Bosu
#
# [1880 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=43, second=2)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=44, second=2)
end_ts=int(end.timestamp() * 1e6)

DF25= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF25['Activity_Label']='V-Shift Swift on Bosu'
DF25
# Out:
# <ipython-input-31-3995fabb524f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF25['Activity_Label']='V-Shift Swift on Bosu'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 101155          1614645782002230    -0.398871     0.196353     0.967849
# 101156          1614645782034147    -0.282170     0.211002     0.953201
# 101157          1614645782066064    -0.289006     0.207095     0.958083
# 101158          1614645782097981    -0.382757     0.253483     1.032792
# 101159          1614645782129898    -0.369574     0.203677     0.975662
# ...                          ...          ...          ...          ...
# 103030          1614645841859846    -0.377386     0.595285     0.711986
# 103031          1614645841891776    -0.384222     0.588449     0.729076
# 103032          1614645841923706    -0.375433     0.581613     0.698802
# 103033          1614645841955636    -0.375433     0.576242     0.698314
# 103034          1614645841987566    -0.366644     0.566476     0.707591
#
#                Activity_Label
# 101155  V-Shift Swift on Bosu
# 101156  V-Shift Swift on Bosu
# 101157  V-Shift Swift on Bosu
# 101158  V-Shift Swift on Bosu
# 101159  V-Shift Swift on Bosu
# ...                       ...
# 103030  V-Shift Swift on Bosu
# 103031  V-Shift Swift on Bosu
# 103032  V-Shift Swift on Bosu
# 103033  V-Shift Swift on Bosu
# 103034  V-Shift Swift on Bosu
#
# [1880 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=46, second=50)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=47, second=20)
end_ts=int(end.timestamp() * 1e6)

DF26= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF26['Activity_Label']='Freestyle Boxing'
DF26
# Out:
# <ipython-input-32-ac3c15f67f9f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF26['Activity_Label']='Freestyle Boxing'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 108294          1614646010000981     0.053285     0.977127     0.285222
# 108295          1614646010032942     0.052308     0.955642     0.289128
# 108296          1614646010064903     0.039124     0.954665     0.318914
# 108297          1614646010096864     0.050843     0.926345     0.335027
# 108298          1614646010128825     0.055238     0.906813     0.331121
# ...                          ...          ...          ...          ...
# 109228          1614646039848940    -0.506294     0.650950    -0.152773
# 109229          1614646039880895    -0.820752     0.315496    -0.107851
# 109230          1614646039912850    -0.105898     0.781811    -0.166445
# 109231          1614646039944805     0.002502     1.235431    -0.134218
# 109232          1614646039976760     0.350652     1.262287    -0.207950
#
#           Activity_Label
# 108294  Freestyle Boxing
# 108295  Freestyle Boxing
# 108296  Freestyle Boxing
# 108297  Freestyle Boxing
# 108298  Freestyle Boxing
# ...                  ...
# 109228  Freestyle Boxing
# 109229  Freestyle Boxing
# 109230  Freestyle Boxing
# 109231  Freestyle Boxing
# 109232  Freestyle Boxing
#
# [939 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=47, second=55)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=48, second=25)
end_ts=int(end.timestamp() * 1e6)

DF27= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF27['Activity_Label']='Left_Right_Punches_flip'
DF27
# Out:
# <ipython-input-33-3990e029228f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF27['Activity_Label']='Left_Right_Punches_flip'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 110328          1614646075009998    -0.303166     0.830152     0.075257
# 110329          1614646075041967    -0.458442     0.921950     0.176822
# 110330          1614646075073937    -0.180117     0.842359     0.089906
# 110331          1614646075105907    -0.006287     0.808179     0.099672
# 110332          1614646075137876    -0.065370     0.660716     0.125551
# ...                          ...          ...          ...          ...
# 111262          1614646104867542     0.221256     0.620676    -0.098085
# 111263          1614646104899507    -0.090272     0.578683    -0.362249
# 111264          1614646104931472    -0.314885    -0.169863    -0.530220
# 111265          1614646104963438    -0.400336     0.961990    -0.766064
# 111266          1614646104995403    -0.115175     1.727626     0.825757
#
#                  Activity_Label
# 110328  Left_Right_Punches_flip
# 110329  Left_Right_Punches_flip
# 110330  Left_Right_Punches_flip
# 110331  Left_Right_Punches_flip
# 110332  Left_Right_Punches_flip
# ...                         ...
# 111262  Left_Right_Punches_flip
# 111263  Left_Right_Punches_flip
# 111264  Left_Right_Punches_flip
# 111265  Left_Right_Punches_flip
# 111266  Left_Right_Punches_flip
#
# [939 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=49, second=21)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=49, second=51)
end_ts=int(end.timestamp() * 1e6)

DF28= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF28['Activity_Label']='left_Right_Punch'
DF28
# Out:
# <ipython-input-34-83b28f4f9fc4>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF28['Activity_Label']='left_Right_Punch'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 113018          1614646161002950    -0.004822     0.934157     0.298405
# 113019          1614646161034920     0.062074     0.916091     0.213443
# 113020          1614646161066890     0.165591     0.933181     0.227604
# 113021          1614646161098860     0.217838     1.054276     0.303288
# 113022          1614646161130830     0.226139     1.127520     0.352605
# ...                          ...          ...          ...          ...
# 113952          1614646190861419    -0.081483     0.921462     0.666575
# 113953          1614646190893388     0.364324     1.134844     0.406806
# 113954          1614646190925357     0.475166     1.299886     0.533761
# 113955          1614646190957327     0.107485     0.883864     0.437568
# 113956          1614646190989296     0.114321     0.616770     0.314519
#
#           Activity_Label
# 113018  left_Right_Punch
# 113019  left_Right_Punch
# 113020  left_Right_Punch
# 113021  left_Right_Punch
# 113022  left_Right_Punch
# ...                  ...
# 113952  left_Right_Punch
# 113953  left_Right_Punch
# 113954  left_Right_Punch
# 113955  left_Right_Punch
# 113956  left_Right_Punch
#
# [939 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=50, second=51)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=51, second=21)
end_ts=int(end.timestamp() * 1e6)

DF29= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF29['Activity_Label']='one_twos'
DF29
# Out:
# <ipython-input-35-759ec8fe4387>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF29['Activity_Label']='one_twos'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 115833          1614646251011013    -0.054139     0.959548     0.311101
# 115834          1614646251042991    -0.042420     0.939040     0.279362
# 115835          1614646251074970    -0.052674     0.971756     0.320867
# 115836          1614646251106948    -0.029725     0.949783     0.305241
# 115837          1614646251138927    -0.044373     0.883864     0.309148
# ...                          ...          ...          ...          ...
# 116766          1614646280843543    -0.096132     1.573327    -1.201129
# 116767          1614646280875516     0.062562     0.299870    -0.312932
# 116768          1614646280907489     0.165103     0.961501    -0.350530
# 116769          1614646280939463    -0.543893     0.894606     0.746654
# 116770          1614646280971436    -1.691859     0.700755    -1.300252
#
#        Activity_Label
# 115833       one_twos
# 115834       one_twos
# 115835       one_twos
# 115836       one_twos
# 115837       one_twos
# ...               ...
# 116766       one_twos
# 116767       one_twos
# 116768       one_twos
# 116769       one_twos
# 116770       one_twos
#
# [938 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=51, second=45)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=52, second=15)
end_ts=int(end.timestamp() * 1e6)

DF30= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF30['Activity_Label']='hooks'
DF30
# Out:
# <ipython-input-37-ec76f3665bbb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF30['Activity_Label']='hooks'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 117522          1614646305015150     0.068910     1.049393     0.274968
# 117523          1614646305047124     0.057191     1.006424     0.374578
# 117524          1614646305079097    -0.039490     0.915602     0.373114
# 117525          1614646305111071    -0.041932     0.836988     0.401923
# 117526          1614646305143045    -0.002869     0.792065     0.324773
# ...                          ...          ...          ...          ...
# 118455          1614646334850369    -1.073686     0.603098     0.665110
# 118456          1614646334882347    -1.667933     0.675364     0.634836
# 118457          1614646334914325    -0.208438     0.847242    -0.134218
# 118458          1614646334946303     0.126040     1.233478    -0.323186
# 118459          1614646334978281     0.217838     1.435142    -0.443305
#
#        Activity_Label
# 117522          hooks
# 117523          hooks
# 117524          hooks
# 117525          hooks
# 117526          hooks
# ...               ...
# 118455          hooks
# 118456          hooks
# 118457          hooks
# 118458          hooks
# 118459          hooks
#
# [938 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=52, second=51)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=53, second=21)
end_ts=int(end.timestamp() * 1e6)

DF31= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF31['Activity_Label']='Upper_cuts'
DF31
# Out:
# <ipython-input-38-26154fb3a353>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF31['Activity_Label']='Upper_cuts'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 119586          1614646371017747     0.113832     1.021561    -0.047303
# 119587          1614646371049724     0.039612     0.951736     0.029358
# 119588          1614646371081701    -0.062928     0.911208     0.075746
# 119589          1614646371113678    -0.131289     0.818433     0.054749
# 119590          1614646371145655    -0.134218     0.731518     0.024964
# ...                          ...          ...          ...          ...
# 120519          1614646400850307    -0.086366     0.096742     0.295964
# 120520          1614646400882263    -0.313909     2.832136    -1.331991
# 120521          1614646400914238     1.298421     2.347265     3.610468
# 120522          1614646400946212     0.334539     1.516686     0.485420
# 120523          1614646400978187     0.062074     0.925856     0.263249
#
#        Activity_Label
# 119586     Upper_cuts
# 119587     Upper_cuts
# 119588     Upper_cuts
# 119589     Upper_cuts
# 119590     Upper_cuts
# ...               ...
# 120519     Upper_cuts
# 120520     Upper_cuts
# 120521     Upper_cuts
# 120522     Upper_cuts
# 120523     Upper_cuts
#
# [938 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=54, second=0)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=54, second=30)
end_ts=int(end.timestamp() * 1e6)

DF32= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF32['Activity_Label']='run'
DF32
# Out:
# <ipython-input-39-f3dcc3cf0331>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF32['Activity_Label']='run'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 121744          1614646440026611     0.143130     0.757885     0.369207
# 121745          1614646440058593     0.129458     0.813550     0.350652
# 121746          1614646440090576     0.083070     0.942947     0.379950
# 121747          1614646440122558    -0.049256     1.037675     0.400946
# 121748          1614646440154541    -0.097108     1.189532     0.512276
# ...                          ...          ...          ...          ...
# 122676          1614646469839939    -0.463813     0.628000     0.337469
# 122677          1614646469871930    -0.193301     0.100160    -0.223087
# 122678          1614646469903921     0.185122    -0.707469     0.191958
# 122679          1614646469935912     0.125063    -0.277775    -0.325628
# 122680          1614646469968078    -0.187930     0.437079    -0.284123
#
#        Activity_Label
# 121744            run
# 121745            run
# 121746            run
# 121747            run
# 121748            run
# ...               ...
# 122676            run
# 122677            run
# 122678            run
# 122679            run
# 122680            run
#
# [937 rows x 5 columns]

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=55, second=6)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=55, second=36)
end_ts=int(end.timestamp() * 1e6)

DF33= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF33['Activity_Label']='Punch_down_Up_Hooks'
DF33
# Out:
# <ipython-input-40-78e3e95211d3>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF33['Activity_Label']='Punch_down_Up_Hooks'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 123807          1614646506024596    -0.033143     0.727611     0.115785
# 123808          1614646506056587    -0.060975     0.885328     0.171450
# 123809          1614646506088578     0.008362     0.530343     0.122133
# 123810          1614646506120569    -0.253849     0.185611     0.133852
# 123811          1614646506152560    -0.219181    -0.194766    -0.003357
# ...                          ...          ...          ...          ...
# 124740          1614646535857946    -0.375433     1.149493    -0.104433
# 124741          1614646535889917    -0.453559     1.517174     0.246159
# 124742          1614646535921887    -0.355901     1.610925     0.162173
# 124743          1614646535953858    -0.213809     1.025956    -0.212345
# 124744          1614646535985828    -0.097597     0.521553    -0.254826
#
#              Activity_Label
# 123807  Punch_down_Up_Hooks
# 123808  Punch_down_Up_Hooks
# 123809  Punch_down_Up_Hooks
# 123810  Punch_down_Up_Hooks
# 123811  Punch_down_Up_Hooks
# ...                     ...
# 124740  Punch_down_Up_Hooks
# 124741  Punch_down_Up_Hooks
# 124742  Punch_down_Up_Hooks
# 124743  Punch_down_Up_Hooks
# 124744  Punch_down_Up_Hooks
#
# [938 rows x 5 columns]

# %%
sub05_final_chest_accel=pd.concat ([DF1,DF2, DF3, DF4, DF5, DF6, DF7, DF8, DF9, DF10, DF11, DF12, DF13, DF14, DF15, DF16, DF17, DF18, DF19, DF20, DF21, DF22, DF23, DF24, DF25, DF26, DF27, DF28, DF29, DF30, DF31, DF32, DF33], ignore_index=True)
sub05_final_chest_accel
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1614642696005627     0.012757     0.305730     0.078187
# 1              1614642696037588    -0.088808     0.727611     0.098207
# 2              1614642696069548    -0.253849     1.064530     0.478584
# 3              1614642696101509    -0.287053     0.930739     0.657298
# 4              1614642696133469     0.204654     0.250065     0.299870
# ...                         ...          ...          ...          ...
# 54447          1614646535857946    -0.375433     1.149493    -0.104433
# 54448          1614646535889917    -0.453559     1.517174     0.246159
# 54449          1614646535921887    -0.355901     1.610925     0.162173
# 54450          1614646535953858    -0.213809     1.025956    -0.212345
# 54451          1614646535985828    -0.097597     0.521553    -0.254826
#
#                   Activity_Label
# 0      Forward and backward step
# 1      Forward and backward step
# 2      Forward and backward step
# 3      Forward and backward step
# 4      Forward and backward step
# ...                          ...
# 54447        Punch_down_Up_Hooks
# 54448        Punch_down_Up_Hooks
# 54449        Punch_down_Up_Hooks
# 54450        Punch_down_Up_Hooks
# 54451        Punch_down_Up_Hooks
#
# [54452 rows x 5 columns]

# %%
sub05_final_chest_accel.to_csv('final_cleaned_chest_accel-sub05.csv-sub05')
