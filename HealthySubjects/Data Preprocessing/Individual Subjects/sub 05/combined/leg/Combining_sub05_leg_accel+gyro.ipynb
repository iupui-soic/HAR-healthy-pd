# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('final_cleaned_leg_accel-sub05.csv-sub05')
gyro = pd.read_csv('final_cleaned_leg_gyro-sub05.csv-sub05')

# %%
accel
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                0          1614642696001831    -0.611032    -0.336492
# 1                1          1614642696017807    -0.387762    -0.225284
# 2                2          1614642696033783    -0.246281    -0.099428
# 3                3          1614642696049759    -0.452338    -0.165103
# 4                4          1614642696065734    -0.955398    -0.523873
# ...            ...                       ...          ...          ...
# 108908      108908          1614646535934250    -0.482246     0.214664
# 108909      108909          1614646535950225    -0.648508     0.459663
# 108910      108910          1614646535966201    -1.682094     0.528878
# 108911      108911          1614646535982177    -3.139635     0.320623
# 108912      108912          1614646535998153    -1.671351    -1.257282
#
#         Accel Z (g)             Activity_Label
# 0          0.087221  Forward and backward step
# 1          0.149111  Forward and backward step
# 2          0.216861  Forward and backward step
# 3          0.222599  Forward and backward step
# 4          0.280827  Forward and backward step
# ...             ...                        ...
# 108908     0.488106        Punch_down_Up_Hooks
# 108909     0.551095        Punch_down_Up_Hooks
# 108910     0.269841        Punch_down_Up_Hooks
# 108911    -0.274113        Punch_down_Up_Hooks
# 108912    -0.627146        Punch_down_Up_Hooks
#
# [108913 rows x 6 columns]

# %%
gyro
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Gyro X (°/s)  Gyro Y (°/s)  \
# 0                0          1614642696001831     25.055314   -139.375906
# 1                1          1614642696017807     46.112764   -113.252461
# 2                2          1614642696033783     64.423590    -81.574731
# 3                3          1614642696049759     77.180133    -24.933242
# 4                4          1614642696065734     76.020447     50.202182
# ...            ...                       ...           ...           ...
# 108908      108908          1614646535934250   -163.485161    302.586404
# 108909      108909          1614646535950225    -83.344778    329.991608
# 108910      108910          1614646535966201   -156.954299    360.692760
# 108911      108911          1614646535982177   -354.528115    313.328756
# 108912      108912          1614646535998153   -433.142596    151.888304
#
#         Gyro Z (°/s)             Activity_Label
# 0         -39.154650  Forward and backward step
# 1         -48.065919  Forward and backward step
# 2         -45.136187  Forward and backward step
# 3         -34.271763  Forward and backward step
# 4         -36.408026  Forward and backward step
# ...              ...                        ...
# 108908    134.309911        Punch_down_Up_Hooks
# 108909    134.859236        Punch_down_Up_Hooks
# 108910    127.901122        Punch_down_Up_Hooks
# 108911     63.324941        Punch_down_Up_Hooks
# 108912     32.684825        Punch_down_Up_Hooks
#
# [108913 rows x 6 columns]

# %%
inner_df = accel.join(gyro.set_index('Timestamp (microseconds)'), on='Timestamp (microseconds)', how='inner', lsuffix='_left', rsuffix='_right')

# %%
inner_df
# Out:
#         Unnamed: 0_left  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                     0          1614642696001831    -0.611032    -0.336492
# 1                     1          1614642696017807    -0.387762    -0.225284
# 2                     2          1614642696033783    -0.246281    -0.099428
# 3                     3          1614642696049759    -0.452338    -0.165103
# 4                     4          1614642696065734    -0.955398    -0.523873
# ...                 ...                       ...          ...          ...
# 108908           108908          1614646535934250    -0.482246     0.214664
# 108909           108909          1614646535950225    -0.648508     0.459663
# 108910           108910          1614646535966201    -1.682094     0.528878
# 108911           108911          1614646535982177    -3.139635     0.320623
# 108912           108912          1614646535998153    -1.671351    -1.257282
#
#         Accel Z (g)        Activity_Label_left  Unnamed: 0_right  \
# 0          0.087221  Forward and backward step                 0
# 1          0.149111  Forward and backward step                 1
# 2          0.216861  Forward and backward step                 2
# 3          0.222599  Forward and backward step                 3
# 4          0.280827  Forward and backward step                 4
# ...             ...                        ...               ...
# 108908     0.488106        Punch_down_Up_Hooks            108908
# 108909     0.551095        Punch_down_Up_Hooks            108909
# 108910     0.269841        Punch_down_Up_Hooks            108910
# 108911    -0.274113        Punch_down_Up_Hooks            108911
# 108912    -0.627146        Punch_down_Up_Hooks            108912
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          25.055314   -139.375906    -39.154650  Forward and backward step
# 1          46.112764   -113.252461    -48.065919  Forward and backward step
# 2          64.423590    -81.574731    -45.136187  Forward and backward step
# 3          77.180133    -24.933242    -34.271763  Forward and backward step
# 4          76.020447     50.202182    -36.408026  Forward and backward step
# ...              ...           ...           ...                        ...
# 108908   -163.485161    302.586404    134.309911        Punch_down_Up_Hooks
# 108909    -83.344778    329.991608    134.859236        Punch_down_Up_Hooks
# 108910   -156.954299    360.692760    127.901122        Punch_down_Up_Hooks
# 108911   -354.528115    313.328756     63.324941        Punch_down_Up_Hooks
# 108912   -433.142596    151.888304     32.684825        Punch_down_Up_Hooks
#
# [108913 rows x 11 columns]

# %%
inner_df.drop(['Activity_Label_left','Unnamed: 0_left','Unnamed: 0_right'], axis=1, inplace=True)

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614642696001831    -0.611032    -0.336492     0.087221
# 1               1614642696017807    -0.387762    -0.225284     0.149111
# 2               1614642696033783    -0.246281    -0.099428     0.216861
# 3               1614642696049759    -0.452338    -0.165103     0.222599
# 4               1614642696065734    -0.955398    -0.523873     0.280827
# ...                          ...          ...          ...          ...
# 108908          1614646535934250    -0.482246     0.214664     0.488106
# 108909          1614646535950225    -0.648508     0.459663     0.551095
# 108910          1614646535966201    -1.682094     0.528878     0.269841
# 108911          1614646535982177    -3.139635     0.320623    -0.274113
# 108912          1614646535998153    -1.671351    -1.257282    -0.627146
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          25.055314   -139.375906    -39.154650  Forward and backward step
# 1          46.112764   -113.252461    -48.065919  Forward and backward step
# 2          64.423590    -81.574731    -45.136187  Forward and backward step
# 3          77.180133    -24.933242    -34.271763  Forward and backward step
# 4          76.020447     50.202182    -36.408026  Forward and backward step
# ...              ...           ...           ...                        ...
# 108908   -163.485161    302.586404    134.309911        Punch_down_Up_Hooks
# 108909    -83.344778    329.991608    134.859236        Punch_down_Up_Hooks
# 108910   -156.954299    360.692760    127.901122        Punch_down_Up_Hooks
# 108911   -354.528115    313.328756     63.324941        Punch_down_Up_Hooks
# 108912   -433.142596    151.888304     32.684825        Punch_down_Up_Hooks
#
# [108913 rows x 8 columns]

# %%
ts = inner_df['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
inner_df['Time_elapse'] = ts1.tolist()

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614642696001831    -0.611032    -0.336492     0.087221
# 1               1614642696017807    -0.387762    -0.225284     0.149111
# 2               1614642696033783    -0.246281    -0.099428     0.216861
# 3               1614642696049759    -0.452338    -0.165103     0.222599
# 4               1614642696065734    -0.955398    -0.523873     0.280827
# ...                          ...          ...          ...          ...
# 108908          1614646535934250    -0.482246     0.214664     0.488106
# 108909          1614646535950225    -0.648508     0.459663     0.551095
# 108910          1614646535966201    -1.682094     0.528878     0.269841
# 108911          1614646535982177    -3.139635     0.320623    -0.274113
# 108912          1614646535998153    -1.671351    -1.257282    -0.627146
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right  \
# 0          25.055314   -139.375906    -39.154650  Forward and backward step
# 1          46.112764   -113.252461    -48.065919  Forward and backward step
# 2          64.423590    -81.574731    -45.136187  Forward and backward step
# 3          77.180133    -24.933242    -34.271763  Forward and backward step
# 4          76.020447     50.202182    -36.408026  Forward and backward step
# ...              ...           ...           ...                        ...
# 108908   -163.485161    302.586404    134.309911        Punch_down_Up_Hooks
# 108909    -83.344778    329.991608    134.859236        Punch_down_Up_Hooks
# 108910   -156.954299    360.692760    127.901122        Punch_down_Up_Hooks
# 108911   -354.528115    313.328756     63.324941        Punch_down_Up_Hooks
# 108912   -433.142596    151.888304     32.684825        Punch_down_Up_Hooks
#
#         Time_elapse
# 0          0.000000
# 1          0.015976
# 2          0.031952
# 3          0.047928
# 4          0.063903
# ...             ...
# 108908  3839.932419
# 108909  3839.948394
# 108910  3839.964370
# 108911  3839.980346
# 108912  3839.996322
#
# [108913 rows x 9 columns]

# %%
# inner_df.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)

# %%
# inner_df

# %%
inner_df.to_csv('sub05_leg_accel+gyro.csv', index = False)
