# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('final_cleaned_chest_accel-sub05.csv-sub05')
elec = pd.read_csv('final_cleaned_chest_elec-sub05.csv-sub05')

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614642696005627     0.012757     0.305730
# 1               1          1614642696037588    -0.088808     0.727611
# 2               2          1614642696069548    -0.253849     1.064530
# 3               3          1614642696101509    -0.287053     0.930739
# 4               4          1614642696133469     0.204654     0.250065
# ...           ...                       ...          ...          ...
# 54447       54447          1614646535857946    -0.375433     1.149493
# 54448       54448          1614646535889917    -0.453559     1.517174
# 54449       54449          1614646535921887    -0.355901     1.610925
# 54450       54450          1614646535953858    -0.213809     1.025956
# 54451       54451          1614646535985828    -0.097597     0.521553
#
#        Accel Z (g)             Activity_Label
# 0         0.078187  Forward and backward step
# 1         0.098207  Forward and backward step
# 2         0.478584  Forward and backward step
# 3         0.657298  Forward and backward step
# 4         0.299870  Forward and backward step
# ...            ...                        ...
# 54447    -0.104433        Punch_down_Up_Hooks
# 54448     0.246159        Punch_down_Up_Hooks
# 54449     0.162173        Punch_down_Up_Hooks
# 54450    -0.212345        Punch_down_Up_Hooks
# 54451    -0.254826        Punch_down_Up_Hooks
#
# [54452 rows x 6 columns]

# %%
elec
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Sample (V)  \
# 0                0          1614642696002603    0.001812
# 1                1          1614642696006610    0.001806
# 2                2          1614642696010618    0.001812
# 3                3          1614642696014625    0.001800
# 4                4          1614642696018633    0.001794
# ...            ...                       ...         ...
# 434163      434163          1614646535980396    0.002428
# 434164      434164          1614646535984404    0.002422
# 434165      434165          1614646535988412    0.002403
# 434166      434166          1614646535992419    0.002397
# 434167      434167          1614646535996427    0.002397
#
#                    Activity_Label
# 0       Forward and backward step
# 1       Forward and backward step
# 2       Forward and backward step
# 3       Forward and backward step
# 4       Forward and backward step
# ...                           ...
# 434163        Punch_down_Up_Hooks
# 434164        Punch_down_Up_Hooks
# 434165        Punch_down_Up_Hooks
# 434166        Punch_down_Up_Hooks
# 434167        Punch_down_Up_Hooks
#
# [434168 rows x 4 columns]

# %%
elec_ts = elec['Timestamp (microseconds)'].to_numpy()

# %%
elec_ts
# Out:
# array([1614642696002603, 1614642696006610, 1614642696010618, ...,
#        1614646535988412, 1614646535992419, 1614646535996427])

# %%
accel_ts = accel['Timestamp (microseconds)'].to_numpy()

# %%
accel_ts
# Out:
# array([1614642696005627, 1614642696037588, 1614642696069548, ...,
#        1614646535921887, 1614646535953858, 1614646535985828])

# %%
for i in range(len(accel_ts)):
    accel.at[i, 'Sample (V)'] = elec['Sample (V)'].iloc[np.argmin(abs(accel_ts[i] - elec_ts))]

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614642696005627     0.012757     0.305730
# 1               1          1614642696037588    -0.088808     0.727611
# 2               2          1614642696069548    -0.253849     1.064530
# 3               3          1614642696101509    -0.287053     0.930739
# 4               4          1614642696133469     0.204654     0.250065
# ...           ...                       ...          ...          ...
# 54447       54447          1614646535857946    -0.375433     1.149493
# 54448       54448          1614646535889917    -0.453559     1.517174
# 54449       54449          1614646535921887    -0.355901     1.610925
# 54450       54450          1614646535953858    -0.213809     1.025956
# 54451       54451          1614646535985828    -0.097597     0.521553
#
#        Accel Z (g)             Activity_Label  Sample (V)
# 0         0.078187  Forward and backward step    0.001806
# 1         0.098207  Forward and backward step    0.001751
# 2         0.478584  Forward and backward step    0.001714
# 3         0.657298  Forward and backward step    0.001702
# 4         0.299870  Forward and backward step    0.001708
# ...            ...                        ...         ...
# 54447    -0.104433        Punch_down_Up_Hooks    0.000742
# 54448     0.246159        Punch_down_Up_Hooks    0.002600
# 54449     0.162173        Punch_down_Up_Hooks    0.002736
# 54450    -0.212345        Punch_down_Up_Hooks    0.002576
# 54451    -0.254826        Punch_down_Up_Hooks    0.002422
#
# [54452 rows x 7 columns]

# %%
ts = accel['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
accel['Time_elapse'] = ts1.tolist()

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614642696005627     0.012757     0.305730
# 1               1          1614642696037588    -0.088808     0.727611
# 2               2          1614642696069548    -0.253849     1.064530
# 3               3          1614642696101509    -0.287053     0.930739
# 4               4          1614642696133469     0.204654     0.250065
# ...           ...                       ...          ...          ...
# 54447       54447          1614646535857946    -0.375433     1.149493
# 54448       54448          1614646535889917    -0.453559     1.517174
# 54449       54449          1614646535921887    -0.355901     1.610925
# 54450       54450          1614646535953858    -0.213809     1.025956
# 54451       54451          1614646535985828    -0.097597     0.521553
#
#        Accel Z (g)             Activity_Label  Sample (V)  Time_elapse
# 0         0.078187  Forward and backward step    0.001806     0.000000
# 1         0.098207  Forward and backward step    0.001751     0.031961
# 2         0.478584  Forward and backward step    0.001714     0.063921
# 3         0.657298  Forward and backward step    0.001702     0.095882
# 4         0.299870  Forward and backward step    0.001708     0.127842
# ...            ...                        ...         ...          ...
# 54447    -0.104433        Punch_down_Up_Hooks    0.000742  3839.852319
# 54448     0.246159        Punch_down_Up_Hooks    0.002600  3839.884290
# 54449     0.162173        Punch_down_Up_Hooks    0.002736  3839.916260
# 54450    -0.212345        Punch_down_Up_Hooks    0.002576  3839.948231
# 54451    -0.254826        Punch_down_Up_Hooks    0.002422  3839.980201
#
# [54452 rows x 8 columns]

# %%
accel.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
accel
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1614642696005627     0.012757     0.305730     0.078187
# 1              1614642696037588    -0.088808     0.727611     0.098207
# 2              1614642696069548    -0.253849     1.064530     0.478584
# 3              1614642696101509    -0.287053     0.930739     0.657298
# 4              1614642696133469     0.204654     0.250065     0.299870
# ...                         ...          ...          ...          ...
# 54447          1614646535857946    -0.375433     1.149493    -0.104433
# 54448          1614646535889917    -0.453559     1.517174     0.246159
# 54449          1614646535921887    -0.355901     1.610925     0.162173
# 54450          1614646535953858    -0.213809     1.025956    -0.212345
# 54451          1614646535985828    -0.097597     0.521553    -0.254826
#
#                   Activity_Label  Sample (V)  Time_elapse
# 0      Forward and backward step    0.001806     0.000000
# 1      Forward and backward step    0.001751     0.031961
# 2      Forward and backward step    0.001714     0.063921
# 3      Forward and backward step    0.001702     0.095882
# 4      Forward and backward step    0.001708     0.127842
# ...                          ...         ...          ...
# 54447        Punch_down_Up_Hooks    0.000742  3839.852319
# 54448        Punch_down_Up_Hooks    0.002600  3839.884290
# 54449        Punch_down_Up_Hooks    0.002736  3839.916260
# 54450        Punch_down_Up_Hooks    0.002576  3839.948231
# 54451        Punch_down_Up_Hooks    0.002422  3839.980201
#
# [54452 rows x 7 columns]

# %%
#accel.to_csv('sub01_chest_accel+elec.csv', index = False)

# %%
# accel.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)
#accel

# %%
accel.to_csv('sub05_chest_accel+elec.csv', index = False)
