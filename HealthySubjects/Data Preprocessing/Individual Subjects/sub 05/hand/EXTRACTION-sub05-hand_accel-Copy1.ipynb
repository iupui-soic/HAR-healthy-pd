# %%
from datetime import datetime
import time
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv('/Users/shreyasaswar/HARDataset/Sub07/pd-healthy_07_extensor_digitorum_right_n4sh9vn2_2021-03-02t21_24_35z/accel.csv')

# %%
df1
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)
# 0               1614720275375366    -0.569894     0.501411    -0.596017
# 1               1614720275391366    -0.611643     0.591135    -0.566110
# 2               1614720275407365    -0.688670     0.733349    -0.581857
# 3               1614720275423365    -0.654368     0.782300    -0.618112
# 4               1614720275439365    -0.591867     0.715282    -0.602853
# ...                          ...          ...          ...          ...
# 253273          1614724327783660    -0.542306     0.552804    -0.664134
# 253274          1614724327799659    -0.573922     0.712230    -0.761059
# 253275          1614724327815659    -0.533639     0.779248    -0.733715
# 253276          1614724327831658    -0.528389     0.697093    -0.619089
# 253277          1614724327847657    -0.554269     0.636301    -0.629221
#
# [253278 rows x 4 columns]

# %%
pd.Timestamp(df1['Timestamp (microseconds)'][0], unit='us')
# Out:
# Timestamp('2021-03-02 21:24:35.375366')

# %%
start = pd.Timestamp(year=2021, month=3, day=2, hour=16, minute=27, second=1)
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year=2021, month=3, day=2, hour=16, minute=28, second=1)
end_ts = int(end.timestamp() * 1e6)

DF1 = df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF1['Activity_Label'] = 'Forward and backward step'
DF1
# Out:
# Empty DataFrame
# Columns: [Timestamp (microseconds), Accel X (g), Accel Y (g), Accel Z (g), Activity_Label]
# Index: []

# %%
start=pd.Timestamp(year=2021, month=3, day=1, hour=11, minute=21, second=29)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=1, hour=11, minute=22, second=29)
end_ts=int(end.timestamp() * 1e6)

DF2= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF2['Activity_Label']='Sideward step'
DF2
# Out:
# Empty DataFrame
# Columns: [Timestamp (microseconds), Accel X (g), Accel Y (g), Accel Z (g), Activity_Label]
# Index: []

# %%
start=pd.Timestamp(year=2021, month=3, day=1, hour=23, minute=54, second=53)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=1, hour=23, minute=55, second=53)
end_ts=int(end.timestamp() * 1e6)

DF3= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF3['Activity_Label']='Pushups'
DF3
# Out:
# <ipython-input-7-9aa91ac6d6ce>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF3['Activity_Label']='Pushups'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 22158          1614642893001876    -0.842359     0.190005    -0.596750
# 22159          1614642893017875    -1.105303     0.318303    -0.522408
# 22160          1614642893033874    -0.819043     0.418891    -0.646921
# 22161          1614642893049873    -0.502510     0.305241    -0.663645
# 22162          1614642893065872    -0.758618     0.079042    -0.726635
# ...                         ...          ...          ...          ...
# 25904          1614642952932525    -1.696376     1.521813     0.095521
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=1, hour=23, minute=56, second=39)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=1, hour=23, minute=57, second=39)
end_ts=int(end.timestamp() * 1e6)

DF4= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF4['Activity_Label']='Hip raise step with punches in the air'
DF4
# Out:
# <ipython-input-8-d2f7630bf61a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF4['Activity_Label']='Hip raise step with punches in the air'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 28784          1614642999008606     0.479805     0.835523     0.108217
# 28785          1614642999024604     0.475654     0.805249     0.101747
# 28786          1614642999040603     0.496284     0.803296     0.111879
# 28787          1614642999056602     0.516304     0.823316     0.138369
# 28788          1614642999072601     0.516060     0.863844     0.151308
# ...                         ...          ...          ...          ...
# 32529          1614643058923652     0.758740     0.063050     0.588693
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=1, hour=23, minute=58, second=58)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=1, hour=23, minute=59, second=58)
end_ts=int(end.timestamp() * 1e6)

DF5= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF5['Activity_Label']='Front and back scooter'
DF5
# Out:
# <ipython-input-9-2a715700a61f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF5['Activity_Label']='Front and back scooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 37472          1614643138005493    -0.531930     0.948196    -0.533639
# 37473          1614643138021492    -0.463447     0.823072    -0.597238
# 37474          1614643138037490    -0.496529     0.758618    -0.634226
# 37475          1614643138053489    -0.563424     0.869703    -0.593820
# 37476          1614643138069488    -0.648142     0.669505    -0.608835
# ...                         ...          ...          ...          ...
# 41217          1614643197921363    -0.859327     0.275212    -0.596139
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=2, second=25)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=3, second=25)
end_ts=int(end.timestamp() * 1e6)

DF6= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF6['Activity_Label']='Belly Scooter'
DF6
# Out:
# <ipython-input-10-5b4fd6879356>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF6['Activity_Label']='Belly Scooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 50410          1614643345000233    -0.519234     1.106767     0.150332
# 50411          1614643345016233    -0.468940     1.119463     0.159731
# 50412          1614643345032232    -0.507393     1.206867     0.150576
# 50413          1614643345048231    -0.412543     1.148516     0.139834
# 50414          1614643345064231    -0.343694     1.108598     0.145693
# ...                         ...          ...          ...          ...
# 54156          1614643404932624    -0.282414    -1.116899    -0.446723
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=3, second=45)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=4, second=45)
end_ts=int(end.timestamp() * 1e6)

DF7= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF7['Activity_Label']='Circular Scooter'
DF7
# Out:
# <ipython-input-11-14cc1c1edf38>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF7['Activity_Label']='Circular Scooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 55411          1614643425011380    -0.945388    -0.436591     0.021180
# 55412          1614643425027380    -1.025589    -0.416083     0.045350
# 55413          1614643425043379    -0.968460    -0.412909     0.059754
# 55414          1614643425059378    -0.914260    -0.349676     0.089418
# 55415          1614643425075378    -0.871290    -0.294865     0.114321
# ...                         ...          ...          ...          ...
# 59156          1614643484927894    -0.824170     0.292546     0.198184
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=6, second=58)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=7, second=58)
end_ts=int(end.timestamp() * 1e6)

DF8= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF8['Activity_Label']='Cycling Slow'
DF8
# Out:
# <ipython-input-12-81eeea766c0c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF8['Activity_Label']='Cycling Slow'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 67474          1614643618008719    -0.414984     0.851148    -0.349798
# 67475          1614643618024718    -0.407538     0.857008    -0.356634
# 67476          1614643618040718    -0.346746     0.935378    -0.364691
# 67477          1614643618056717    -0.380316     1.005081    -0.353460
# 67478          1614643618072716    -0.381048     0.961990    -0.335515
# ...                         ...          ...          ...          ...
# 71219          1614643677925325    -0.097963     0.963821    -0.645579
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=7, second=59)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=8, second=59)
end_ts=int(end.timestamp() * 1e6)

DF9= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF9['Activity_Label']='Cycling Fast'
DF9
# Out:
# <ipython-input-13-e864ea10ed90>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF9['Activity_Label']='Cycling Fast'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 71287          1614643679013270    -0.422309     0.863111    -0.328435
# 71288          1614643679029270    -0.416449     0.747631    -0.311223
# 71289          1614643679045269    -0.416205     0.778271    -0.310124
# 71290          1614643679061268    -0.400092     0.886915    -0.311589
# 71291          1614643679077268    -0.372259     0.925856    -0.367987
# ...                         ...          ...          ...          ...
# 75032          1614643738929321     0.509224     1.066850    -0.786206
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=10, second=43)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=11, second=43)
end_ts=int(end.timestamp() * 1e6)

DF10= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF10['Activity_Label']='Medicine_ball'
DF10
# Out:
# <ipython-input-14-185538fb6733>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF10['Activity_Label']='Medicine_ball'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 81537          1614643843002670     0.866041     0.169497     0.512398
# 81538          1614643843018670     0.914626     0.108949     0.482612
# 81539          1614643843034669     0.881056     0.099550     0.485420
# 81540          1614643843050659     0.782055     0.145571     0.524361
# 81541          1614643843066658     0.825757     0.154116     0.498116
# ...                         ...          ...          ...          ...
# 85283          1614643902934960     0.832105     0.201114     0.442573
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=11, second=53)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=12, second=53)
end_ts=int(end.timestamp() * 1e6)

DF11= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF11['Activity_Label']='Medicine ball with burpies'
DF11
# Out:
# <ipython-input-15-4896ff752642>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF11['Activity_Label']='Medicine ball with burpies'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 85913          1614643913014326    -0.204410     0.789746    -0.322454
# 85914          1614643913030326     0.052552     0.914870    -0.445014
# 85915          1614643913046325    -0.044373     0.219791    -0.471260
# 85916          1614643913062324    -0.531930    -0.228580    -0.552316
# 85917          1614643913078323    -1.419760    -0.625193    -0.741039
# ...                         ...          ...          ...          ...
# 89658          1614643972930718    -1.400229    -0.270085    -0.465888
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=17, second=20)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=18, second=20)
end_ts=int(end.timestamp() * 1e6)

DF12= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF12['Activity_Label']='punch ball'
DF12
# Out:
# <ipython-input-16-8c2dcfc459b6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF12['Activity_Label']='punch ball'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 106351          1614644240007937    -0.706249     0.256779    -0.431464
# 106352          1614644240023937    -0.684642     0.250065    -0.413642
# 106353          1614644240039937    -0.674022     0.245548    -0.400702
# 106354          1614644240055936    -0.690990     0.238590    -0.388373
# 106355          1614644240071936    -0.710765     0.210513    -0.378973
# ...                          ...          ...          ...          ...
# 110096          1614644299925544     0.023255    -0.173526    -0.478950
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=19, second=13)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=20, second=13)
end_ts=int(end.timestamp() * 1e6)

DF13= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF13['Activity_Label']='Squarts Toe ups'
DF13
# Out:
# <ipython-input-17-fd04f2203726>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF13['Activity_Label']='Squarts Toe ups'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 113414          1614644353011099     0.110170     0.388495    -0.610056
# 113415          1614644353027099     0.092592     0.358709    -0.752514
# 113416          1614644353043098     0.097353     0.288884    -0.843824
# 113417          1614644353059097     0.112001     0.288273    -0.865064
# 113418          1614644353075097     0.075257     0.450752    -0.827466
# ...                          ...          ...          ...          ...
# 117159          1614644412928407    -0.262394     0.692332    -1.195636
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=20, second=55)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=21, second=55)
end_ts=int(end.timestamp() * 1e6)

DF14= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF14['Activity_Label']='Weight lifts'
DF14
# Out:
# <ipython-input-18-950049b5159c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF14['Activity_Label']='Weight lifts'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 119789          1614644455006573    -0.351629     0.231388    -0.612375
# 119790          1614644455022572    -0.348699     0.181338    -0.609689
# 119791          1614644455038571    -0.366155     0.134340    -0.616037
# 119792          1614644455054571    -0.383978     0.152163    -0.604685
# 119793          1614644455070570    -0.374456     0.185489    -0.609812
# ...                          ...          ...          ...          ...
# 123534          1614644514923972     0.302556     0.721752    -0.635203
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=22, second=49)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=23, second=49)
end_ts=int(end.timestamp() * 1e6)

DF15= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF15['Activity_Label']='Heavy Weight lifts'
DF15
# Out:
# <ipython-input-19-18773cd91355>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF15['Activity_Label']='Heavy Weight lifts'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 126914          1614644569001608    -0.829786     0.432197    -0.738231
# 126915          1614644569017608    -0.760082     0.379339    -0.780835
# 126916          1614644569033607    -0.685252     0.471504    -0.810986
# 126917          1614644569049606    -0.542794     0.430121    -0.770336
# 126918          1614644569065606    -0.463203     0.564157    -0.770336
# ...                          ...          ...          ...          ...
# 130660          1614644628935241    -0.947097     0.106386    -0.231510
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=24, second=45)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=25, second=45)
end_ts=int(end.timestamp() * 1e6)

DF16= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF16['Activity_Label']='Forward Lunges on Bosu'
DF16
# Out:
# <ipython-input-20-94083dc3f1f6>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF16['Activity_Label']='Forward Lunges on Bosu'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 134165          1614644685013071    -0.944045     0.253239    -0.439399
# 134166          1614644685029070    -0.960037     0.261051    -0.415229
# 134167          1614644685045070    -0.926589     0.270085    -0.387152
# 134168          1614644685061069    -0.897047     0.267887    -0.384466
# 134169          1614644685077068    -0.903761     0.259953    -0.432074
# ...                          ...          ...          ...          ...
# 137910          1614644744930440    -0.651682     0.319768    -0.409003
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=26, second=48)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=27, second=48)
end_ts=int(end.timestamp() * 1e6)

DF17= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF17['Activity_Label']='Split squart left on Bosu'
DF17
# Out:
# <ipython-input-21-62080580c548>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF17['Activity_Label']='Split squart left on Bosu'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 141853          1614644808015425    -0.799634     0.189883    -0.410468
# 141854          1614644808031424    -0.815137     0.185245    -0.415717
# 141855          1614644808047423    -0.832715     0.179507    -0.419257
# 141856          1614644808063423    -0.842237     0.170962    -0.414130
# 141857          1614644808079422    -0.843336     0.166323    -0.407660
# ...                          ...          ...          ...          ...
# 145598          1614644867932824    -0.578561     0.507515    -0.671092
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=28, second=0)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=29, second=0)
end_ts=int(end.timestamp() * 1e6)

DF18= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF18['Activity_Label']='Split squart right on Bosu'
DF18
# Out:
# <ipython-input-22-bdbb8cdde35b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF18['Activity_Label']='Split squart right on Bosu'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 146353          1614644880012312    -0.826001     0.277653    -0.387396
# 146354          1614644880028311    -0.808911     0.275578    -0.384833
# 146355          1614644880044311    -0.790845     0.271061    -0.378607
# 146356          1614644880060310    -0.789258     0.275334    -0.379339
# 146357          1614644880076309    -0.817823     0.283513    -0.380072
# ...                          ...          ...          ...          ...
# 150098          1614644939929772    -0.528634    -0.800122    -0.703929
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=30, second=32)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=31, second=32)
end_ts=int(end.timestamp() * 1e6)

DF19= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF19['Activity_Label']='plank pie on Bosu'
DF19
# Out:
# <ipython-input-23-f5483580dfe9>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF19['Activity_Label']='plank pie on Bosu'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 155853          1614645032006209    -0.949905     0.087343    -0.317815
# 155854          1614645032022208    -0.988846     0.063294    -0.258488
# 155855          1614645032038207    -0.928054     0.198917    -0.229801
# 155856          1614645032054206    -0.935622     0.153750    -0.318669
# 155857          1614645032070206    -1.003861     0.060487    -0.271305
# ...                          ...          ...          ...          ...
# 159598          1614645091924126    -0.841138     0.323919    -0.392401
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=32, second=37)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=33, second=37)
end_ts=int(end.timestamp() * 1e6)

DF20= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF20['Activity_Label']='plank top on Bosu'
DF20
# Out:
# <ipython-input-24-82eaf00409de>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF20['Activity_Label']='plank top on Bosu'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 163666          1614645157009878    -0.971389     0.044129    -0.375921
# 163667          1614645157025878    -1.029374    -0.017395    -0.312444
# 163668          1614645157041877    -0.966751     0.029725    -0.194156
# 163669          1614645157057877    -0.900587    -0.057435    -0.175845
# 163670          1614645157073877    -0.957351    -0.055238    -0.264103
# ...                          ...          ...          ...          ...
# 167411          1614645216928042    -0.816480     0.306950    -0.466133
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=34, second=57)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=35, second=57)
end_ts=int(end.timestamp() * 1e6)

DF21= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF21['Activity_Label']='dips on Bosu'
DF21
# Out:
# <ipython-input-25-f965cc1a2ab4>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF21['Activity_Label']='dips on Bosu'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 172416          1614645297005935    -0.933791     0.624582    -0.000305
# 172417          1614645297021935    -0.980056     0.632151     0.015564
# 172418          1614645297037935    -0.853223     0.564523    -0.012390
# 172419          1614645297053935    -0.890211     0.647166    -0.017273
# 172420          1614645297069915    -0.991287     0.695628     0.038270
# ...                          ...          ...          ...          ...
# 176161          1614645356924386    -0.654978     0.570260     0.257267
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=36, second=52)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=37, second=52)
end_ts=int(end.timestamp() * 1e6)

DF22= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF22['Activity_Label']='moveforward backward on Bosu'
DF22
# Out:
# <ipython-input-26-e9267ac5fbf7>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF22['Activity_Label']='moveforward backward on Bosu'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 179604          1614645412011051     0.023255     0.720165    -0.699779
# 179605          1614645412027051     0.017273     0.707958    -0.700877
# 179606          1614645412043050     0.010681     0.706249    -0.700145
# 179607          1614645412059050     0.000793     0.713207    -0.701244
# 179608          1614645412075050     0.007019     0.725292    -0.704051
# ...                          ...          ...          ...          ...
# 183349          1614645471929642     0.428656     0.697581     0.737255
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=39, second=2)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=40, second=2)
end_ts=int(end.timestamp() * 1e6)

DF23= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF23['Activity_Label']='Left leg Hip ups on Bosu'
DF23
# Out:
# <ipython-input-27-eb7f55f1d151>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF23['Activity_Label']='Left leg Hip ups on Bosu'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 187729          1614645542007981     0.096498     0.789502    -0.595529
# 187730          1614645542023981     0.092470     0.795605    -0.603342
# 187731          1614645542039981     0.107240     0.795483    -0.602853
# 187732          1614645542055980     0.083192     0.772534    -0.607004
# 187733          1614645542071980     0.083680     0.798047    -0.603342
# ...                          ...          ...          ...          ...
# 191474          1614645601926511     0.052674     0.944900    -0.241398
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=40, second=11)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=41, second=11)
end_ts=int(end.timestamp() * 1e6)

DF24= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF24['Activity_Label']='right leg Hip ups on Bosu'
DF24
# Out:
# <ipython-input-28-b2b9804ae980>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF24['Activity_Label']='right leg Hip ups on Bosu'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 192042          1614645611014299     0.855055     0.662791    -0.063172
# 192043          1614645611030299     0.799878     0.628000     0.037659
# 192044          1614645611046299     0.812573     0.566964     0.146181
# 192045          1614645611062298     0.803906     0.469429     0.219425
# 192046          1614645611078298     0.748852     0.414984     0.254215
# ...                          ...          ...          ...          ...
# 195787          1614645670932921     0.624094     0.683909    -0.358587
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=43, second=2)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=44, second=2)
end_ts=int(end.timestamp() * 1e6)

DF25= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF25['Activity_Label']='V-Shift Swift on Bosu'
DF25
# Out:
# <ipython-input-29-3995fabb524f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF25['Activity_Label']='V-Shift Swift on Bosu'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 202729          1614645782001816    -0.390204     0.865675    -0.489693
# 202730          1614645782017816    -0.397772     0.844800    -0.453437
# 202731          1614645782033816    -0.342596     0.832715    -0.414252
# 202732          1614645782049816    -0.274113     0.809400    -0.409125
# 202733          1614645782065816    -0.257877     0.803296    -0.408026
# ...                          ...          ...          ...          ...
# 206475          1614645841935767    -0.971145     0.267765    -0.001770
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=46, second=50)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=47, second=20)
end_ts=int(end.timestamp() * 1e6)

DF26= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF26['Activity_Label']='Freestyle Boxing'
DF26
# Out:
# <ipython-input-30-ac3c15f67f9f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF26['Activity_Label']='Freestyle Boxing'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 216980          1614646010009124    -0.753002     0.315862    -0.612863
# 216981          1614646010025124    -0.734081     0.299504    -0.621897
# 216982          1614646010041123    -0.727123     0.282048    -0.630564
# 216983          1614646010057122    -0.727733     0.327825    -0.645701
# 216984          1614646010073122    -0.730419     0.351995    -0.669627
# ...                          ...          ...          ...          ...
# 218850          1614646039927510    -0.409613     0.298161    -0.148623
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=47, second=55)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=48, second=25)
end_ts=int(end.timestamp() * 1e6)

DF27= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF27['Activity_Label']='Left_Right_Punches_flip'
DF27
# Out:
# <ipython-input-31-3990e029228f>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF27['Activity_Label']='Left_Right_Punches_flip'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 221043          1614646075013360    -0.792065     0.938308    -1.189532
# 221044          1614646075029359    -0.495186     0.484932    -1.347494
# 221045          1614646075045359    -0.201724     0.795605    -1.238605
# 221046          1614646075061358     0.319402     0.508492    -1.138018
# 221047          1614646075077357     0.519966     0.387396    -0.871046
# ...                          ...          ...          ...          ...
# 222909          1614646104931440    -0.525093    -0.584909    -0.789258
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=49, second=21)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=49, second=51)
end_ts=int(end.timestamp() * 1e6)

DF28= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF28['Activity_Label']='left_Right_Punch'
DF28
# Out:
# <ipython-input-32-83b28f4f9fc4>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF28['Activity_Label']='left_Right_Punch'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 226414          1614646161007736    -0.795727     0.326116    -0.341253
# 226415          1614646161023735    -0.809277     0.338201    -0.335393
# 226416          1614646161039734    -0.815259     0.339910    -0.339544
# 226417          1614646161055732    -0.839185     0.345525    -0.337102
# 226418          1614646161071731    -0.861891     0.335637    -0.342718
# ...                          ...          ...          ...          ...
# 228282          1614646190925750    -0.738964     0.674022    -0.949294
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=50, second=51)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=51, second=21)
end_ts=int(end.timestamp() * 1e6)

DF29= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF29['Activity_Label']='one_twos'
DF29
# Out:
# <ipython-input-33-759ec8fe4387>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF29['Activity_Label']='one_twos'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 232037          1614646251001855    -0.777050     0.441108    -0.422431
# 232038          1614646251017854    -0.768627     0.415473    -0.425360
# 232039          1614646251033854    -0.776562     0.405951    -0.430732
# 232040          1614646251049853    -0.774731     0.408392    -0.438178
# 232041          1614646251065852    -0.778149     0.433906    -0.430854
# ...                          ...          ...          ...          ...
# 233908          1614646280935935     4.000000     3.063584     0.646677
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=51, second=45)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=52, second=15)
end_ts=int(end.timestamp() * 1e6)

DF30= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF30['Activity_Label']='hooks'
DF30
# Out:
# <ipython-input-34-ec76f3665bbb>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF30['Activity_Label']='hooks'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 235412          1614646305014274    -0.688914     0.380560    -0.584421
# 235413          1614646305030304    -0.712963     0.388861    -0.652293
# 235414          1614646305046302    -0.758740     0.372747    -0.708690
# 235415          1614646305062301    -0.800000     0.333196    -0.756786
# 235416          1614646305078300    -0.824781     0.298161    -0.794385
# ...                          ...          ...          ...          ...
# 237281          1614646334932258    -0.279728     0.913039    -0.328313
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=52, second=51)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=53, second=21)
end_ts=int(end.timestamp() * 1e6)

DF31= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF31['Activity_Label']='Upper_cuts'
DF31
# Out:
# <ipython-input-35-26154fb3a353>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF31['Activity_Label']='Upper_cuts'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 239536          1614646371009796    -0.932326     0.317082    -0.347845
# 239537          1614646371025795    -0.927321     0.349676    -0.340154
# 239538          1614646371041793    -0.915236     0.393988    -0.317082
# 239539          1614646371057792    -0.888869     0.428412    -0.286442
# 239540          1614646371073791    -0.854200     0.447456    -0.259464
# ...                          ...          ...          ...          ...
# 241406          1614646400927749    -0.206729     0.408026    -0.923659
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=54, second=0)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=54, second=30)
end_ts=int(end.timestamp() * 1e6)

DF32= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF32['Activity_Label']='run'
DF32
# Out:
# <ipython-input-36-f3dcc3cf0331>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF32['Activity_Label']='run'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 243849          1614646440013069    -0.937331     0.084291    -0.825391
# 243850          1614646440029068    -0.754467     0.052918    -0.809400
# 243851          1614646440045066    -0.619333     0.022400    -0.752026
# 243852          1614646440061065    -0.503609    -0.022034    -0.680613
# 243853          1614646440077064    -0.445502    -0.010071    -0.594430
# ...                          ...          ...          ...          ...
# 245719          1614646469930931    -0.393622     0.052186     0.170962
# ...

# %%
start=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=55, second=6)
start_ts=int(start.timestamp() * 1e6)

end=pd.Timestamp(year=2021, month=3, day=2, hour=0, minute=55, second=36)
end_ts=int(end.timestamp() * 1e6)

DF33= df1.loc[(df1['Timestamp (microseconds)'] >=start_ts) & (df1['Timestamp (microseconds)']<=end_ts)]

DF33['Activity_Label']='Punch_down_Up_Hooks'
DF33
# Out:
# <ipython-input-37-78e3e95211d3>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DF33['Activity_Label']='Punch_down_Up_Hooks'
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 247972          1614646506008285    -1.139483     0.348699    -0.843336
# 247973          1614646506024284    -1.099077     0.339666    -0.805737
# 247974          1614646506040283    -1.022660     0.479683    -0.679515
# 247975          1614646506056282    -0.923415     0.593942    -0.544137
# 247976          1614646506072281    -0.773388     0.649363    -0.441474
# ...                          ...          ...          ...          ...
# 249841          1614646535926178    -0.923781     0.981155    -0.478096
# ...

# %%
sub05_final_hand_accel=pd.concat ([DF1,DF2, DF3, DF4, DF5, DF6, DF7, DF8, DF9, DF10, DF11, DF12, DF13, DF14, DF15, DF16, DF17, DF18, DF19, DF20, DF21, DF22, DF23, DF24, DF25, DF26, DF27, DF28, DF29, DF30, DF31, DF32, DF33], ignore_index=True)
sub05_final_hand_accel
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614642696013219    -0.007752     0.613474    -0.545602
# 1               1614642696029217     0.089296     0.548287    -0.474800
# 2               1614642696045216     0.175601     0.534249    -0.429877
# 3               1614642696061214     0.263127     0.519234    -0.392157
# 4               1614642696077212     0.321721     0.503609    -0.352605
# ...                          ...          ...          ...          ...
# 108743          1614646535926178    -0.923781     0.981155    -0.478096
# 108744          1614646535942176    -0.794263     0.829419    -0.471260
# 108745          1614646535958175    -0.718090     0.703197    -0.507149
# 108746          1614646535974174    -0.665599     0.661936    -0.543038
# 108747          1614646535990173    -0.660716     0.684764    -0.533272
#
#                    Activity_Label
# 0       Forward and backward step
# ...

# %%
sub05_final_hand_accel.to_csv('final_cleaned_hand_accel-sub05.csv-sub05')
