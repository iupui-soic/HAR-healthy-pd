# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('final_cleaned_hand_accel-sub01.csv-sub01')
gyro = pd.read_csv('final_cleaned_hand_gyro-sub01.csv-sub01')

# %%
accel
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                0          1614540810004902    -0.765454     0.629099
# 1                1          1614540810020897    -0.763134     0.633371
# 2                2          1614540810036891    -0.760204     0.632029
# 3                3          1614540810052885    -0.762280     0.629953
# 4                4          1614540810068879    -0.764843     0.627756
# ...            ...                       ...          ...          ...
# 107491      107491          1614544529920802     0.668040     0.431952
# 107492      107492          1614544529936796     0.634592     0.438056
# 107493      107493          1614544529952790     0.589425     0.443183
# 107494      107494          1614544529968784     0.518990     0.443671
# 107495      107495          1614544529984778     0.435859     0.429755
#
#         Accel Z (g)             Activity_Label
# 0         -0.168521  Forward and backward step
# 1         -0.183291  Forward and backward step
# 2         -0.200015  Forward and backward step
# 3         -0.216861  Forward and backward step
# 4         -0.225162  Forward and backward step
# ...             ...                        ...
# 107491    -0.471382        Punch_down_Up_Hooks
# 107492    -0.457832        Punch_down_Up_Hooks
# 107493    -0.439399        Punch_down_Up_Hooks
# 107494    -0.468086        Punch_down_Up_Hooks
# 107495    -0.495552        Punch_down_Up_Hooks
#
# [107496 rows x 6 columns]

# %%
gyro
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Gyro X (°/s)  Gyro Y (°/s)  \
# 0                0          1614540810004902     25.726711    -25.482567
# 1                1          1614540810020897     23.468376    -25.726711
# 2                2          1614540810036891     20.477607    -25.482567
# 3                3          1614540810052885     17.975128    -24.689097
# 4                4          1614540810068879     16.388190    -23.895628
# ...            ...                       ...           ...           ...
# 107531      107531          1614544529920802    -12.664988    -14.862287
# 107532      107532          1614544529936796    -14.129854    -16.754406
# 107533      107533          1614544529952790    -16.998550    -17.120623
# 107534      107534          1614544529968784    -20.355535    -16.327153
# 107535      107535          1614544529984778    -22.186618    -15.411612
#
#         Gyro Z (°/s)             Activity_Label
# 0          -9.430076  Forward and backward step
# 1          -9.674220  Forward and backward step
# 2          -9.796292  Forward and backward step
# 3          -9.979400  Forward and backward step
# 4          -9.796292  Forward and backward step
# ...              ...                        ...
# 107531     37.384604        Punch_down_Up_Hooks
# 107532     25.787747        Punch_down_Up_Hooks
# 107533     12.970169        Punch_down_Up_Hooks
# 107534      0.946059        Punch_down_Up_Hooks
# 107535     -9.369039        Punch_down_Up_Hooks
#
# [107536 rows x 6 columns]

# %%
inner_df = accel.join(gyro.set_index('Timestamp (microseconds)'), on='Timestamp (microseconds)', how='inner', lsuffix='_left', rsuffix='_right')

# %%
inner_df
# Out:
#         Unnamed: 0_left  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                     0          1614540810004902    -0.765454     0.629099
# 1                     1          1614540810020897    -0.763134     0.633371
# 2                     2          1614540810036891    -0.760204     0.632029
# 3                     3          1614540810052885    -0.762280     0.629953
# 4                     4          1614540810068879    -0.764843     0.627756
# ...                 ...                       ...          ...          ...
# 107491           107491          1614544529920802     0.668040     0.431952
# 107492           107492          1614544529936796     0.634592     0.438056
# 107493           107493          1614544529952790     0.589425     0.443183
# 107494           107494          1614544529968784     0.518990     0.443671
# 107495           107495          1614544529984778     0.435859     0.429755
#
#         Accel Z (g)        Activity_Label_left  Unnamed: 0_right  \
# 0         -0.168521  Forward and backward step                 0
# 1         -0.183291  Forward and backward step                 1
# 2         -0.200015  Forward and backward step                 2
# 3         -0.216861  Forward and backward step                 3
# 4         -0.225162  Forward and backward step                 4
# ...             ...                        ...               ...
# 107491    -0.471382        Punch_down_Up_Hooks            107531
# 107492    -0.457832        Punch_down_Up_Hooks            107532
# 107493    -0.439399        Punch_down_Up_Hooks            107533
# 107494    -0.468086        Punch_down_Up_Hooks            107534
# 107495    -0.495552        Punch_down_Up_Hooks            107535
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          25.726711    -25.482567     -9.430076  Forward and backward step
# 1          23.468376    -25.726711     -9.674220  Forward and backward step
# 2          20.477607    -25.482567     -9.796292  Forward and backward step
# 3          17.975128    -24.689097     -9.979400  Forward and backward step
# 4          16.388190    -23.895628     -9.796292  Forward and backward step
# ...              ...           ...           ...                        ...
# 107491    -12.664988    -14.862287     37.384604        Punch_down_Up_Hooks
# 107492    -14.129854    -16.754406     25.787747        Punch_down_Up_Hooks
# 107493    -16.998550    -17.120623     12.970169        Punch_down_Up_Hooks
# 107494    -20.355535    -16.327153      0.946059        Punch_down_Up_Hooks
# 107495    -22.186618    -15.411612     -9.369039        Punch_down_Up_Hooks
#
# [110614 rows x 11 columns]

# %%
inner_df.drop(['Activity_Label_left','Unnamed: 0_left','Unnamed: 0_right'], axis=1, inplace=True)

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614540810004902    -0.765454     0.629099    -0.168521
# 1               1614540810020897    -0.763134     0.633371    -0.183291
# 2               1614540810036891    -0.760204     0.632029    -0.200015
# 3               1614540810052885    -0.762280     0.629953    -0.216861
# 4               1614540810068879    -0.764843     0.627756    -0.225162
# ...                          ...          ...          ...          ...
# 107491          1614544529920802     0.668040     0.431952    -0.471382
# 107492          1614544529936796     0.634592     0.438056    -0.457832
# 107493          1614544529952790     0.589425     0.443183    -0.439399
# 107494          1614544529968784     0.518990     0.443671    -0.468086
# 107495          1614544529984778     0.435859     0.429755    -0.495552
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          25.726711    -25.482567     -9.430076  Forward and backward step
# 1          23.468376    -25.726711     -9.674220  Forward and backward step
# 2          20.477607    -25.482567     -9.796292  Forward and backward step
# 3          17.975128    -24.689097     -9.979400  Forward and backward step
# 4          16.388190    -23.895628     -9.796292  Forward and backward step
# ...              ...           ...           ...                        ...
# 107491    -12.664988    -14.862287     37.384604        Punch_down_Up_Hooks
# 107492    -14.129854    -16.754406     25.787747        Punch_down_Up_Hooks
# 107493    -16.998550    -17.120623     12.970169        Punch_down_Up_Hooks
# 107494    -20.355535    -16.327153      0.946059        Punch_down_Up_Hooks
# 107495    -22.186618    -15.411612     -9.369039        Punch_down_Up_Hooks
#
# [110614 rows x 8 columns]

# %%
ts = inner_df['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
inner_df['Time_elapse'] = ts1.tolist()

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614540810004902    -0.765454     0.629099    -0.168521
# 1               1614540810020897    -0.763134     0.633371    -0.183291
# 2               1614540810036891    -0.760204     0.632029    -0.200015
# 3               1614540810052885    -0.762280     0.629953    -0.216861
# 4               1614540810068879    -0.764843     0.627756    -0.225162
# ...                          ...          ...          ...          ...
# 107491          1614544529920802     0.668040     0.431952    -0.471382
# 107492          1614544529936796     0.634592     0.438056    -0.457832
# 107493          1614544529952790     0.589425     0.443183    -0.439399
# 107494          1614544529968784     0.518990     0.443671    -0.468086
# 107495          1614544529984778     0.435859     0.429755    -0.495552
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right  \
# 0          25.726711    -25.482567     -9.430076  Forward and backward step
# 1          23.468376    -25.726711     -9.674220  Forward and backward step
# 2          20.477607    -25.482567     -9.796292  Forward and backward step
# 3          17.975128    -24.689097     -9.979400  Forward and backward step
# 4          16.388190    -23.895628     -9.796292  Forward and backward step
# ...              ...           ...           ...                        ...
# 107491    -12.664988    -14.862287     37.384604        Punch_down_Up_Hooks
# 107492    -14.129854    -16.754406     25.787747        Punch_down_Up_Hooks
# 107493    -16.998550    -17.120623     12.970169        Punch_down_Up_Hooks
# 107494    -20.355535    -16.327153      0.946059        Punch_down_Up_Hooks
# 107495    -22.186618    -15.411612     -9.369039        Punch_down_Up_Hooks
#
#         Time_elapse
# 0          0.000000
# 1          0.015995
# 2          0.031989
# 3          0.047983
# 4          0.063977
# ...             ...
# 107491  3719.915900
# 107492  3719.931894
# 107493  3719.947888
# 107494  3719.963882
# 107495  3719.979876
#
# [110614 rows x 9 columns]

# %%
# inner_df.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)

# %%
# inner_df

# %%
inner_df.to_csv('sub01_hand_accel+gyro.csv', index = False)
