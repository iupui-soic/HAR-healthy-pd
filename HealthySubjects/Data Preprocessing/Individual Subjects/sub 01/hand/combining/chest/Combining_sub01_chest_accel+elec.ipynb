# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('final_cleaned_chest_accel-sub01.csv-sub01')
elec = pd.read_csv('final_cleaned_chest_elec-sub01.csv-sub01')

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614540810021832     0.139223     0.923903
# 1               1          1614540810053670     0.129458     0.913649
# 2               2          1614540810085507     0.133852     0.915114
# 3               3          1614540810117345     0.121157     0.925856
# 4               4          1614540810149183     0.113832     0.917556
# ...           ...                       ...          ...          ...
# 54124       54124          1614544529867791     0.216861     0.669017
# 54125       54125          1614544529899557     0.204166     0.673411
# 54126       54126          1614544529931323     0.177798     0.710033
# 54127       54127          1614544529963089     0.147036     0.700755
# 54128       54128          1614544529994855     0.083070     0.706126
#
#        Accel Z (g)             Activity_Label
# 0         0.393622  Forward and backward step
# 1         0.381415  Forward and backward step
# 2         0.402899  Forward and backward step
# 3         0.408759  Forward and backward step
# 4         0.387274  Forward and backward step
# ...            ...                        ...
# 54124     0.375067        Punch_down_Up_Hooks
# 54125     0.390204        Punch_down_Up_Hooks
# 54126     0.429267        Punch_down_Up_Hooks
# 54127     0.419501        Punch_down_Up_Hooks
# 54128     0.443427        Punch_down_Up_Hooks
#
# [54129 rows x 6 columns]

# %%
elec
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Sample (V)  \
# 0                0          1614540810001538   -0.010564
# 1                1          1614540810005542   -0.010558
# 2                2          1614540810009546   -0.010564
# 3                3          1614540810013550   -0.010570
# 4                4          1614540810017554   -0.010570
# ...            ...                       ...         ...
# 429465      429465          1614544529981282   -0.010392
# 429466      429466          1614544529985287   -0.010226
# 429467      429467          1614544529989292   -0.010103
# 429468      429468          1614544529993297   -0.010170
# 429469      429469          1614544529997302   -0.010287
#
#                    Activity_Label
# 0       Forward and backward step
# 1       Forward and backward step
# 2       Forward and backward step
# 3       Forward and backward step
# 4       Forward and backward step
# ...                           ...
# 429465        Punch_down_Up_Hooks
# 429466        Punch_down_Up_Hooks
# 429467        Punch_down_Up_Hooks
# 429468        Punch_down_Up_Hooks
# 429469        Punch_down_Up_Hooks
#
# [429470 rows x 4 columns]

# %%
elec_ts = elec['Timestamp (microseconds)'].to_numpy()

# %%
elec_ts
# Out:
# array([1614540810001538, 1614540810005542, 1614540810009546, ...,
#        1614544529989292, 1614544529993297, 1614544529997302])

# %%
accel_ts = accel['Timestamp (microseconds)'].to_numpy()

# %%
accel_ts
# Out:
# array([1614540810021832, 1614540810053670, 1614540810085507, ...,
#        1614544529931323, 1614544529963089, 1614544529994855])

# %%
for i in range(len(accel_ts)):
    accel.at[i, 'Sample (V)'] = elec['Sample (V)'].iloc[np.argmin(abs(accel_ts[i] - elec_ts))]

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614540810021832     0.139223     0.923903
# 1               1          1614540810053670     0.129458     0.913649
# 2               2          1614540810085507     0.133852     0.915114
# 3               3          1614540810117345     0.121157     0.925856
# 4               4          1614540810149183     0.113832     0.917556
# ...           ...                       ...          ...          ...
# 54124       54124          1614544529867791     0.216861     0.669017
# 54125       54125          1614544529899557     0.204166     0.673411
# 54126       54126          1614544529931323     0.177798     0.710033
# 54127       54127          1614544529963089     0.147036     0.700755
# 54128       54128          1614544529994855     0.083070     0.706126
#
#        Accel Z (g)             Activity_Label  Sample (V)
# 0         0.393622  Forward and backward step   -0.010576
# 1         0.381415  Forward and backward step   -0.010589
# 2         0.402899  Forward and backward step   -0.010558
# 3         0.408759  Forward and backward step   -0.010583
# 4         0.387274  Forward and backward step   -0.010589
# ...            ...                        ...         ...
# 54124     0.375067        Punch_down_Up_Hooks   -0.010570
# 54125     0.390204        Punch_down_Up_Hooks   -0.010564
# 54126     0.429267        Punch_down_Up_Hooks   -0.010540
# 54127     0.419501        Punch_down_Up_Hooks   -0.010564
# 54128     0.443427        Punch_down_Up_Hooks   -0.010170
#
# [54129 rows x 7 columns]

# %%
ts = accel['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
accel['Time_elapse'] = ts1.tolist()

# %%
accel
# Out:
#        Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0               0          1614540810021832     0.139223     0.923903
# 1               1          1614540810053670     0.129458     0.913649
# 2               2          1614540810085507     0.133852     0.915114
# 3               3          1614540810117345     0.121157     0.925856
# 4               4          1614540810149183     0.113832     0.917556
# ...           ...                       ...          ...          ...
# 54124       54124          1614544529867791     0.216861     0.669017
# 54125       54125          1614544529899557     0.204166     0.673411
# 54126       54126          1614544529931323     0.177798     0.710033
# 54127       54127          1614544529963089     0.147036     0.700755
# 54128       54128          1614544529994855     0.083070     0.706126
#
#        Accel Z (g)             Activity_Label  Sample (V)  Time_elapse
# 0         0.393622  Forward and backward step   -0.010576     0.000000
# 1         0.381415  Forward and backward step   -0.010589     0.031838
# 2         0.402899  Forward and backward step   -0.010558     0.063675
# 3         0.408759  Forward and backward step   -0.010583     0.095513
# 4         0.387274  Forward and backward step   -0.010589     0.127351
# ...            ...                        ...         ...          ...
# 54124     0.375067        Punch_down_Up_Hooks   -0.010570  3719.845959
# 54125     0.390204        Punch_down_Up_Hooks   -0.010564  3719.877725
# 54126     0.429267        Punch_down_Up_Hooks   -0.010540  3719.909491
# 54127     0.419501        Punch_down_Up_Hooks   -0.010564  3719.941257
# 54128     0.443427        Punch_down_Up_Hooks   -0.010170  3719.973023
#
# [54129 rows x 8 columns]

# %%
accel.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
accel
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1614540810021832     0.139223     0.923903     0.393622
# 1              1614540810053670     0.129458     0.913649     0.381415
# 2              1614540810085507     0.133852     0.915114     0.402899
# 3              1614540810117345     0.121157     0.925856     0.408759
# 4              1614540810149183     0.113832     0.917556     0.387274
# ...                         ...          ...          ...          ...
# 54124          1614544529867791     0.216861     0.669017     0.375067
# 54125          1614544529899557     0.204166     0.673411     0.390204
# 54126          1614544529931323     0.177798     0.710033     0.429267
# 54127          1614544529963089     0.147036     0.700755     0.419501
# 54128          1614544529994855     0.083070     0.706126     0.443427
#
#                   Activity_Label  Sample (V)  Time_elapse
# 0      Forward and backward step   -0.010576     0.000000
# 1      Forward and backward step   -0.010589     0.031838
# 2      Forward and backward step   -0.010558     0.063675
# 3      Forward and backward step   -0.010583     0.095513
# 4      Forward and backward step   -0.010589     0.127351
# ...                          ...         ...          ...
# 54124        Punch_down_Up_Hooks   -0.010570  3719.845959
# 54125        Punch_down_Up_Hooks   -0.010564  3719.877725
# 54126        Punch_down_Up_Hooks   -0.010540  3719.909491
# 54127        Punch_down_Up_Hooks   -0.010564  3719.941257
# 54128        Punch_down_Up_Hooks   -0.010170  3719.973023
#
# [54129 rows x 7 columns]

# %%
#accel.to_csv('sub01_chest_accel+elec.csv', index = False)

# %%
# accel.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)
#accel

# %%
accel.to_csv('sub01_chest_accel+elec.csv', index = False)
