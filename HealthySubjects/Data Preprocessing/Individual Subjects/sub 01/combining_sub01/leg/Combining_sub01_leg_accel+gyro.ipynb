# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('final_cleaned_leg_accel-sub01.csv-sub01')
gyro = pd.read_csv('final_cleaned_leg_gyro-sub01.csv-sub01')

# %%
accel
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                0          1614540810014994    -0.967361    -0.116640
# 1                1          1614540810030969    -0.963088    -0.119814
# 2                2          1614540810046944    -0.967117    -0.119814
# 3                3          1614540810062919    -0.965774    -0.116274
# 4                4          1614540810078894    -0.962112    -0.117128
# ...            ...                       ...          ...          ...
# 107661      107661          1614544529935351    -0.740551    -0.235294
# 107662      107662          1614544529951324    -0.687083    -0.226993
# 107663      107663          1614544529967299    -0.703319    -0.225650
# 107664      107664          1614544529983273    -0.733104    -0.109560
# 107665      107665          1614544529999248    -0.737377    -0.034119
#
#         Accel Z (g)             Activity_Label
# 0          0.259586  Forward and backward step
# 1          0.258732  Forward and backward step
# 2          0.262272  Forward and backward step
# 3          0.267277  Forward and backward step
# 4          0.270573  Forward and backward step
# ...             ...                        ...
# 107661     0.554635        Punch_down_Up_Hooks
# 107662     0.491890        Punch_down_Up_Hooks
# 107663     0.532784        Punch_down_Up_Hooks
# 107664     0.511055        Punch_down_Up_Hooks
# 107665     0.478706        Punch_down_Up_Hooks
#
# [107666 rows x 6 columns]

# %%
gyro
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Gyro X (°/s)  Gyro Y (°/s)  \
# 0                0          1614540810014994      0.274662     -2.044709
# 1                1          1614540810030969      0.030518     -2.532998
# 2                2          1614540810046944     -0.213626     -2.899214
# 3                3          1614540810062919     -0.762951     -3.265431
# 4                4          1614540810078894     -1.007095     -3.692683
# ...            ...                       ...           ...           ...
# 107661      107661          1614544529935351      9.063859     11.566339
# 107662      107662          1614544529951324      9.918364      8.819715
# 107663      107663          1614544529967299     12.115663      9.002823
# 107664      107664          1614544529983273     26.459144      6.805524
# 107665      107665          1614544529999248     29.510948      4.486152
#
#         Gyro Z (°/s)             Activity_Label
# 0          -0.274662  Forward and backward step
# 1          -0.274662  Forward and backward step
# 2          -0.274662  Forward and backward step
# 3          -0.335698  Forward and backward step
# 4          -0.213626  Forward and backward step
# ...              ...                        ...
# 107661    -13.275349        Punch_down_Up_Hooks
# 107662    -14.435035        Punch_down_Up_Hooks
# 107663    -15.045396        Punch_down_Up_Hooks
# 107664    -14.312963        Punch_down_Up_Hooks
# 107665    -14.923323        Punch_down_Up_Hooks
#
# [107666 rows x 6 columns]

# %%
inner_df = accel.join(gyro.set_index('Timestamp (microseconds)'), on='Timestamp (microseconds)', how='inner', lsuffix='_left', rsuffix='_right')

# %%
inner_df
# Out:
#         Unnamed: 0_left  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                     0          1614540810014994    -0.967361    -0.116640
# 1                     1          1614540810030969    -0.963088    -0.119814
# 2                     2          1614540810046944    -0.967117    -0.119814
# 3                     3          1614540810062919    -0.965774    -0.116274
# 4                     4          1614540810078894    -0.962112    -0.117128
# ...                 ...                       ...          ...          ...
# 107661           107661          1614544529935351    -0.740551    -0.235294
# 107662           107662          1614544529951324    -0.687083    -0.226993
# 107663           107663          1614544529967299    -0.703319    -0.225650
# 107664           107664          1614544529983273    -0.733104    -0.109560
# 107665           107665          1614544529999248    -0.737377    -0.034119
#
#         Accel Z (g)        Activity_Label_left  Unnamed: 0_right  \
# 0          0.259586  Forward and backward step                 0
# 1          0.258732  Forward and backward step                 1
# 2          0.262272  Forward and backward step                 2
# 3          0.267277  Forward and backward step                 3
# 4          0.270573  Forward and backward step                 4
# ...             ...                        ...               ...
# 107661     0.554635        Punch_down_Up_Hooks            107661
# 107662     0.491890        Punch_down_Up_Hooks            107662
# 107663     0.532784        Punch_down_Up_Hooks            107663
# 107664     0.511055        Punch_down_Up_Hooks            107664
# 107665     0.478706        Punch_down_Up_Hooks            107665
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0           0.274662     -2.044709     -0.274662  Forward and backward step
# 1           0.030518     -2.532998     -0.274662  Forward and backward step
# 2          -0.213626     -2.899214     -0.274662  Forward and backward step
# 3          -0.762951     -3.265431     -0.335698  Forward and backward step
# 4          -1.007095     -3.692683     -0.213626  Forward and backward step
# ...              ...           ...           ...                        ...
# 107661      9.063859     11.566339    -13.275349        Punch_down_Up_Hooks
# 107662      9.918364      8.819715    -14.435035        Punch_down_Up_Hooks
# 107663     12.115663      9.002823    -15.045396        Punch_down_Up_Hooks
# 107664     26.459144      6.805524    -14.312963        Punch_down_Up_Hooks
# 107665     29.510948      4.486152    -14.923323        Punch_down_Up_Hooks
#
# [110796 rows x 11 columns]

# %%
inner_df.drop(['Activity_Label_left','Unnamed: 0_left','Unnamed: 0_right'], axis=1, inplace=True)

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614540810014994    -0.967361    -0.116640     0.259586
# 1               1614540810030969    -0.963088    -0.119814     0.258732
# 2               1614540810046944    -0.967117    -0.119814     0.262272
# 3               1614540810062919    -0.965774    -0.116274     0.267277
# 4               1614540810078894    -0.962112    -0.117128     0.270573
# ...                          ...          ...          ...          ...
# 107661          1614544529935351    -0.740551    -0.235294     0.554635
# 107662          1614544529951324    -0.687083    -0.226993     0.491890
# 107663          1614544529967299    -0.703319    -0.225650     0.532784
# 107664          1614544529983273    -0.733104    -0.109560     0.511055
# 107665          1614544529999248    -0.737377    -0.034119     0.478706
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0           0.274662     -2.044709     -0.274662  Forward and backward step
# 1           0.030518     -2.532998     -0.274662  Forward and backward step
# 2          -0.213626     -2.899214     -0.274662  Forward and backward step
# 3          -0.762951     -3.265431     -0.335698  Forward and backward step
# 4          -1.007095     -3.692683     -0.213626  Forward and backward step
# ...              ...           ...           ...                        ...
# 107661      9.063859     11.566339    -13.275349        Punch_down_Up_Hooks
# 107662      9.918364      8.819715    -14.435035        Punch_down_Up_Hooks
# 107663     12.115663      9.002823    -15.045396        Punch_down_Up_Hooks
# 107664     26.459144      6.805524    -14.312963        Punch_down_Up_Hooks
# 107665     29.510948      4.486152    -14.923323        Punch_down_Up_Hooks
#
# [110796 rows x 8 columns]

# %%
ts = inner_df['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
inner_df['Time_elapse'] = ts1.tolist()

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614540810014994    -0.967361    -0.116640     0.259586
# 1               1614540810030969    -0.963088    -0.119814     0.258732
# 2               1614540810046944    -0.967117    -0.119814     0.262272
# 3               1614540810062919    -0.965774    -0.116274     0.267277
# 4               1614540810078894    -0.962112    -0.117128     0.270573
# ...                          ...          ...          ...          ...
# 107661          1614544529935351    -0.740551    -0.235294     0.554635
# 107662          1614544529951324    -0.687083    -0.226993     0.491890
# 107663          1614544529967299    -0.703319    -0.225650     0.532784
# 107664          1614544529983273    -0.733104    -0.109560     0.511055
# 107665          1614544529999248    -0.737377    -0.034119     0.478706
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right  \
# 0           0.274662     -2.044709     -0.274662  Forward and backward step
# 1           0.030518     -2.532998     -0.274662  Forward and backward step
# 2          -0.213626     -2.899214     -0.274662  Forward and backward step
# 3          -0.762951     -3.265431     -0.335698  Forward and backward step
# 4          -1.007095     -3.692683     -0.213626  Forward and backward step
# ...              ...           ...           ...                        ...
# 107661      9.063859     11.566339    -13.275349        Punch_down_Up_Hooks
# 107662      9.918364      8.819715    -14.435035        Punch_down_Up_Hooks
# 107663     12.115663      9.002823    -15.045396        Punch_down_Up_Hooks
# 107664     26.459144      6.805524    -14.312963        Punch_down_Up_Hooks
# 107665     29.510948      4.486152    -14.923323        Punch_down_Up_Hooks
#
#         Time_elapse
# 0          0.000000
# 1          0.015975
# 2          0.031950
# 3          0.047925
# 4          0.063900
# ...             ...
# 107661  3719.920357
# 107662  3719.936330
# 107663  3719.952305
# 107664  3719.968279
# 107665  3719.984254
#
# [110796 rows x 9 columns]

# %%
# inner_df.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)

# %%
# inner_df

# %%
inner_df.to_csv('sub01_leg_accel+gyro.csv', index = False)
