# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('/Users/shreyasaswar/HARDataset/EXTRACTION/Sub06/leg/cleaned/final_cleaned_leg_accel-sub06.csv-sub06')
gyro = pd.read_csv('/Users/shreyasaswar/HARDataset/EXTRACTION/Sub06/leg/cleaned/final_cleaned_leg_gyro-sub06.csv-sub06')

# %%
accel
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                0          1614702011013816    -1.024002     0.037171
# 1                1          1614702011029790    -1.007645     0.029358
# 2                2          1614702011045765    -0.987747     0.043275
# 3                3          1614702011061739    -0.962112     0.054505
# 4                4          1614702011077714    -0.936843     0.074647
# ...            ...                       ...          ...          ...
# 108288      108288          1614707345935329    -0.976028     0.417670
# 108289      108289          1614707345951304    -1.003128     0.457099
# 108290      108290          1614707345967279    -0.875074     0.457710
# 108291      108291          1614707345983254    -0.822950     0.355779
# 108292      108292          1614707345999229    -0.919631     0.205631
#
#         Accel Z (g)             Activity_Label
# 0          0.053773  Forward and backward step
# 1          0.070863  Forward and backward step
# 2          0.089784  Forward and backward step
# 3          0.134707  Forward and backward step
# 4          0.206729  Forward and backward step
# ...             ...                        ...
# 108288     0.460639        Punch_down_Up_Hooks
# 108289     0.487861        Punch_down_Up_Hooks
# 108290     0.488350        Punch_down_Up_Hooks
# 108291     0.470649        Punch_down_Up_Hooks
# 108292     0.361883        Punch_down_Up_Hooks
#
# [108293 rows x 6 columns]

# %%
gyro
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Gyro X (°/s)  Gyro Y (°/s)  \
# 0                0          1614702011013816     -2.532998    -14.251926
# 1                1          1614702011029790     -1.678492    -16.876478
# 2                2          1614702011045765     -0.823987    -18.524453
# 3                3          1614702011061739     -1.556420    -17.975128
# 4                4          1614702011077714     -0.396735    -14.984360
# ...            ...                       ...           ...           ...
# 108290      108290          1614707345935329     32.318608     19.378958
# 108291      108291          1614707345951304     31.525139     28.961624
# 108292      108292          1614707345967279     17.975128     36.896315
# 108293      108293          1614707345983254      3.387503     42.694743
# 108294      108294          1614707345999229      8.941787     48.981460
#
#         Gyro Z (°/s)             Activity_Label
# 0          13.275349  Forward and backward step
# 1          13.336385  Forward and backward step
# 2          11.688411  Forward and backward step
# 3           9.735256  Forward and backward step
# 4           7.904173  Forward and backward step
# ...              ...                        ...
# 108290      9.552148        Punch_down_Up_Hooks
# 108291      5.951019        Punch_down_Up_Hooks
# 108292      0.213626        Punch_down_Up_Hooks
# 108293     -9.857328        Punch_down_Up_Hooks
# 108294    -14.435035        Punch_down_Up_Hooks
#
# [108295 rows x 6 columns]

# %%
inner_df = accel.join(gyro.set_index('Timestamp (microseconds)'), on='Timestamp (microseconds)', how='inner', lsuffix='_left', rsuffix='_right')

# %%
inner_df
# Out:
#         Unnamed: 0_left  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                     0          1614702011013816    -1.024002     0.037171
# 1                     1          1614702011029790    -1.007645     0.029358
# 2                     2          1614702011045765    -0.987747     0.043275
# 3                     3          1614702011061739    -0.962112     0.054505
# 4                     4          1614702011077714    -0.936843     0.074647
# ...                 ...                       ...          ...          ...
# 108288           108288          1614707345935329    -0.976028     0.417670
# 108289           108289          1614707345951304    -1.003128     0.457099
# 108290           108290          1614707345967279    -0.875074     0.457710
# 108291           108291          1614707345983254    -0.822950     0.355779
# 108292           108292          1614707345999229    -0.919631     0.205631
#
#         Accel Z (g)        Activity_Label_left  Unnamed: 0_right  \
# 0          0.053773  Forward and backward step                 0
# 1          0.070863  Forward and backward step                 1
# 2          0.089784  Forward and backward step                 2
# 3          0.134707  Forward and backward step                 3
# 4          0.206729  Forward and backward step                 4
# ...             ...                        ...               ...
# 108288     0.460639        Punch_down_Up_Hooks            108290
# 108289     0.487861        Punch_down_Up_Hooks            108291
# 108290     0.488350        Punch_down_Up_Hooks            108292
# 108291     0.470649        Punch_down_Up_Hooks            108293
# 108292     0.361883        Punch_down_Up_Hooks            108294
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          -2.532998    -14.251926     13.275349  Forward and backward step
# 1          -1.678492    -16.876478     13.336385  Forward and backward step
# 2          -0.823987    -18.524453     11.688411  Forward and backward step
# 3          -1.556420    -17.975128      9.735256  Forward and backward step
# 4          -0.396735    -14.984360      7.904173  Forward and backward step
# ...              ...           ...           ...                        ...
# 108288     32.318608     19.378958      9.552148        Punch_down_Up_Hooks
# 108289     31.525139     28.961624      5.951019        Punch_down_Up_Hooks
# 108290     17.975128     36.896315      0.213626        Punch_down_Up_Hooks
# 108291      3.387503     42.694743     -9.857328        Punch_down_Up_Hooks
# 108292      8.941787     48.981460    -14.435035        Punch_down_Up_Hooks
#
# [108293 rows x 11 columns]

# %%
inner_df.drop(['Activity_Label_left','Unnamed: 0_left','Unnamed: 0_right'], axis=1, inplace=True)

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614702011013816    -1.024002     0.037171     0.053773
# 1               1614702011029790    -1.007645     0.029358     0.070863
# 2               1614702011045765    -0.987747     0.043275     0.089784
# 3               1614702011061739    -0.962112     0.054505     0.134707
# 4               1614702011077714    -0.936843     0.074647     0.206729
# ...                          ...          ...          ...          ...
# 108288          1614707345935329    -0.976028     0.417670     0.460639
# 108289          1614707345951304    -1.003128     0.457099     0.487861
# 108290          1614707345967279    -0.875074     0.457710     0.488350
# 108291          1614707345983254    -0.822950     0.355779     0.470649
# 108292          1614707345999229    -0.919631     0.205631     0.361883
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# 0          -2.532998    -14.251926     13.275349  Forward and backward step
# 1          -1.678492    -16.876478     13.336385  Forward and backward step
# 2          -0.823987    -18.524453     11.688411  Forward and backward step
# 3          -1.556420    -17.975128      9.735256  Forward and backward step
# 4          -0.396735    -14.984360      7.904173  Forward and backward step
# ...              ...           ...           ...                        ...
# 108288     32.318608     19.378958      9.552148        Punch_down_Up_Hooks
# 108289     31.525139     28.961624      5.951019        Punch_down_Up_Hooks
# 108290     17.975128     36.896315      0.213626        Punch_down_Up_Hooks
# 108291      3.387503     42.694743     -9.857328        Punch_down_Up_Hooks
# 108292      8.941787     48.981460    -14.435035        Punch_down_Up_Hooks
#
# [108293 rows x 8 columns]

# %%
ts = inner_df['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
inner_df['Time_elapse'] = ts1.tolist()

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614702011013816    -1.024002     0.037171     0.053773
# 1               1614702011029790    -1.007645     0.029358     0.070863
# 2               1614702011045765    -0.987747     0.043275     0.089784
# 3               1614702011061739    -0.962112     0.054505     0.134707
# 4               1614702011077714    -0.936843     0.074647     0.206729
# ...                          ...          ...          ...          ...
# 108288          1614707345935329    -0.976028     0.417670     0.460639
# 108289          1614707345951304    -1.003128     0.457099     0.487861
# 108290          1614707345967279    -0.875074     0.457710     0.488350
# 108291          1614707345983254    -0.822950     0.355779     0.470649
# 108292          1614707345999229    -0.919631     0.205631     0.361883
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right  \
# 0          -2.532998    -14.251926     13.275349  Forward and backward step
# 1          -1.678492    -16.876478     13.336385  Forward and backward step
# 2          -0.823987    -18.524453     11.688411  Forward and backward step
# 3          -1.556420    -17.975128      9.735256  Forward and backward step
# 4          -0.396735    -14.984360      7.904173  Forward and backward step
# ...              ...           ...           ...                        ...
# 108288     32.318608     19.378958      9.552148        Punch_down_Up_Hooks
# 108289     31.525139     28.961624      5.951019        Punch_down_Up_Hooks
# 108290     17.975128     36.896315      0.213626        Punch_down_Up_Hooks
# 108291      3.387503     42.694743     -9.857328        Punch_down_Up_Hooks
# 108292      8.941787     48.981460    -14.435035        Punch_down_Up_Hooks
#
#         Time_elapse
# 0          0.000000
# 1          0.015974
# 2          0.031949
# 3          0.047923
# 4          0.063898
# ...             ...
# 108288  5334.921513
# 108289  5334.937488
# 108290  5334.953463
# 108291  5334.969438
# 108292  5334.985413
#
# [108293 rows x 9 columns]

# %%
# inner_df.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)

# %%
# inner_df

# %%
inner_df.to_csv('sub06_leg_accel+gyro.csv', index = False)
