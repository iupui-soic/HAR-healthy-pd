# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
accel = pd.read_csv('/Users/shreyasaswar/HARDataset/EXTRACTION/Sub06/hand/cleaned data/final_cleaned_hand_accel-sub06.csv-sub06')
gyro = pd.read_csv('/Users/shreyasaswar/HARDataset/EXTRACTION/Sub06/hand/cleaned data/final_cleaned_hand_gyro-sub06.csv-sub06')

# %%
accel
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                0          1614702011015704     0.410590     0.185000
# 1                1          1614702011031703     0.395819     0.182803
# 2                2          1614702011047702     0.389593     0.167666
# 3                3          1614702011063702     0.385443     0.204166
# 4                4          1614702011079701     0.401068     0.276188
# ...            ...                       ...          ...          ...
# 108117      108117          1614707345923193    -4.000000     0.423651
# 108118      108118          1614707345939192     1.408286     0.285954
# 108119      108119          1614707345955191     2.343847     1.732998
# 108120      108120          1614707345971191     0.033875     0.259953
# 108121      108121          1614707345987190    -1.066850    -0.609323
#
#         Accel Z (g)             Activity_Label
# 0         -0.741650  Forward and backward step
# ...

# %%
gyro
# Out:
#         Unnamed: 0  Timestamp (microseconds)  Gyro X (°/s)  Gyro Y (°/s)  \
# 0                0          1614702011015704    -23.651484     65.400168
# 1                1          1614702011031703    -23.956664     51.911192
# 2                2          1614702011047702    -20.355535     35.248341
# 3                3          1614702011063702    -12.237736     18.402380
# 4                4          1614702011079701     -5.767910      3.570611
# ...            ...                       ...           ...           ...
# 108125      108125          1614707345923193    -75.959411   -106.721599
# 108126      108126          1614707345939192      0.152590   -211.581598
# 108127      108127          1614707345955191    -37.750820   -211.093309
# 108128      108128          1614707345971191   -196.688792    -86.945907
# 108129      108129          1614707345987190    -82.795453    -26.031891
#
#         Gyro Z (°/s)             Activity_Label
# ...

# %%
inner_df = accel.join(gyro.set_index('Timestamp (microseconds)'), on='Timestamp (microseconds)', how='inner', lsuffix='_left', rsuffix='_right')

# %%
inner_df
# Out:
#         Unnamed: 0_left  Timestamp (microseconds)  Accel X (g)  Accel Y (g)  \
# 0                     0          1614702011015704     0.410590     0.185000
# 1                     1          1614702011031703     0.395819     0.182803
# 2                     2          1614702011047702     0.389593     0.167666
# 3                     3          1614702011063702     0.385443     0.204166
# 4                     4          1614702011079701     0.401068     0.276188
# ...                 ...                       ...          ...          ...
# 108117           108117          1614707345923193    -4.000000     0.423651
# 108118           108118          1614707345939192     1.408286     0.285954
# 108119           108119          1614707345955191     2.343847     1.732998
# 108120           108120          1614707345971191     0.033875     0.259953
# 108121           108121          1614707345987190    -1.066850    -0.609323
#
# ...

# %%
inner_df.drop(['Activity_Label_left','Unnamed: 0_left','Unnamed: 0_right'], axis=1, inplace=True)

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614702011015704     0.410590     0.185000    -0.741650
# 1               1614702011031703     0.395819     0.182803    -0.754711
# 2               1614702011047702     0.389593     0.167666    -0.764233
# 3               1614702011063702     0.385443     0.204166    -0.765454
# 4               1614702011079701     0.401068     0.276188    -0.768994
# ...                          ...          ...          ...          ...
# 108117          1614707345923193    -4.000000     0.423651     1.068559
# 108118          1614707345939192     1.408286     0.285954     0.859937
# 108119          1614707345955191     2.343847     1.732998     0.320256
# 108120          1614707345971191     0.033875     0.259953     0.912917
# 108121          1614707345987190    -1.066850    -0.609323     1.405722
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right
# ...

# %%
ts = inner_df['Timestamp (microseconds)'].to_numpy()
ts1 = ((ts - ts[0])*1e-6)

# %%
inner_df['Time_elapse'] = ts1.tolist()

# %%
inner_df
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1614702011015704     0.410590     0.185000    -0.741650
# 1               1614702011031703     0.395819     0.182803    -0.754711
# 2               1614702011047702     0.389593     0.167666    -0.764233
# 3               1614702011063702     0.385443     0.204166    -0.765454
# 4               1614702011079701     0.401068     0.276188    -0.768994
# ...                          ...          ...          ...          ...
# 108117          1614707345923193    -4.000000     0.423651     1.068559
# 108118          1614707345939192     1.408286     0.285954     0.859937
# 108119          1614707345955191     2.343847     1.732998     0.320256
# 108120          1614707345971191     0.033875     0.259953     0.912917
# 108121          1614707345987190    -1.066850    -0.609323     1.405722
#
#         Gyro X (°/s)  Gyro Y (°/s)  Gyro Z (°/s)       Activity_Label_right  \
# ...

# %%
# inner_df.drop(['Timestamp (microseconds)'], axis = 1, inplace = True)

# %%
# inner_df

# %%
inner_df.to_csv('sub06_hand_accel+gyro.csv', index = False)
