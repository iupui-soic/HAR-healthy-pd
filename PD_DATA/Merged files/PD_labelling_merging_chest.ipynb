# %%
#merging accel and sample into single subject chest data

# %%
from datetime import datetime
import time
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('pd1-accel-chest.csv')
df2 = pd.read_csv('pd1-elec-chest.csv')

# %%
PD1_elec = df2['Timestamp (microseconds)'].to_numpy()
PD1_elec
# Out:
# array([1613574061641754, 1613574061645757, 1613574061649760, ...,
#        1613575964403077, 1613575964407081, 1613575964411086])

# %%
PD1_accel = df['Timestamp (microseconds)'].to_numpy()
PD1_accel
# Out:
# array([1613574061624023, 1613574061656002, 1613574061687981, ...,
#        1613575963300908, 1613575963332791, 1613575963364674])

# %%
for i in range(len(PD1_accel)):
    df.at[i, 'Sample (V)'] = df2['Sample (V)'].iloc[np.argmin(abs(PD1_accel[i] - PD1_elec))]

# %%
df
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1613574061624023     0.157290     0.854566     0.031312
# 1              1613574061656002     0.257389     0.852125    -0.852979
# 2              1613574061687981     0.153872     0.762768    -0.523384
# 3              1613574061719960    -0.022889     0.865309     0.048402
# 4              1613574061751939    -0.139590     1.260822    -0.186465
# ...                         ...          ...          ...          ...
# 59635          1613575963237143     0.555734     0.767163    -0.285588
# 59636          1613575963269025     0.546456     0.788159    -0.317815
# 59637          1613575963300908     0.526925     0.784253    -0.301213
# 59638          1613575963332791     0.528878     0.789624    -0.291447
# 59639          1613575963364674     0.537179     0.801831    -0.267033
#
#        Sample (V)
# 0       -0.007450
# 1       -0.011377
# 2       -0.028252
# 3        0.002354
# ...

# %%
PD1_chest = df

# %%
#Data filtering and adding labels

# %%
print(PD1_chest['Timestamp (microseconds)'][0])
pd.Timestamp(PD1_chest['Timestamp (microseconds)'][0], unit='us', tz="US/Eastern")
# Out:
# 1613574061624023
# Timestamp('2021-02-17 10:01:01.624023-0500', tz='US/Eastern')

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 17, second = 6, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 18, second = 1, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

MedicineBall = PD1_chest.loc[(PD1_chest['Timestamp (microseconds)'] >= start_ts) & (PD1_chest['Timestamp (microseconds)'] <= end_ts)]

MedicineBall['Activity_Label'] = 'Medicine Ball'
MedicineBall
# Out:
# /tmp/ipykernel_24612/2170693050.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MedicineBall['Activity_Label'] = 'Medicine Ball'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 30233          1613575026030946    -0.027771     0.902419    -0.315862
# 30234          1613575026062884    -0.011170     0.953689    -0.340276
# 30235          1613575026094822    -0.026307     0.907790    -0.341253
# 30236          1613575026126760    -0.049744     0.877028    -0.303166
# 30237          1613575026158698    -0.020447     0.885817    -0.337346
# ...                         ...          ...          ...          ...
# 31950          1613575080851367    -0.033143     0.955642    -0.296330
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 18, second = 17, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 18, second = 58, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

Burpees = PD1_chest.loc[(PD1_chest['Timestamp (microseconds)'] >= start_ts) & (PD1_chest['Timestamp (microseconds)'] <= end_ts)]

Burpees['Activity_Label'] = 'Burpees'
Burpees
# Out:
# /tmp/ipykernel_24612/1089508732.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Burpees['Activity_Label'] = 'Burpees'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 32457          1613575097030255    -0.367132     0.832593    -0.613718
# 32458          1613575097062167    -0.338323     0.797925    -0.622019
# 32459          1613575097094078    -0.314397     0.832105    -0.548775
# 32460          1613575097125990    -0.267521     0.847730    -0.499458
# 32461          1613575097157901    -0.203555     0.803296    -0.426215
# ...                         ...          ...          ...          ...
# 33737          1613575137858260     0.297429     0.853101     0.464424
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 19, second = 10, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 20, second = 13, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

FBstep = PD1_chest.loc[(PD1_chest['Timestamp (microseconds)'] >= start_ts) & (PD1_chest['Timestamp (microseconds)'] <= end_ts)]

FBstep ['Activity_Label'] = 'FBstep'
FBstep
# Out:
# /tmp/ipykernel_24612/3262189589.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FBstep ['Activity_Label'] = 'FBstep'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 34118          1613575150004105     0.130922     0.948318     0.173404
# 34119          1613575150035986     0.123598     0.954177     0.189029
# 34120          1613575150067840     0.109926     0.984451     0.196841
# 34121          1613575150099721     0.102602     0.987381     0.185122
# 34122          1613575150131601     0.117739     0.993729     0.184634
# ...                         ...          ...          ...          ...
# 36090          1613575212870540    -0.038025     0.907790     0.195377
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 20, second = 15, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 21, second = 12, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

sidestep = PD1_chest.loc[(PD1_chest['Timestamp (microseconds)'] >= start_ts) & (PD1_chest['Timestamp (microseconds)'] <= end_ts)]

sidestep ['Activity_Label'] = 'sidestep'
sidestep
# Out:
# /tmp/ipykernel_24612/2300420855.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sidestep ['Activity_Label'] = 'sidestep'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 36157          1613575215006635    -0.065858     0.949783     0.121157
# 36158          1613575215038517    -0.088319     0.910231     0.013733
# 36159          1613575215070398    -0.099550     1.065995     0.117250
# 36160          1613575215102386    -0.117617     0.978103     0.108949
# 36161          1613575215134268    -0.114199     0.990799     0.111879
# ...                         ...          ...          ...          ...
# 37940          1613575271858759     0.216861     0.967849     0.162173
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 21, second = 32, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 22, second = 28, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

scooter = PD1_chest.loc[(PD1_chest['Timestamp (microseconds)'] >= start_ts) & (PD1_chest['Timestamp (microseconds)'] <= end_ts)]

scooter ['Activity_Label'] = 'scooter'
scooter
# Out:
# /tmp/ipykernel_24612/75901605.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scooter ['Activity_Label'] = 'scooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 38572          1613575292013849    -0.210880     0.729564    -0.664500
# 38573          1613575292045739    -0.178653     0.738842    -0.664012
# 38574          1613575292077630    -0.178164     0.744213    -0.670848
# 38575          1613575292109520    -0.191348     0.726635    -0.663035
# 38576          1613575292141410    -0.202579     0.721752    -0.704051
# ...                         ...          ...          ...          ...
# 40323          1613575347849285     0.080629     0.802808     0.545480
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 23, second = 3, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 23, second = 28, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

bellyscooter = PD1_chest.loc[(PD1_chest['Timestamp (microseconds)'] >= start_ts) & (PD1_chest['Timestamp (microseconds)'] <= end_ts)]

bellyscooter ['Activity_Label'] = 'bellyscooter'
bellyscooter
# Out:
# /tmp/ipykernel_24612/1929067945.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bellyscooter ['Activity_Label'] = 'bellyscooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 41426          1613575383010717    -0.162539     0.466377    -0.780713
# 41427          1613575383042592    -0.122499     0.416083    -0.751415
# 41428          1613575383074466    -0.122988     0.621653    -0.726513
# 41429          1613575383106341    -0.216251     0.531807    -0.873976
# 41430          1613575383138216    -0.178653     0.538155    -1.002396
# ...                         ...          ...          ...          ...
# 42206          1613575407867813     0.105531     0.657786    -0.810010
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 23, second = 42, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 24, second = 26, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

circularscooter = PD1_chest.loc[(PD1_chest['Timestamp (microseconds)'] >= start_ts) & (PD1_chest['Timestamp (microseconds)'] <= end_ts)]

circularscooter ['Activity_Label'] = 'circularscooter'
circularscooter
# Out:
# /tmp/ipykernel_24612/33242059.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   circularscooter ['Activity_Label'] = 'circularscooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 42650          1613575422016327    -0.162051     0.814527    -0.538033
# 42651          1613575422048194    -0.208927     0.799390    -0.560494
# 42652          1613575422080061    -0.249943     0.796460    -0.542916
# 42653          1613575422111927    -0.238712     0.799390    -0.578073
# 42654          1613575422143794    -0.232853     0.809644    -0.467720
# ...                         ...          ...          ...          ...
# 44026          1613575465867888    -0.079530     0.727611    -0.796338
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 25, second = 0, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 25, second = 48, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

kneescooter = PD1_chest.loc[(PD1_chest['Timestamp (microseconds)'] >= start_ts) & (PD1_chest['Timestamp (microseconds)'] <= end_ts)]

kneescooter ['Activity_Label'] = 'kneescooter'
kneescooter
# Out:
# /tmp/ipykernel_24612/1011998313.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kneescooter ['Activity_Label'] = 'kneescooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 45097          1613575500012724    -0.105898     0.813062    -0.509224
# 45098          1613575500044606    -0.102968     0.815503    -0.511666
# 45099          1613575500076488    -0.080018     0.802319    -0.566842
# 45100          1613575500108369    -0.056580     0.790600    -0.582956
# 45101          1613575500140251    -0.083436     0.800366    -0.541939
# ...                         ...          ...          ...          ...
# 46598          1613575547854684     0.002991     0.905837    -0.428168
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 28, second = 45, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 29, second = 16, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

Boxing1 = PD1_chest.loc[(PD1_chest['Timestamp (microseconds)'] >= start_ts) & (PD1_chest['Timestamp (microseconds)'] <= end_ts)]

Boxing1 ['Activity_Label'] = 'Boxing1'
Boxing1
# Out:
# /tmp/ipykernel_24612/3518129661.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Boxing1 ['Activity_Label'] = 'Boxing1'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 52161          1613575725030166     0.100649     0.972732     0.137758
# 52162          1613575725062010     0.090883     0.983963     0.108461
# 52163          1613575725093855     0.080140     1.040116     0.103090
# 52164          1613575725125700     0.081117     1.028397     0.106020
# 52165          1613575725157544     0.059144     1.005936     0.086000
# ...                         ...          ...          ...          ...
# 53129          1613575755861808    -0.023377     1.013748    -0.081483
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 29, second = 31, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 30, second = 0, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

Roundboxing = PD1_chest.loc[(PD1_chest['Timestamp (microseconds)'] >= start_ts) & (PD1_chest['Timestamp (microseconds)'] <= end_ts)]

Roundboxing ['Activity_Label'] = 'Roundboxing'
Roundboxing
# Out:
# /tmp/ipykernel_24612/4207808505.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Roundboxing ['Activity_Label'] = 'Roundboxing'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 53605          1613575771026815     0.176333     1.110430    -0.322698
# 53606          1613575771058673    -0.079530     1.195880     0.572335
# 53607          1613575771090532    -0.274357     1.282795     0.202213
# 53608          1613575771122390    -0.197696     0.858473     0.090394
# 53609          1613575771154249     0.113832     1.351156     0.273991
# ...                         ...          ...          ...          ...
# 54510          1613575799863194    -0.101015     0.850660     0.126528
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 30, second = 31, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 30, second = 40, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

LRboxing = PD1_chest.loc[(PD1_chest['Timestamp (microseconds)'] >= start_ts) & (PD1_chest['Timestamp (microseconds)'] <= end_ts)]

LRboxing ['Activity_Label'] = 'LRboxing'
LRboxing
# Out:
# /tmp/ipykernel_24612/188841643.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LRboxing ['Activity_Label'] = 'LRboxing'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 55487          1613575831000928    -0.257267     1.325765     0.374578
# 55488          1613575831032798    -0.243595     0.883375     0.193423
# 55489          1613575831064669    -0.070253     1.024979     0.195865
# 55490          1613575831096540     0.050843     1.083085     0.350164
# 55491          1613575831128411    -0.027771     1.042557     0.153872
# ...                         ...          ...          ...          ...
# 55765          1613575839861509     0.071351     0.564523    -0.030701
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 31, second = 0, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 31, second = 30, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing4 = PD1_chest.loc[(PD1_chest['Timestamp (microseconds)'] >= start_ts) & (PD1_chest['Timestamp (microseconds)'] <= end_ts)]

boxing4 ['Activity_Label'] = 'boxing4'
boxing4
# Out:
# /tmp/ipykernel_24612/1228581117.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing4 ['Activity_Label'] = 'boxing4'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 56397          1613575860007034     0.123598     0.944900     0.285710
# 56398          1613575860038910     0.117250     0.942458     0.262760
# 56399          1613575860070785     0.120180     0.951247     0.327703
# 56400          1613575860102630     0.115785     0.941970     0.286198
# 56401          1613575860134506     0.121645     0.965408     0.337957
# ...                         ...          ...          ...          ...
# 57333          1613575889842301    -0.185489     0.874098     0.096254
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 31, second = 51, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 10, minute = 32, second = 16, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing5 = PD1_chest.loc[(PD1_chest['Timestamp (microseconds)'] >= start_ts) & (PD1_chest['Timestamp (microseconds)'] <= end_ts)]

boxing5 ['Activity_Label'] = 'boxing5'
boxing5
# Out:
# /tmp/ipykernel_24612/647239946.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing5 ['Activity_Label'] = 'boxing5'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 57997          1613575911012006     0.081605     0.990311     0.230533
# 57998          1613575911043888     0.083070     0.980545     0.232975
# 57999          1613575911075769     0.082582     0.969802     0.216373
# 58000          1613575911107696     0.080629     0.976638     0.251041
# 58001          1613575911139578     0.069398     0.970291     0.212467
# ...                         ...          ...          ...          ...
# 58776          1613575935848693     0.073793     0.938064     0.066957
# ...

# %%
#merging all the activities
merged_PD1_chest = pd.concat([MedicineBall, Burpees, FBstep, sidestep, scooter, bellyscooter, circularscooter, kneescooter, Boxing1, Roundboxing, LRboxing, boxing4, boxing5], ignore_index=True)
merged_PD1_chest
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1613575026030946    -0.027771     0.902419    -0.315862
# 1              1613575026062884    -0.011170     0.953689    -0.340276
# 2              1613575026094822    -0.026307     0.907790    -0.341253
# 3              1613575026126760    -0.049744     0.877028    -0.303166
# 4              1613575026158698    -0.020447     0.885817    -0.337346
# ...                         ...          ...          ...          ...
# 16086          1613575935848693     0.073793     0.938064     0.066957
# 16087          1613575935880577     0.278386     0.976638    -0.074647
# 16088          1613575935912460     0.268620     1.026444     0.013245
# 16089          1613575935944343     0.189029     0.976150    -0.003845
# 16090          1613575935976226     0.073793     1.011307     0.052308
#
#        Sample (V) Activity_Label
# 0       -0.006521  Medicine Ball
# 1       -0.007868  Medicine Ball
# ...

# %%
#combined(accel+elec) .csv
merged_PD1_chest.to_csv('PD1chest.csv', sep=',',  index = False)

# %% [markdown]
# # PD2 Chest

# %%
PD2_chest = pd.read_csv('pd2-accel-chest.csv')
PD2_elec = pd.read_csv('pd2-elec-chest.csv')
pd2a = PD2_chest['Timestamp (microseconds)'].to_numpy()
pd2e = PD2_elec['Timestamp (microseconds)'].to_numpy()
for i in range(len(PD2_chest)):
    PD2_chest.at[i, 'Sample (V)'] = PD2_elec['Sample (V)'].iloc[np.argmin(abs(pd2a[i] - pd2e))]
PD2_chest
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1613587698018921    -0.997513    -0.040467     0.250553
# 1              1613587698050892    -1.011185    -0.037049     0.304753
# 2              1613587698082862    -1.001907    -0.028748     0.330144
# 3              1613587698114833    -1.014115    -0.028748     0.298894
# 4              1613587698146804    -0.987259    -0.059998     0.326726
# ...                         ...          ...          ...          ...
# 26555          1613588541719384     0.526925    -0.245060     0.830152
# 26556          1613588541751146     0.519600    -0.241642     0.822339
# 26557          1613588541782908     0.519112    -0.245060     0.831617
# 26558          1613588541814669     0.526925    -0.256779     0.844800
# 26559          1613588541846431     0.516670    -0.272404     0.841382
#
#        Sample (V)
# 0       -0.007979
# 1       -0.006896
# 2       -0.006428
# 3       -0.005998
# ...

# %%
print(PD2_chest['Timestamp (microseconds)'][0])
pd.Timestamp(PD2_chest['Timestamp (microseconds)'][0], unit='us', tz="US/Eastern")
# Out:
# 1613587698018921
# Timestamp('2021-02-17 13:48:18.018921-0500', tz='US/Eastern')

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 50, second = 38, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 51, second = 42, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

MedicineBall = PD2_chest.loc[(PD2_chest['Timestamp (microseconds)'] >= start_ts) & (PD2_chest['Timestamp (microseconds)'] <= end_ts)]

MedicineBall['Activity_Label'] = 'Medicine Ball'
MedicineBall
# Out:
# /tmp/ipykernel_24612/2825938554.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MedicineBall['Activity_Label'] = 'Medicine Ball'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 4404          1613587838001192    -0.988235    -0.078065     0.316472
# 4405          1613587838032984    -0.987259    -0.036561     0.327703
# 4406          1613587838064776    -0.981399    -0.035584     0.330632
# 4407          1613587838096568    -0.995560    -0.055116     0.370672
# 4408          1613587838128360    -0.968704    -0.091249     0.342840
# ...                        ...          ...          ...          ...
# 6413          1613587901863528    -0.949660     0.043030     0.337957
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 51, second = 54, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 52, second = 40, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

Burpees = PD2_chest.loc[(PD2_chest['Timestamp (microseconds)'] >= start_ts) & (PD2_chest['Timestamp (microseconds)'] <= end_ts)]

Burpees['Activity_Label'] = 'Burpees'
Burpees
# Out:
# /tmp/ipykernel_24612/3259976120.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Burpees['Activity_Label'] = 'Burpees'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 6795          1613587914004559    -0.745068    -0.162539     0.777905
# 6796          1613587914036342    -0.717235    -0.141054     0.780835
# 6797          1613587914068125    -0.701610    -0.135683     0.744213
# 6798          1613587914099908    -0.717723    -0.147402     0.689525
# 6799          1613587914131692    -0.701122    -0.219181     0.637278
# ...                        ...          ...          ...          ...
# 8238          1613587959862502    -1.367147    -0.058045     0.877516
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 53, second = 6, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 54, second = 2, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

FBstep = PD2_chest.loc[(PD2_chest['Timestamp (microseconds)'] >= start_ts) & (PD2_chest['Timestamp (microseconds)'] <= end_ts)]

FBstep ['Activity_Label'] = 'FBstep'
FBstep
# Out:
# /tmp/ipykernel_24612/1107019015.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FBstep ['Activity_Label'] = 'FBstep'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 9061           1613587986015571    -0.937453     0.114809     0.346746
# 9062           1613587986047349    -0.948684     0.138247     0.290593
# 9063           1613587986079126    -0.968704     0.121157     0.252506
# 9064           1613587986110904    -1.005325     0.182193     0.251530
# 9065           1613587986142682    -0.971633     0.220279     0.350164
# ...                         ...          ...          ...          ...
# 10818          1613588041845897    -0.906691     0.010803     0.419989
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 54, second = 10, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 54, second = 56, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

sidestep = PD2_chest.loc[(PD2_chest['Timestamp (microseconds)'] >= start_ts) & (PD2_chest['Timestamp (microseconds)'] <= end_ts)]

sidestep ['Activity_Label'] = 'sidestep'
sidestep
# Out:
# /tmp/ipykernel_24612/3996763997.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sidestep ['Activity_Label'] = 'sidestep'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 11075          1613588050011780    -0.886183    -0.061463     0.463447
# 11076          1613588050043554    -0.984817    -0.151308     0.281804
# 11077          1613588050075328    -0.942824    -0.164004     0.351629
# 11078          1613588050107102    -0.890578    -0.031678     0.393622
# 11079          1613588050138876    -0.912062    -0.083436     0.401923
# ...                         ...          ...          ...          ...
# 12518          1613588095858293    -0.953567    -0.079530     0.402899
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 55, second = 58, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 57, second = 8, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

scooter = PD2_chest.loc[(PD2_chest['Timestamp (microseconds)'] >= start_ts) & (PD2_chest['Timestamp (microseconds)'] <= end_ts)]

scooter ['Activity_Label'] = 'scooter'
scooter
# Out:
# /tmp/ipykernel_24612/2273007897.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scooter ['Activity_Label'] = 'scooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 14474          1613588158002443    -0.728954    -0.358343    -0.591745
# 14475          1613588158034213    -0.752880    -0.288029    -0.577096
# 14476          1613588158065982    -0.786084    -0.271427    -0.552193
# 14477          1613588158097752    -0.786084    -0.280217    -0.571725
# 14478          1613588158129522    -0.780713    -0.263127    -0.559030
# ...                         ...          ...          ...          ...
# 16673          1613588227854395    -0.780224    -0.339300    -0.545357
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 58, second = 50, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 59, second = 34, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

bellyscooter = PD2_chest.loc[(PD2_chest['Timestamp (microseconds)'] >= start_ts) & (PD2_chest['Timestamp (microseconds)'] <= end_ts)]

bellyscooter ['Activity_Label'] = 'bellyscooter'
bellyscooter
# Out:
# /tmp/ipykernel_24612/928289628.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bellyscooter ['Activity_Label'] = 'bellyscooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 19889          1613588330003056     0.246159    -0.224552     1.401450
# 19890          1613588330034822     0.689525     0.135317     0.999100
# 19891          1613588330066588     0.582589     0.044495     0.981033
# 19892          1613588330098354     0.471748    -0.124941     0.996658
# 19893          1613588330130120     0.353094     0.025940     0.841871
# ...                         ...          ...          ...          ...
# 21269          1613588373846296     0.312566     0.267155     0.932692
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 57, second = 25, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 58, second = 27, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

circularscooter = PD2_chest.loc[(PD2_chest['Timestamp (microseconds)'] >= start_ts) & (PD2_chest['Timestamp (microseconds)'] <= end_ts)]

circularscooter ['Activity_Label'] = 'circularscooter'
circularscooter
# Out:
# /tmp/ipykernel_24612/229069950.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   circularscooter ['Activity_Label'] = 'circularscooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 17213          1613588245007390    -0.744091    -0.315862    -0.589303
# 17214          1613588245039155    -0.750439    -0.328069    -0.597604
# 17215          1613588245070919    -0.743114    -0.309514    -0.579538
# 17216          1613588245102684    -0.763622    -0.332952    -0.584421
# 17217          1613588245134448    -0.720653    -0.348577    -0.603464
# ...                         ...          ...          ...          ...
# 19160          1613588306847351    -0.893996    -0.080995    -0.406683
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 14, minute = 1, second = 0, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 14, minute = 1, second = 40, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

scooterfnb = PD2_chest.loc[(PD2_chest['Timestamp (microseconds)'] >= start_ts) & (PD2_chest['Timestamp (microseconds)'] <= end_ts)]

scooterfnb ['Activity_Label'] = 'scooterfnb'
scooterfnb
# Out:
# /tmp/ipykernel_24612/2203379921.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scooterfnb ['Activity_Label'] = 'scooterfnb'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 23982          1613588460009034     0.319890    -0.091249     1.011795
# 23983          1613588460040789     0.330632     0.175357     1.019120
# 23984          1613588460072544     0.430243     0.237369     0.895583
# 23985          1613588460104299     0.474678     0.029358     0.896559
# 23986          1613588460136054     0.460029     0.059144     0.936110
# ...                         ...          ...          ...          ...
# 25237          1613588499859260    -0.792432     0.169986    -0.491646
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 49, second = 10, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 49, second = 55, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

handcycling = PD2_chest.loc[(PD2_chest['Timestamp (microseconds)'] >= start_ts) & (PD2_chest['Timestamp (microseconds)'] <= end_ts)]

handcycling ['Activity_Label'] = 'handcycling'
handcycling
# Out:
# /tmp/ipykernel_24612/3813859086.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   handcycling ['Activity_Label'] = 'handcycling'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 1636          1613587750025280    -0.933059     0.040589     0.352605
# 1637          1613587750057059    -0.975540     0.117739     0.338445
# 1638          1613587750088838    -0.964797     0.065003     0.287663
# 1639          1613587750120617    -0.983841     0.052796     0.260807
# 1640          1613587750152282    -0.989212     0.056214     0.249577
# ...                        ...          ...          ...          ...
# 3047          1613587794862690    -0.829053     0.342351    -0.324163
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 50, second = 0, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 13, minute = 50, second = 27, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

completecycling = PD2_chest.loc[(PD2_chest['Timestamp (microseconds)'] >= start_ts) & (PD2_chest['Timestamp (microseconds)'] <= end_ts)]

completecycling ['Activity_Label'] = 'completecycling'
completecycling
# Out:
# /tmp/ipykernel_24612/507395192.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   completecycling ['Activity_Label'] = 'completecycling'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 3209          1613587800011751    -0.891066     0.111879     0.515206
# 3210          1613587800043534    -0.927687     0.041566     0.531807
# 3211          1613587800075317    -0.846143     0.067933     0.497139
# 3212          1613587800107099    -0.856886     0.044007     0.515206
# 3213          1613587800138882    -0.762158     0.061097     0.613840
# ...                        ...          ...          ...          ...
# 4053          1613587826841899    -1.158648     0.186099     0.186099
# ...

# %%
#merging all the activities
merged_PD2_chest = pd.concat([MedicineBall, Burpees, FBstep, sidestep, scooter, bellyscooter, circularscooter, scooterfnb, handcycling, completecycling], ignore_index=True)
merged_PD2_chest
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1613587838001192    -0.988235    -0.078065     0.316472
# 1              1613587838032984    -0.987259    -0.036561     0.327703
# 2              1613587838064776    -0.981399    -0.035584     0.330632
# 3              1613587838096568    -0.995560    -0.055116     0.370672
# 4              1613587838128360    -0.968704    -0.091249     0.342840
# ...                         ...          ...          ...          ...
# 15733          1613587826841899    -1.158648     0.186099     0.186099
# 15734          1613587826873689    -1.122515     0.236393     0.118715
# 15735          1613587826905480    -1.136675     0.189517     0.194400
# 15736          1613587826937271    -1.123980     0.219303     0.105531
# 15737          1613587826969061    -1.070268     0.198795     0.103090
#
#        Sample (V)   Activity_Label
# 0       -0.004034    Medicine Ball
# 1       -0.004010    Medicine Ball
# ...

# %%
#combined(accel+gyro) .csv
merged_PD2_chest.to_csv('PD2chest.csv', sep=',',  index = False)

# %% [markdown]
# # PD3 chest

# %%
PD3_chest = pd.read_csv('pd3-accel-chest_new.csv')
PD3_elec = pd.read_csv('pd3-elec-chest_new.csv')
pd3a = PD3_chest['Timestamp (microseconds)'].to_numpy()
pd3e = PD3_elec['Timestamp (microseconds)'].to_numpy()
for i in range(len(PD3_chest)):
    PD3_chest.at[i, 'Sample (V)'] = PD3_elec['Sample (V)'].iloc[np.argmin(abs(pd3a[i] - pd3e))]
PD3_chest
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1613602832401580    -0.128359     0.837964     0.332586
# 1              1613602832433557    -0.179629     0.931228     0.363348
# 2              1613602832465534    -0.174746     0.962966     0.375067
# 3              1613602832497511    -0.188418     0.955154     0.364324
# 4              1613602832529487    -0.176699     0.825757     0.350652
# ...                         ...          ...          ...          ...
# 61555          1613604847490910    -0.250431     0.723217    -0.497993
# 61556          1613604847522787    -0.255314     0.835035    -0.639109
# 61557          1613604847554664    -0.250919     1.016190    -0.759228
# 61558          1613604847586541    -0.268498     1.092851    -0.808545
# 61559          1613604847618418    -0.222110     1.127520    -0.786572
#
#        Sample (V)
# 0       -0.014749
# 1       -0.012927
# 2       -0.012097
# 3       -0.011555
# ...

# %%
print(PD3_chest['Timestamp (microseconds)'][0])
pd.Timestamp(PD3_chest['Timestamp (microseconds)'][0], unit='us', tz="US/Eastern")
# Out:
# 1613602832401580
# Timestamp('2021-02-17 18:00:32.401580-0500', tz='US/Eastern')

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 0, second = 24, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 1, second = 4, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

FBstep = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

FBstep['Activity_Label'] = 'FBstep'
FBstep
# Out:
# /tmp/ipykernel_24612/2695946783.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FBstep['Activity_Label'] = 'FBstep'
#      Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0            1613602832401580    -0.128359     0.837964     0.332586
# 1            1613602832433557    -0.179629     0.931228     0.363348
# 2            1613602832465534    -0.174746     0.962966     0.375067
# 3            1613602832497511    -0.188418     0.955154     0.364324
# 4            1613602832529487    -0.176699     0.825757     0.350652
# ..                        ...          ...          ...          ...
# 988          1613602863869848    -0.452583     1.145098     0.437079
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 1, second = 11, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 2, second = 3, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

sidestep = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

sidestep['Activity_Label'] = 'sidestep'
sidestep
# Out:
# /tmp/ipykernel_24612/1039897736.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sidestep['Activity_Label'] = 'sidestep'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 1212          1613602871001485    -0.330999     0.539132     0.015686
# 1213          1613602871033327    -0.298283     0.480049    -0.085389
# 1214          1613602871065169    -0.192325     0.391669     0.065492
# 1215          1613602871097011    -0.074647     0.441474     0.103578
# 1216          1613602871128852     0.016663     1.051347     0.750072
# ...                        ...          ...          ...          ...
# 2841          1613602922855559     0.212467     1.076249    -0.050233
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 2, second = 34, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 3, second = 20, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

pushups = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

pushups['Activity_Label'] = 'pushups'
pushups
# Out:
# /tmp/ipykernel_24612/1686664823.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pushups['Activity_Label'] = 'pushups'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 3820          1613602954009159     0.011292     0.856519    -0.455512
# 3821          1613602954040978    -0.008240     0.857984    -0.526314
# 3822          1613602954072797    -0.033631     0.868727    -0.497993
# 3823          1613602954104617    -0.038514     0.876539    -0.482856
# 3824          1613602954136436    -0.039002     0.865797    -0.457954
# ...                        ...          ...          ...          ...
# 5261          1613602999845762    -0.118593     0.878492    -0.152773
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 3, second = 36, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 4, second = 17, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

hipstep = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

hipstep['Activity_Label'] = 'hipstep'
hipstep
# Out:
# /tmp/ipykernel_24612/3119629325.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hipstep['Activity_Label'] = 'hipstep'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 5769          1613603016000161    -0.017029     0.841871     0.496651
# 5770          1613603016031961    -0.052674     0.870680     0.545968
# 5771          1613603016063761    -0.030213     0.806714     0.576242
# 5772          1613603016095562     0.020569     0.769604     0.545968
# 5773          1613603016127362     0.021057     0.803784     0.598215
# ...                        ...          ...          ...          ...
# 7054          1613603056854222    -0.034607    -0.993118     0.663157
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 4, second = 44, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 6, second = 33, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

FBscooter = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

FBscooter['Activity_Label'] = 'FBscooter'
FBscooter
# Out:
# /tmp/ipykernel_24612/1375186575.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FBscooter['Activity_Label'] = 'FBscooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 7908           1613603084006296    -0.000916     0.936110     0.229557
# 7909           1613603084038089     0.015198     0.946365     0.253971
# 7910           1613603084069882     0.031312     0.955154     0.221744
# 7911           1613603084101675    -0.005310     1.007401     0.244694
# 7912           1613603084133468     0.009827     0.979568     0.245670
# ...                         ...          ...          ...          ...
# 11333          1613603192848352     0.242252     0.999588     0.019104
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 6, second = 49, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 7, second = 55, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

bellyscooter = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

bellyscooter['Activity_Label'] = 'bellyscooter'
bellyscooter
# Out:
# /tmp/ipykernel_24612/591027140.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bellyscooter['Activity_Label'] = 'bellyscooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 11842          1613603209015371     0.213931     0.777417    -0.776318
# 11843          1613603209047135     0.235416     0.795972    -0.758740
# 11844          1613603209078899     0.220768     0.842847    -0.778759
# 11845          1613603209110663     0.241764     0.805737    -0.782177
# 11846          1613603209142427     0.290593     0.841382    -0.840284
# ...                         ...          ...          ...          ...
# 13915          1613603274864529    -0.012146     0.647532    -0.757275
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 8, second = 8, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 8, second = 48, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

roundscooter = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

roundscooter['Activity_Label'] = 'roundscooter'
roundscooter
# Out:
# /tmp/ipykernel_24612/629898587.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   roundscooter['Activity_Label'] = 'roundscooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 14329          1613603288017839    -0.078065     0.769604    -0.643992
# 14330          1613603288049610    -0.053162     0.730053    -0.697215
# 14331          1613603288081380    -0.044862     0.748608    -0.736767
# 14332          1613603288113151    -0.090272     0.741283    -0.710887
# 14333          1613603288144922    -0.072694     0.729564    -0.650340
# ...                         ...          ...          ...          ...
# 15583          1613603327865711     0.155337     0.672435    -0.665476
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 9, second = 51, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 11, second = 20, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

cycling = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

cycling['Activity_Label'] = 'cycling'
cycling
# Out:
# /tmp/ipykernel_24612/1311290761.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cycling['Activity_Label'] = 'cycling'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 17570          1613603391017645    -0.295842     0.943923    -0.216251
# 17571          1613603391049427    -0.333928     0.908766    -0.183536
# 17572          1613603391081209    -0.321721     0.910719    -0.205020
# 17573          1613603391112990    -0.285100     0.934157    -0.199649
# 17574          1613603391144772    -0.279240     0.930251    -0.236271
# ...                         ...          ...          ...          ...
# 20362          1613603479850099    -0.192813     0.982498     0.182193
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 11, second = 22, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 11, second = 55, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

fastcycling = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

fastcycling['Activity_Label'] = 'fastcycling'
fastcycling
# Out:
# /tmp/ipykernel_24612/3980779230.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fastcycling['Activity_Label'] = 'fastcycling'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 20430          1613603482015895    -0.001404     0.802808    -0.012634
# 20431          1613603482047742    -0.199161     1.034257     0.044007
# 20432          1613603482079589    -0.207950     1.039628     0.169986
# 20433          1613603482111436    -0.264591     1.133867     0.169497
# 20434          1613603482143283    -0.307073     1.330648     0.175845
# ...                         ...          ...          ...          ...
# 21461          1613603514860108     0.186587     0.950271     0.049378
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 11, second = 56, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 12, second = 22, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

cycling2 = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

cycling2['Activity_Label'] = 'cycling2'
cycling2
# Out:
# /tmp/ipykernel_24612/983865295.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cycling2['Activity_Label'] = 'cycling2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 21497          1613603516006970     0.260319     1.002029     0.214420
# 21498          1613603516038828     0.157778     0.988357     0.231998
# 21499          1613603516070685     0.152407     0.953689     0.195377
# 21500          1613603516102543     0.108461     0.968826     0.209049
# 21501          1613603516134400     0.091371     0.973220     0.164126
# ...                         ...          ...          ...          ...
# 22308          1613603541845323    -0.038025     0.826734     0.088930
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 12, second = 23, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 13, second = 1, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

fastcycling2 = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

fastcycling2['Activity_Label'] = 'fastcycling2'
fastcycling2
# Out:
# /tmp/ipykernel_24612/1439238789.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fastcycling2['Activity_Label'] = 'fastcycling2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 22345          1613603543024158     0.038636     0.986893    -0.020447
# 22346          1613603543056018     0.170474     0.973709     0.004944
# 22347          1613603543087877     0.081605     0.881422    -0.059998
# 22348          1613603543119737     0.074281     0.792554    -0.062928
# 22349          1613603543151597    -0.020935     0.824292     0.010803
# ...                         ...          ...          ...          ...
# 23532          1613603580841228     0.023011     0.936599     0.398993
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 13, second = 8, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 13, second = 45, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

MedicineBall = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

MedicineBall['Activity_Label'] = 'Medicine Ball'
MedicineBall
# Out:
# /tmp/ipykernel_24612/2944408894.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MedicineBall['Activity_Label'] = 'Medicine Ball'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 23757          1613603588009844    -0.104921     0.963943     0.028382
# 23758          1613603588041705    -0.184512     0.844800    -0.043885
# 23759          1613603588073566    -0.221622     0.778882    -0.101503
# 23760          1613603588105407    -0.179629     0.872633     0.125063
# 23761          1613603588137268    -0.107362     0.975662     0.305730
# ...                         ...          ...          ...          ...
# 24914          1613603624867756    -0.242130     0.300847    -0.824659
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 13, second = 45, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 14, second = 20, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

burpees = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

burpees['Activity_Label'] = 'burpees'
burpees
# Out:
# /tmp/ipykernel_24612/609419522.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   burpees['Activity_Label'] = 'burpees'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 24919          1613603625027029    -0.181582     0.338445    -0.951125
# 24920          1613603625058838    -0.209903     0.407294    -0.921340
# 24921          1613603625090692    -0.197696     0.403876    -0.898878
# 24922          1613603625122547    -0.249454     0.379950    -0.952590
# 24923          1613603625154401    -0.247990     0.378485    -0.938430
# ...                         ...          ...          ...          ...
# 26013          1613603659870139    -0.063905     0.480049    -0.489693
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 16, second = 25, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 17, second = 23, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

sidestep2 = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

sidestep2['Activity_Label'] = 'sidestep2'
sidestep2
# Out:
# /tmp/ipykernel_24612/3322268179.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sidestep2['Activity_Label'] = 'sidestep2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 29944          1613603785012294    -0.318303     0.736400     0.502510
# 29945          1613603785044123    -0.345647     0.746654     0.245182
# 29946          1613603785075951    -0.257267     0.857008     0.204654
# 29947          1613603785107780    -0.083436     1.043046     0.375067
# 29948          1613603785139608     0.027893     0.824781     0.230533
# ...                         ...          ...          ...          ...
# 31761          1613603842849521     0.007874     0.640208     0.328679
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 17, second = 40, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 18, second = 36, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

pushups2 = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

pushups2['Activity_Label'] = 'pushups2'
pushups2
# Out:
# /tmp/ipykernel_24612/688962085.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pushups2['Activity_Label'] = 'pushups2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 32300          1613603860008497     0.098207     0.725658    -0.550240
# 32301          1613603860040332     0.115785     0.762280    -0.618112
# 32302          1613603860072167     0.055238     0.772534    -0.555123
# 32303          1613603860104002     0.153384     0.699290    -0.703075
# 32304          1613603860135837     0.026429     0.766674    -0.656687
# ...                         ...          ...          ...          ...
# 34055          1613603915863973     0.182681     0.942458    -0.328557
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 14, second = 40, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 15, second = 8, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

punchball = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

punchball['Activity_Label'] = 'punchball'
punchball
# Out:
# /tmp/ipykernel_24612/1395035132.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   punchball['Activity_Label'] = 'punchball'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 26646          1613603680027210     0.179751     0.679271    -0.929641
# 26647          1613603680059053     0.189029     0.705638    -0.857374
# 26648          1613603680090896     0.124086     0.689525    -0.831006
# 26649          1613603680122739     0.100160     0.645579    -0.769970
# 26650          1613603680154583     0.089906     0.546456    -0.748486
# ...                         ...          ...          ...          ...
# 27520          1613603707854339    -0.378851     0.252018    -0.788037
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 15, second = 23, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 16, second = 24, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

FBstep2 = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

FBstep2['Activity_Label'] = 'FBstep2'
FBstep2
# Out:
# /tmp/ipykernel_24612/2485201293.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FBstep2['Activity_Label'] = 'FBstep2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 27996          1613603723007957    -0.205020     0.859937     0.261295
# 27997          1613603723039793    -0.265080     0.964431     0.388739
# 27998          1613603723071628    -0.250919     1.124102     0.470283
# 27999          1613603723103464    -0.310491     0.961990     0.446845
# 28000          1613603723135192    -0.349065     0.901930     0.391669
# ...                         ...          ...          ...          ...
# 29908          1613603783866432     0.215396     0.919997     0.038148
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 18, second = 49, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 19, second = 38, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

highraise = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

highraise['Activity_Label'] = 'highraise'
highraise
# Out:
# /tmp/ipykernel_24612/69776469.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   highraise['Activity_Label'] = 'highraise'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 34468          1613603929003976     0.122133     0.657786     0.767651
# 34469          1613603929035792     0.117739     0.635325     0.733471
# 34470          1613603929067608     0.107973     0.614328     0.744701
# 34471          1613603929099424     0.059144     0.615793     0.774487
# 34472          1613603929131240     0.026917     0.594308     0.797436
# ...                         ...          ...          ...          ...
# 36004          1613603977856424    -0.092714    -0.742626     0.761791
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 20, second = 2, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 20, second = 52, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

FBscooter2 = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

FBscooter2['Activity_Label'] = 'FBscooter2'
FBscooter2
# Out:
# /tmp/ipykernel_24612/2880936961.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FBscooter2['Activity_Label'] = 'FBscooter2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 36764          1613604002023740    -0.128359     0.917556     0.444892
# 36765          1613604002055539    -0.134218     0.918044     0.477119
# 36766          1613604002087338    -0.211368     0.990799     0.503975
# 36767          1613604002119137    -0.245060     0.874098     0.534249
# 36768          1613604002150936    -0.203067     0.990311     0.617746
# ...                         ...          ...          ...          ...
# 38331          1613604051855968     0.129458     0.794018     0.631418
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 20, second = 54, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 21, second = 53, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

cirscooter = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

cirscooter['Activity_Label'] = 'cirscooter'
cirscooter
# Out:
# /tmp/ipykernel_24612/3220524944.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cirscooter['Activity_Label'] = 'cirscooter'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 38399          1613604054018581     0.151431     0.959548     0.187076
# 38400          1613604054050415     0.128481     0.989334     0.243229
# 38401          1613604054082218     0.058656     0.930251     0.313054
# 38402          1613604054114022     0.103090     0.774975     0.339422
# 38403          1613604054145825     0.117739     0.669017     0.340887
# ...                         ...          ...          ...          ...
# 40249          1613604112848925     0.063539     0.889723     0.104555
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 25, second = 44, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)
print(start_ts, end_ts)
end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 26, second = 12, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

boxing['Activity_Label'] = 'boxing'
boxing
# Out:
# 1613604344000000 1613604113000000
# /tmp/ipykernel_24612/2701698132.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing['Activity_Label'] = 'boxing'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 46040          1613604353892181     0.091859     1.261311     0.568429
# 46041          1613604353924150     0.025452     1.043046     0.444892
# 46042          1613604353956118     0.027405     0.906325     0.403876
# 46043          1613604353988087    -0.013123     0.757885     0.426337
# 46044          1613604354020055     0.008362     0.574777     0.428290
# ...                         ...          ...          ...          ...
# 46605          1613604371866232    -0.384222     0.921950     0.258854
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 26, second = 22, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 26, second = 50, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

hardboxing = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

hardboxing['Activity_Label'] = 'hardboxing'
hardboxing
# Out:
# /tmp/ipykernel_24612/975511589.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hardboxing['Activity_Label'] = 'hardboxing'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 46924          1613604382012476    -0.171328     0.839429     0.416571
# 46925          1613604382044289    -0.178653     0.850660     0.400458
# 46926          1613604382076102    -0.181582     0.937087     0.380926
# 46927          1613604382107915    -0.174258     0.905837     0.370672
# 46928          1613604382139728    -0.155215     0.961990     0.355047
# ...                         ...          ...          ...          ...
# 47799          1613604409843254    -0.463813     0.831617     0.251530
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 27, second = 43, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 28, second = 8, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

sideboxing = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

sideboxing['Activity_Label'] = 'sideboxing'
sideboxing
# Out:
# /tmp/ipykernel_24612/2922913189.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sideboxing['Activity_Label'] = 'sideboxing'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 49471          1613604463027454    -0.059510     0.904860     0.067445
# 49472          1613604463059265     0.070863     0.972732     0.202213
# 49473          1613604463091076    -0.307561     0.692454    -0.051209
# 49474          1613604463122886    -0.225040     0.924880    -0.062440
# 49475          1613604463154697    -0.396918     1.078202    -0.010681
# ...                         ...          ...          ...          ...
# 50252          1613604487872627     1.123125     0.796948    -0.486275
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 28, second = 20, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 28, second = 51, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

kneeboxing = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

kneeboxing['Activity_Label'] = 'kneeboxing'
kneeboxing
# Out:
# /tmp/ipykernel_24612/3385641272.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kneeboxing['Activity_Label'] = 'kneeboxing'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 50634          1613604500025602    -0.169863     0.769116     0.214908
# 50635          1613604500057416    -0.261173     0.809155     0.196353
# 50636          1613604500089229    -0.255802     0.843824     0.226627
# 50637          1613604500121043    -0.344182     0.892653     0.244694
# 50638          1613604500152856    -0.407660     0.941482     0.266178
# ...                         ...          ...          ...          ...
# 51603          1613604530855459    -0.491157     1.173419     0.198795
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 29, second = 3, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 29, second = 33, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

kneepunchboxing = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

kneepunchboxing['Activity_Label'] = 'kneepunchboxing'
kneepunchboxing
# Out:
# /tmp/ipykernel_24612/1795477829.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kneepunchboxing['Activity_Label'] = 'kneepunchboxing'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 51985          1613604543009554     0.074769     0.776928     0.193423
# 51986          1613604543041370     0.098695     0.720775     0.208560
# 51987          1613604543073186     0.074769     0.723705     0.228092
# 51988          1613604543105003     0.106508     0.805249     0.242252
# 51989          1613604543136819     0.069886     0.880446     0.238834
# ...                         ...          ...          ...          ...
# 52923          1613604572852343     0.264714     0.661204     0.141665
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 29, second = 44, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 30, second = 12, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

RLboxing = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

RLboxing['Activity_Label'] = 'RLboxing'
RLboxing
# Out:
# /tmp/ipykernel_24612/849305266.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RLboxing['Activity_Label'] = 'RLboxing'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 53274          1613604584019364    -0.174746     0.982010     0.519112
# 53275          1613604584051179    -0.159609     0.998611     0.535225
# 53276          1613604584082994    -0.123476     0.968826     0.531807
# 53277          1613604584114809    -0.101503     0.942947     0.493233
# 53278          1613604584146624    -0.090272     0.871656     0.456611
# ...                         ...          ...          ...          ...
# 54149          1613604611852618     0.030335     0.879957     0.341863
# ...

# %%
start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 30, second = 23, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 30, second = 50, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

Rboxing = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

Rboxing['Activity_Label'] = 'Rboxing'
Rboxing
# Out:
# /tmp/ipykernel_24612/3882629701.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Rboxing['Activity_Label'] = 'Rboxing'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 54500          1613604623016540    -0.097597     0.803296     0.658274
# 54501          1613604623048347    -0.085389     0.796948     0.632883
# 54502          1613604623080154    -0.091737     0.768139     0.608469
# 54503          1613604623111961    -0.081971     0.800855     0.648020
# 54504          1613604623143768    -0.101503     0.863355     0.644602
# ...                         ...          ...          ...          ...
# 55344          1613604649860267     0.170474     1.007889     0.470283
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 31, second = 1, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 31, second = 32, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

FCboxing = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

FCboxing['Activity_Label'] = 'FCboxing'
FCboxing
# Out:
# /tmp/ipykernel_24612/596079142.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FCboxing['Activity_Label'] = 'FCboxing'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 55695          1613604661024840     0.160220     0.815503     0.421454
# 55696          1613604661056648     0.087953     0.917556     0.386786
# 55697          1613604661088455    -0.004334     0.831617     0.412177
# 55698          1613604661120263     0.048890     0.857008     0.322332
# 55699          1613604661152070    -0.007263     0.913649     0.287175
# ...                         ...          ...          ...          ...
# 56664          1613604691848407    -0.601999     1.374105     0.113832
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 31, second = 41, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 32, second = 5, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

speedboxing = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

speedboxing['Activity_Label'] = 'speedboxing'
speedboxing
# Out:
# /tmp/ipykernel_24612/1422438714.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   speedboxing['Activity_Label'] = 'speedboxing'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 56952          1613604701010040    -0.059998     1.133867     0.352605
# 56953          1613604701041851    -0.032654     0.911696     0.115785
# 56954          1613604701073661     0.039612     0.773022     0.029847
# 56955          1613604701105472     0.033265     0.536690     0.002502
# 56956          1613604701137283    -0.009705     0.490303     0.254948
# ...                         ...          ...          ...          ...
# 57702          1613604724868375     0.089906     0.984451     0.013733
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 27, second = 4, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 17, hour = 18, minute = 27, second = 30, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxingpf = PD3_chest.loc[(PD3_chest['Timestamp (microseconds)'] >= start_ts) & (PD3_chest['Timestamp (microseconds)'] <= end_ts)]

boxingpf['Activity_Label'] = 'boxingpf'
boxingpf
# Out:
# /tmp/ipykernel_24612/3543103003.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxingpf['Activity_Label'] = 'boxingpf'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 48245          1613604424029180    -0.118105     0.750561     0.474189
# 48246          1613604424060986    -0.151797     0.715404     0.384833
# 48247          1613604424092793    -0.138613     0.720287     0.283268
# 48248          1613604424124599    -0.109316     0.862867     0.424872
# 48249          1613604424156406    -0.119081     0.877516     0.441474
# ...                         ...          ...          ...          ...
# 49057          1613604449857531    -0.012146     1.247150     0.690013
# ...

# %%
#merging all the activities
merged_PD3_chest = pd.concat([FBstep, sidestep, pushups, hipstep, FBscooter, bellyscooter, roundscooter, cycling, fastcycling, cycling2, fastcycling2, MedicineBall, burpees, sidestep2, pushups2, punchball, FBstep2, highraise, FBscooter2, cirscooter, boxing, hardboxing, sideboxing, kneeboxing, kneepunchboxing, RLboxing, Rboxing, FCboxing, speedboxing, boxingpf], ignore_index=True)
merged_PD3_chest
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1613602832401580    -0.128359     0.837964     0.332586
# 1              1613602832433557    -0.179629     0.931228     0.363348
# 2              1613602832465534    -0.174746     0.962966     0.375067
# 3              1613602832497511    -0.188418     0.955154     0.364324
# 4              1613602832529487    -0.176699     0.825757     0.350652
# ...                         ...          ...          ...          ...
# 40001          1613604449857531    -0.012146     1.247150     0.690013
# 40002          1613604449889340    -0.119081     0.937087     0.533761
# 40003          1613604449921149     0.075257     1.197345     0.578683
# 40004          1613604449952959     0.212955     1.190997     0.420478
# 40005          1613604449984768    -0.050721     1.171954     0.469795
#
#        Sample (V) Activity_Label
# 0       -0.014749         FBstep
# 1       -0.012927         FBstep
# ...

# %%
#combined(accel+gyro) .csv
merged_PD3_chest.to_csv('PD3chest.csv', sep=',',  index = False)

# %% [markdown]
# # PD 4 chest

# %%
PD4_chest = pd.read_csv('pd4-accel-chest.csv')
PD4_elec = pd.read_csv('pd4-elec-chest.csv')
pd4a = PD4_chest['Timestamp (microseconds)'].to_numpy()
pd4e = PD4_elec['Timestamp (microseconds)'].to_numpy()
for i in range(len(PD4_chest)):
    PD4_chest.at[i, 'Sample (V)'] = PD4_elec['Sample (V)'].iloc[np.argmin(abs(pd4a[i] - pd4e))]
PD4_chest
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1613688483957550     0.685618     2.720317     1.346761
# 1              1613688483989523     1.392660     2.426368     0.474678
# 2              1613688484021496     1.084062     1.914153     1.089921
# 3              1613688484053470     0.152895     1.867765     1.195392
# 4              1613688484085443    -0.308049     1.731533     1.069902
# ...                         ...          ...          ...          ...
# 67875          1613690641936017    -0.131289     0.922927     0.295476
# 67876          1613690641967775    -0.137148     0.901442     0.280339
# 67877          1613690641999533    -0.146426     0.866773     0.292058
# 67878          1613690642031291    -0.164981     0.891188     0.258854
# 67879          1613690642063048    -0.173770     0.928298     0.401923
#
#        Sample (V)
# 0       -0.019740
# 1       -0.016466
# 2       -0.015291
# 3       -0.013820
# ...

# %%
print(PD4_chest['Timestamp (microseconds)'][0])
pd.Timestamp(PD4_chest['Timestamp (microseconds)'][0], unit='us', tz="US/Eastern")
# Out:
# 1613688483957550
# Timestamp('2021-02-18 17:48:03.957550-0500', tz='US/Eastern')

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 17, minute = 52, second = 18, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 17, minute = 53, second = 16, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

hammerthrows = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

hammerthrows['Activity_Label'] = 'hammerthrows'
hammerthrows
# Out:
# /tmp/ipykernel_24612/1287391231.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hammerthrows['Activity_Label'] = 'hammerthrows'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 7985          1613688738023423    -0.139590     0.928298     0.260319
# 7986          1613688738055235    -0.110292     0.960037     0.248112
# 7987          1613688738087048    -0.104921     0.971267     0.263737
# 7988          1613688738118860    -0.077089     1.037675     0.261295
# 7989          1613688738150672    -0.077577     1.006912     0.212467
# ...                        ...          ...          ...          ...
# 9803          1613688795853386    -0.096620     1.049393     0.080629
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 17, minute = 53, second = 33, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 17, minute = 54, second = 31, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

stepweight = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

stepweight['Activity_Label'] = 'stepweight'
stepweight
# Out:
# /tmp/ipykernel_24612/659100299.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stepweight['Activity_Label'] = 'stepweight'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 10343          1613688813029350    -0.345159     0.878004     0.124086
# 10344          1613688813061157    -0.328557     0.771557     0.041566
# 10345          1613688813092964    -0.252384     0.832105     0.022522
# 10346          1613688813124771    -0.198184     0.868727     0.114321
# 10347          1613688813156578    -0.142519     0.882887     0.102602
# ...                         ...          ...          ...          ...
# 12161          1613688870851385     0.070375     0.903395     0.349676
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 17, minute = 54, second = 46, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 17, minute = 55, second = 46, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

throws = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

throws ['Activity_Label'] = 'throws'
throws
# Out:
# /tmp/ipykernel_24612/83330894.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   throws ['Activity_Label'] = 'throws'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 12638          1613688886022531     0.113832     0.990311     0.212955
# 12639          1613688886054337     0.136294     1.056718     0.270573
# 12640          1613688886086090     0.065980     1.046464     0.300359
# 12641          1613688886117895    -0.004334     0.901442     0.224674
# 12642          1613688886149701    -0.015076     0.802319     0.154360
# ...                         ...          ...          ...          ...
# 14520          1613688945862152     0.100649     1.036210    -0.337346
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 17, minute = 56, second = 1, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 17, minute = 57, second = 1, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

squatweights = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

squatweights ['Activity_Label'] = 'squatweights'
squatweights
# Out:
# /tmp/ipykernel_24612/1540696384.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   squatweights ['Activity_Label'] = 'squatweights'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 14997          1613688961024845     0.044984     0.804273     0.535225
# 14998          1613688961056633    -0.015564     0.849683     0.570382
# 14999          1613688961088420    -0.013123     0.890700     0.539620
# 15000          1613688961120239    -0.010681     0.880934     0.594308
# 15001          1613688961152027     0.063539     0.875563     0.567941
# ...                         ...          ...          ...          ...
# 16879          1613689020865937    -0.135195     0.830640     0.519600
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 17, minute = 57, second = 16, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 17, minute = 58, second = 15, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

lightweights = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

lightweights ['Activity_Label'] = 'lightweights'
lightweights
# Out:
# /tmp/ipykernel_24612/2203313748.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lightweights ['Activity_Label'] = 'lightweights'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 17355          1613689036004436    -0.038025     0.963943     0.243717
# 17356          1613689036036239     0.028870     0.940017     0.286687
# 17357          1613689036068042     0.047913     0.959060     0.317937
# 17358          1613689036099846     0.046448     0.985916     0.370184
# 17359          1613689036131649     0.019593     1.011307     0.352117
# ...                         ...          ...          ...          ...
# 19206          1613689094870647    -0.067323     0.899489     0.298894
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 17, minute = 57, second = 16, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 17, minute = 58, second = 15, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

heavyweights = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

heavyweights ['Activity_Label'] = 'heavyweights'
heavyweights
# Out:
# /tmp/ipykernel_24612/631276471.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heavyweights ['Activity_Label'] = 'heavyweights'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 17355          1613689036004436    -0.038025     0.963943     0.243717
# 17356          1613689036036239     0.028870     0.940017     0.286687
# 17357          1613689036068042     0.047913     0.959060     0.317937
# 17358          1613689036099846     0.046448     0.985916     0.370184
# 17359          1613689036131649     0.019593     1.011307     0.352117
# ...                         ...          ...          ...          ...
# 19206          1613689094870647    -0.067323     0.899489     0.298894
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 3, second = 49, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 4, second = 46, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing12 = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

boxing12 ['Activity_Label'] = 'boxing12'
boxing12
# Out:
# /tmp/ipykernel_24612/1345751758.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing12 ['Activity_Label'] = 'boxing12'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 29713          1613689429030966     0.132387     0.706126     0.268620
# 29714          1613689429062771     0.142153     0.746654     0.357488
# 29715          1613689429094577     0.149477     0.752026     0.355047
# 29716          1613689429126382     0.108461     0.854566     0.307195
# 29717          1613689429158188     0.056214     1.022538     0.394598
# ...                         ...          ...          ...          ...
# 31500          1613689485864322    -0.032166     0.617258     0.479072
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 5, second = 3, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 6, second = 4, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

boxing ['Activity_Label'] = 'boxing'
boxing
# Out:
# /tmp/ipykernel_24612/88043930.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing ['Activity_Label'] = 'boxing'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 32039          1613689503007957    -0.056580     0.948806     0.273991
# 32040          1613689503039856    -0.066346     0.877516     0.227604
# 32041          1613689503071663    -0.064881     0.872633     0.232975
# 32042          1613689503103469    -0.082948     0.903395     0.237858
# 32043          1613689503135276    -0.123964     0.933181     0.249577
# ...                         ...          ...          ...          ...
# 33952          1613689563858047     0.055238     0.849195     0.232975
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 6, second = 20, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 7, second = 17, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxingupper = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

boxingupper ['Activity_Label'] = 'boxingupper'
boxingupper
# Out:
# /tmp/ipykernel_24612/1131758171.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxingupper ['Activity_Label'] = 'boxingupper'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 34460          1613689580017967    -0.177676     0.922927     0.328679
# 34461          1613689580049780     0.017639     1.002518     0.312566
# 34462          1613689580081592    -0.035096     1.105058     0.467842
# 34463          1613689580113405    -0.105409     1.063066     0.481514
# 34464          1613689580145218    -0.194278     1.011307     0.463447
# ...                         ...          ...          ...          ...
# 36247          1613689636867993    -0.309026     1.804288    -1.121538
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 7, second = 34, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 8, second = 32, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxingfront = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

boxingfront ['Activity_Label'] = 'boxingfront'
boxingfront
# Out:
# /tmp/ipykernel_24612/1298384343.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxingfront ['Activity_Label'] = 'boxingfront'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 36786          1613689654017909     0.095766     0.947341     0.283268
# 36787          1613689654049727     0.114321     0.939040     0.276921
# 36788          1613689654081545     0.102113     0.918532     0.324773
# 36789          1613689654113362     0.104555     0.932692     0.384344
# 36790          1613689654145180     0.087465     0.911208     0.374578
# ...                         ...          ...          ...          ...
# 38604          1613689711868862    -0.247501     0.937087    -0.343694
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 8, second = 49, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 9, second = 46, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing2 = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

boxing2 ['Activity_Label'] = 'boxing2'
boxing2
# Out:
# /tmp/ipykernel_24612/2481102736.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing2 ['Activity_Label'] = 'boxing2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 39143          1613689729021003    -0.182071     0.923415     0.415595
# 39144          1613689729052826    -0.190372     0.976638     0.455146
# 39145          1613689729084648    -0.199649     0.953689     0.422919
# 39146          1613689729116470    -0.210391     0.919997     0.387274
# 39147          1613689729148292    -0.182559     0.948318     0.361395
# ...                         ...          ...          ...          ...
# 40929          1613689785853085    -0.066346     1.061601    -0.201602
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 10, second = 4, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 11, second = 2, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing3 = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

boxing3 ['Activity_Label'] = 'boxing3'
boxing3
# Out:
# /tmp/ipykernel_24612/2317363388.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing3 ['Activity_Label'] = 'boxing3'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 41500          1613689804022646    -0.332464     1.362875     0.306218
# 41501          1613689804054466    -0.440864     1.100664     0.082094
# 41502          1613689804086287    -0.341741     1.047929     0.216861
# 41503          1613689804118108    -0.268009     1.137774     0.253971
# 41504          1613689804149929    -0.332952     0.980545     0.089418
# ...                         ...          ...          ...          ...
# 43318          1613689861868340    -0.193301     0.930739     0.397528
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 16, second = 0, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 16, second = 58, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

pushupshand = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

pushupshand ['Activity_Label'] = 'pushupshand'
pushupshand
# Out:
# /tmp/ipykernel_24612/3358809805.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pushupshand ['Activity_Label'] = 'pushupshand'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 52698          1613690160022098    -0.324163     0.694408    -0.598093
# 52699          1613690160053854    -0.278752     0.693919    -0.667918
# 52700          1613690160085609    -0.336370     0.654368    -0.678660
# 52701          1613690160117365    -0.328557     0.687572    -0.682567
# 52702          1613690160149120    -0.300725     0.676829    -0.657176
# ...                         ...          ...          ...          ...
# 54520          1613690217870269    -0.285100     0.747143    -0.640574
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 17, second = 13, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 18, second = 11, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

pushupsleg = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

pushupsleg ['Activity_Label'] = 'pushupsleg'
pushupsleg
# Out:
# /tmp/ipykernel_24612/866865077.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pushupsleg ['Activity_Label'] = 'pushupsleg'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 54997          1613690233015923    -0.182071     0.743725    -0.697215
# 54998          1613690233047675    -0.178164     0.682689    -0.664012
# 54999          1613690233079427    -0.184512     0.691478    -0.693797
# 55000          1613690233111206    -0.191348     0.715892    -0.734325
# 55001          1613690233142958    -0.175235     0.627512    -0.747021
# ...                         ...          ...          ...          ...
# 56819          1613690290859499    -0.301701     0.529366    -0.791455
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 17, second = 13, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 18, second = 11, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

pushupsleg2 = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

pushupsleg2['Activity_Label'] = 'pushupsleg2'
pushupsleg2
# Out:
# /tmp/ipykernel_24612/1398549463.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pushupsleg2['Activity_Label'] = 'pushupsleg2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 54997          1613690233015923    -0.182071     0.743725    -0.697215
# 54998          1613690233047675    -0.178164     0.682689    -0.664012
# 54999          1613690233079427    -0.184512     0.691478    -0.693797
# 55000          1613690233111206    -0.191348     0.715892    -0.734325
# 55001          1613690233142958    -0.175235     0.627512    -0.747021
# ...                         ...          ...          ...          ...
# 56819          1613690290859499    -0.301701     0.529366    -0.791455
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 19, second = 41, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 20, second = 41, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

exercise = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

exercise ['Activity_Label'] = 'exercise'
exercise
# Out:
# /tmp/ipykernel_24612/3745924000.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exercise ['Activity_Label'] = 'exercise'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 59659          1613690381016233    -0.076112     0.992264     0.098695
# 59660          1613690381047981    -0.068299     1.009354     0.135317
# 59661          1613690381079729    -0.061463     0.988357     0.085023
# 59662          1613690381111477    -0.059510     1.020096     0.079164
# 59663          1613690381143224    -0.077089     0.987381     0.093812
# ...                         ...          ...          ...          ...
# 61544          1613690440863971     0.060609    -0.260197     0.802319
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 20, second = 59, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 18, hour = 18, minute = 21, second = 57, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

ridgeplunges = PD4_chest.loc[(PD4_chest['Timestamp (microseconds)'] >= start_ts) & (PD4_chest['Timestamp (microseconds)'] <= end_ts)]

ridgeplunges ['Activity_Label'] = 'ridgeplunges'
ridgeplunges
# Out:
# /tmp/ipykernel_24612/3962075087.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ridgeplunges ['Activity_Label'] = 'ridgeplunges'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 62116          1613690459031355    -0.067811    -0.449653     0.952224
# 62117          1613690459063115    -0.001404    -0.367132     0.983963
# 62118          1613690459094876     0.020081    -0.314885     0.967361
# 62119          1613690459126637     0.022034    -0.333928     0.946365
# 62120          1613690459158447    -0.024842    -0.465766     0.899001
# ...                         ...          ...          ...          ...
# 63936          1613690516848129    -0.082460    -0.481392     0.908278
# ...

# %%
#merging all the activities
merged_PD4_chest = pd.concat([hammerthrows, stepweight,throws,squatweights,lightweights,heavyweights,boxing12, boxing,boxingupper,boxingfront,boxing2,boxing3,pushupshand,pushupsleg,pushupsleg2,exercise,ridgeplunges], ignore_index=True)
merged_PD4_chest
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1613688738023423    -0.139590     0.928298     0.260319
# 1              1613688738055235    -0.110292     0.960037     0.248112
# 2              1613688738087048    -0.104921     0.971267     0.263737
# 3              1613688738118860    -0.077089     1.037675     0.261295
# 4              1613688738150672    -0.077577     1.006912     0.212467
# ...                         ...          ...          ...          ...
# 31262          1613690516848129    -0.082460    -0.481392     0.908278
# 31263          1613690516879901    -0.135683    -0.482856     0.901930
# 31264          1613690516911672    -0.084413    -0.462837     0.917067
# 31265          1613690516943444    -0.080018    -0.423285     0.940017
# 31266          1613690516975216    -0.053651    -0.426703     0.925368
#
#        Sample (V) Activity_Label
# 0       -0.010601   hammerthrows
# 1       -0.010583   hammerthrows
# ...

# %%
#combined(accel+gyro) .csv
merged_PD4_chest.to_csv('PD4chest.csv', sep=',',  index = False)

# %% [markdown]
# # PD 5 chest

# %%
PD5_chest = pd.read_csv('pd5-accel-chest.csv')
PD5_elec = pd.read_csv('pd5-elec-chest.csv')
pd5a = PD5_chest['Timestamp (microseconds)'].to_numpy()
pd5e = PD5_elec['Timestamp (microseconds)'].to_numpy()
for i in range(len(PD5_chest)):
    PD5_chest.at[i, 'Sample (V)'] = PD5_elec['Sample (V)'].iloc[np.argmin(abs(pd5a[i] - pd5e))]
PD5_chest
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1614120945590210    -0.134218     0.844800     0.501534
# 1              1614120945622172    -0.167910     0.753979     0.409735
# 2              1614120945654134    -0.084901     0.724193     0.371649
# 3              1614120945686097    -0.058534     0.795483     0.380926
# 4              1614120945718059    -0.080995     0.802808     0.414618
# ...                         ...          ...          ...          ...
# 49675          1614122523913269     0.057191     0.878981     0.527901
# 49676          1614122523945068     0.062074     0.899977     0.468330
# 49677          1614122523976867     0.070375     0.876539     0.521553
# 49678          1614122524008667     0.071839     0.858473     0.519600
# 49679          1614122524040466     0.051331     0.837964     0.490791
#
#        Sample (V)
# 0       -0.006613
# 1       -0.005628
# 2       -0.005142
# 3       -0.004853
# ...

# %%
print(PD5_chest['Timestamp (microseconds)'][0])
pd.Timestamp(PD5_chest['Timestamp (microseconds)'][0], unit='us', tz="US/Eastern")
# Out:
# 1614120945590210
# Timestamp('2021-02-23 17:55:45.590210-0500', tz='US/Eastern')

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 17, minute = 55, second = 45, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 17, minute = 56, second = 23, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

legstretch = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

legstretch['Activity_Label'] = 'legstretch'
legstretch
# Out:
# /tmp/ipykernel_24612/175933159.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   legstretch['Activity_Label'] = 'legstretch'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0             1614120945590210    -0.134218     0.844800     0.501534
# 1             1614120945622172    -0.167910     0.753979     0.409735
# 2             1614120945654134    -0.084901     0.724193     0.371649
# 3             1614120945686097    -0.058534     0.795483     0.380926
# 4             1614120945718059    -0.080995     0.802808     0.414618
# ...                        ...          ...          ...          ...
# 1174          1614120982866689    -0.162539     0.852125     0.396063
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 17, minute = 56, second = 39, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 17, minute = 57, second = 18, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

sidestretch = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

sidestretch['Activity_Label'] = 'sidestretch'
sidestretch
# Out:
# /tmp/ipykernel_24612/1068617361.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sidestretch['Activity_Label'] = 'sidestretch'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 1683          1614120999027195     0.018128     0.918044     0.309148
# 1684          1614120999058944     0.048402     0.913649     0.299382
# 1685          1614120999090694     0.142153     0.991287     0.384344
# 1686          1614120999122444     0.231998     0.966384     0.357488
# 1687          1614120999154194     0.262760     0.849195     0.359930
# ...                        ...          ...          ...          ...
# 2906          1614121037862684    -0.613230     0.614328    -0.168887
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 17, minute = 57, second = 34, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 17, minute = 58, second = 12, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

splitleft = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

splitleft['Activity_Label'] = 'splitleft'
splitleft
# Out:
# /tmp/ipykernel_24612/3357795510.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   splitleft['Activity_Label'] = 'splitleft'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 3415          1614121054028611     0.085023     0.988846     0.175845
# 3416          1614121054060371     0.076234     0.955154     0.188052
# 3417          1614121054092131     0.073304     0.927810     0.212955
# 3418          1614121054123891     0.080629     0.922438     0.178286
# 3419          1614121054155650     0.069398     0.961501     0.162661
# ...                        ...          ...          ...          ...
# 4606          1614121091854590    -0.330510     0.959060     0.120180
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 17, minute = 58, second = 28, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 17, minute = 59, second = 8, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)
print(start_ts, end_ts)
splitright = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

splitright['Activity_Label'] = 'splitright'
splitright
# Out:
# 1614121108000000 1614121148000000
# /tmp/ipykernel_24612/1378591620.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   splitright['Activity_Label'] = 'splitright'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 5115          1614121108019300     0.042542     0.958083     0.377020
# 5116          1614121108051057     0.028870     0.964920     0.313054
# 5117          1614121108082815     0.020569     0.910231     0.325261
# 5118          1614121108114573     0.017639     0.917556     0.291569
# 5119          1614121108146331     0.028382     0.923415     0.287175
# ...                        ...          ...          ...          ...
# 6369          1614121147843930    -0.039979     0.908278    -0.259220
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 17, minute = 59, second = 26, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 0, second = 3, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

mountainclimber = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

mountainclimber['Activity_Label'] = 'mountainclimber'
mountainclimber
# Out:
# /tmp/ipykernel_24612/1848174281.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mountainclimber['Activity_Label'] = 'mountainclimber'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 6941          1614121166009657     0.045472     0.854078     0.336980
# 6942          1614121166041415    -0.010193     0.918044     0.230533
# 6943          1614121166073173    -0.046326     0.801343    -0.011170
# 6944          1614121166104931    -0.042908     0.795972    -0.006775
# 6945          1614121166136688    -0.126894     0.765209    -0.205997
# ...                        ...          ...          ...          ...
# 8101          1614121202852683    -0.253849     0.439521    -1.109819
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 0, second = 18, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 0, second = 59, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

plankpie = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

plankpie['Activity_Label'] = 'plankpie'
plankpie
# Out:
# /tmp/ipykernel_24612/846793940.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plankpie['Activity_Label'] = 'plankpie'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 8578          1614121218004944    -0.384222     0.336492    -0.873976
# 8579          1614121218036710    -0.406195     0.277409    -0.878370
# 8580          1614121218068475    -0.330510     0.256901    -0.935500
# 8581          1614121218100241    -0.352972     0.280827    -0.736767
# 8582          1614121218132006    -0.411566     0.238834    -0.595651
# ...                        ...          ...          ...          ...
# 9864          1614121258858867    -0.356390     0.279362    -0.814893
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day =23, hour = 18, minute = 1, second = 14, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 1, second = 53, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

planktop = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

planktop['Activity_Label'] = 'planktop'
planktop
# Out:
# /tmp/ipykernel_24612/2156027160.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   planktop['Activity_Label'] = 'planktop'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 10341          1614121274013467    -0.635691     0.103090    -0.882765
# 10342          1614121274045238    -0.625925     0.078187    -0.885695
# 10343          1614121274077009    -0.598093     0.100160    -0.869581
# 10344          1614121274108780    -0.503365     0.190494    -0.788525
# 10345          1614121274140550    -0.433539     0.235904    -0.650828
# ...                         ...          ...          ...          ...
# 11564          1614121312865402     0.482002     0.282780    -0.803174
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 2, second = 9, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 2, second = 48, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

plankjacks = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

plankjacks['Activity_Label'] = 'plankjacks'
plankjacks
# Out:
# /tmp/ipykernel_24612/1656414751.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plankjacks['Activity_Label'] = 'plankjacks'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 12072          1614121329001297    -0.443305     0.333562    -0.789014
# 12073          1614121329033060    -0.445747     0.337957    -0.853956
# 12074          1614121329064824    -0.467231     0.327214    -0.809033
# 12075          1614121329096587    -0.456977     0.341863    -0.769482
# 12076          1614121329128351    -0.413519     0.343328    -0.877394
# ...                         ...          ...          ...          ...
# 13295          1614121367849695    -0.158145     0.420478    -0.935500
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 3, second = 3, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 3, second = 44, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

pushups = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

pushups['Activity_Label'] = 'pushups'
pushups
# Out:
# /tmp/ipykernel_24612/466303232.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pushups['Activity_Label'] = 'pushups'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 13772          1614121383004131    -0.070741     0.818433    -0.901808
# 13773          1614121383035901    -0.121523     0.803784    -0.882277
# 13774          1614121383067670    -0.158145     0.772534    -0.913039
# 13775          1614121383099440    -0.180117     0.748119    -0.889601
# 13776          1614121383131210    -0.197208     0.683177    -0.853956
# ...                         ...          ...          ...          ...
# 15058          1614121423862958     0.126528     0.891676    -0.431586
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 4, second = 0, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 4, second = 39, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

burpees = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

burpees['Activity_Label'] = 'burpees'
burpees
# Out:
# /tmp/ipykernel_24612/2582383218.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   burpees['Activity_Label'] = 'burpees'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 15566          1614121440001434     0.051331     0.822339     0.631418
# 15567          1614121440033203     0.043030     0.784253     0.665110
# 15568          1614121440064972     0.057679     0.711986     0.709056
# 15569          1614121440096740     0.085512     0.678294     0.715404
# 15570          1614121440128509     0.087465     0.677317     0.685130
# ...                         ...          ...          ...          ...
# 16789          1614121478858459     0.051820     0.394598    -0.275822
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 4, second = 53, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 5, second = 33, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

dips = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

dips['Activity_Label'] = 'dips'
dips
# Out:
# /tmp/ipykernel_24612/3465152074.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dips['Activity_Label'] = 'dips'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 17235          1614121493030768    -0.244083     0.929763    -0.197208
# 17236          1614121493062543    -0.220645     0.951736    -0.201602
# 17237          1614121493094319    -0.182559     0.993729    -0.219669
# 17238          1614121493126095    -0.140566     0.968338    -0.220645
# 17239          1614121493157871    -0.115175     0.958083    -0.164981
# ...                         ...          ...          ...          ...
# 18488          1614121532846038    -0.036072     0.455634    -0.911574
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 5, second =48, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 6, second = 30, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

sideplankright = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

sideplankright['Activity_Label'] = 'sideplankright'
sideplankright
# Out:
# /tmp/ipykernel_24612/3648306871.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sideplankright['Activity_Label'] = 'sideplankright'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 18965          1614121548002902     0.128481    -0.298772     0.933669
# 18966          1614121548034677     0.114321    -0.412055     0.863844
# 18967          1614121548066453     0.112856    -0.441840     0.925368
# 18968          1614121548098228     0.105043    -0.387640     0.969802
# 18969          1614121548130004     0.117739    -0.346624     0.947341
# ...                         ...          ...          ...          ...
# 20282          1614121589846987     0.148989     0.904372     0.273014
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 6, second =43, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 7, second = 24, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

sideplank = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

sideplank['Activity_Label'] = 'sideplank'
sideplank
# Out:
# /tmp/ipykernel_24612/23531264.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sideplank['Activity_Label'] = 'sideplank'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 20697          1614121603030379     0.158267     0.569406     0.899001
# 20698          1614121603062147     0.090883     0.483467     0.903395
# 20699          1614121603093915     0.028870     0.358953     0.887770
# 20700          1614121603125682     0.030823     0.320378     0.939528
# 20701          1614121603157450     0.060609     0.458076     0.975662
# ...                         ...          ...          ...          ...
# 21982          1614121643849006    -0.165957    -0.650828     0.786206
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 7, second = 37, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 8, second = 18, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

singlelegright = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

singlelegright['Activity_Label'] = 'singlelegright'
singlelegright
# Out:
# /tmp/ipykernel_24612/3852324533.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   singlelegright['Activity_Label'] = 'singlelegright'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 22397          1614121657030781    -0.100038    -0.763134     0.669017
# 22398          1614121657062544    -0.106874    -0.748486     0.699779
# 22399          1614121657094308    -0.070741    -0.769482     0.669017
# 22400          1614121657126068    -0.067811    -0.775830     0.662669
# 22401          1614121657157831    -0.111269    -0.723583     0.718822
# ...                         ...          ...          ...          ...
# 23682          1614121697842021    -0.055116    -0.569772     0.811109
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 8, second = 30, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 9, second = 17, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

vshiftswift = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

vshiftswift['Activity_Label'] = 'vshiftswift'
vshiftswift
# Out:
# /tmp/ipykernel_24612/736720420.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vshiftswift['Activity_Label'] = 'vshiftswift'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 24065          1614121710004859     0.043030     0.415106     0.985916
# 24066          1614121710036616     0.007385     0.371160     0.973709
# 24067          1614121710068373    -0.028748     0.368719     0.944900
# 24068          1614121710100130    -0.058045     0.413642     0.947341
# 24069          1614121710131887    -0.006775     0.428290     0.942947
# ...                         ...          ...          ...          ...
# 25541          1614121756861144     0.073304     0.975174     0.106996
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 11, second = 18, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 11, second = 47, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing1 = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

boxing1['Activity_Label'] = 'boxing1'
boxing1
# Out:
# /tmp/ipykernel_24612/4186906487.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing1['Activity_Label'] = 'boxing1'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 29359          1614121878025479    -0.057069     1.009842     0.392157
# 29360          1614121878057403     0.184146     1.828214     0.579171
# 29361          1614121878089137     0.003479     1.463951     0.632883
# 29362          1614121878120871    -0.078553     1.064530     0.493721
# 29363          1614121878152605    -0.067323     0.647044     0.251530
# ...                         ...          ...          ...          ...
# 30267          1614121906847684     0.440986     1.482506     0.391180
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 12, second = 0, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 12, second = 29, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing2 = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

boxing2['Activity_Label'] = 'boxing2'
boxing2
# Out:
# /tmp/ipykernel_24612/1971748063.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing2['Activity_Label'] = 'boxing2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 30682          1614121920025204     0.113832     1.030838     0.166079
# 30683          1614121920056956     0.202213     0.868727     0.232486
# 30684          1614121920088709     0.591867     0.927321     0.533272
# 30685          1614121920120461     0.130922     0.990799     0.060609
# 30686          1614121920152213     0.427314     0.861891     0.013245
# ...                         ...          ...          ...          ...
# 31590          1614121948863691    -0.128359     0.840894     0.306218
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 12, second = 40, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 13, second = 8, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing3 = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

boxing3['Activity_Label'] = 'boxing3'
boxing3
# Out:
# /tmp/ipykernel_24612/1847332155.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing3['Activity_Label'] = 'boxing3'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 31941          1614121960014415    -0.079042     0.906813     0.227115
# 31942          1614121960046181    -0.151797     0.822339     0.253483
# 31943          1614121960077948    -0.167910     0.878492     0.251041
# 31944          1614121960109714    -0.183047     0.963943     0.287663
# 31945          1614121960141481    -0.152773     1.003494     0.232975
# ...                         ...          ...          ...          ...
# 32817          1614121987846264     1.080156     0.924392    -0.923781
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 13, second = 19, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 13, second = 49, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing4 = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

boxing4['Activity_Label'] = 'boxing4'
boxing4
# Out:
# /tmp/ipykernel_24612/2692594506.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing4['Activity_Label'] = 'boxing4'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 33169          1614121999031406    -0.068788     0.997635     0.333562
# 33170          1614121999063182     0.138735     1.179278     0.162661
# 33171          1614121999094957     0.123598     1.294514     0.138247
# 33172          1614121999126733     0.085512     1.117266     0.099184
# 33173          1614121999158509    -0.007263     0.847730     0.267155
# ...                         ...          ...          ...          ...
# 34108          1614122028871570     0.108461     0.018616    -0.085878
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 14, second = 4, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 14, second = 28, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing5 = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

boxing5['Activity_Label'] = 'boxing5'
boxing5
# Out:
# /tmp/ipykernel_24612/1425646319.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing5['Activity_Label'] = 'boxing5'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 34585          1614122044030614    -0.130800     1.035721     0.290593
# 34586          1614122044062395    -0.150820     1.038651     0.330144
# 34587          1614122044094176    -0.120546     1.006424     0.313542
# 34588          1614122044125957    -0.148867     0.897536     0.300359
# 34589          1614122044157738    -0.097597     0.830640     0.357977
# ...                         ...          ...          ...          ...
# 35335          1614122067869802     0.306218     0.888746     0.436103
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 14, second = 38, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 15, second = 9, tz="US/Eastern" )
end_ts = int(end.timestamp() * 1e6)

boxing6 = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

boxing6['Activity_Label'] = 'boxing5'
boxing6
# Out:
# /tmp/ipykernel_24612/349157902.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing6['Activity_Label'] = 'boxing5'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 35654          1614122078011120     0.086488     0.937087     0.326238
# 35655          1614122078042910     0.078676     0.889235     0.391180
# 35656          1614122078074699     0.012268     0.834058     0.339910
# 35657          1614122078106488    -0.091249     0.830640     0.293523
# 35658          1614122078138278    -0.060487     0.981521     0.350164
# ...                         ...          ...          ...          ...
# 36624          1614122108850486     0.298405     0.604562     0.002502
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 15, second = 19, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 15, second = 46, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

downboxing = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

downboxing['Activity_Label'] = 'downboxing'
downboxing
# Out:
# /tmp/ipykernel_24612/2411066881.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downboxing['Activity_Label'] = 'downboxing'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 36944          1614122119024551     0.145083     0.896559     0.454170
# 36945          1614122119056345     0.130434     0.836988     0.446845
# 36946          1614122119088138     0.104555     0.869703     0.420966
# 36947          1614122119119932     0.130434     0.828199     0.431220
# 36948          1614122119151725     0.190494     0.811597     0.428290
# ...                         ...          ...          ...          ...
# 37788          1614122145860078    -0.058534     0.925368    -0.168887
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 16, second = 0, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 16, second = 30, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

fastpunching = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

fastpunching['Activity_Label'] = 'fastpunching'
fastpunching
# Out:
# /tmp/ipykernel_24612/3450427951.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fastpunching['Activity_Label'] = 'fastpunching'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 38233          1614122160009778    -0.033143     0.650462     0.408759
# 38234          1614122160041575     0.108949     0.698314     0.664622
# 38235          1614122160073372    -0.113222     0.733959    -0.012634
# 38236          1614122160105169     0.050843     0.874586     0.095766
# 38237          1614122160136966     0.333074     1.155840     0.014221
# ...                         ...          ...          ...          ...
# 39172          1614122189866842     0.133364     1.032792    -0.440375
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 16, second = 45, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 17, second = 10, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

fastpunchingacc = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

fastpunchingacc['Activity_Label'] = 'fastpunchingacc'
fastpunchingacc
# Out:
# /tmp/ipykernel_24612/1794538774.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fastpunchingacc['Activity_Label'] = 'fastpunchingacc'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 39648          1614122205001869     0.152407     0.950759     0.370184
# 39649          1614122205033665     0.195377     0.855543     0.379950
# 39650          1614122205065462     0.181216     0.863355     0.331121
# 39651          1614122205097258     0.155337     0.915602     0.368231
# 39652          1614122205129055     0.088441     0.948318     0.408759
# ...                         ...          ...          ...          ...
# 40430          1614122229868060    -0.933547     1.074784     1.015702
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 17, second = 20, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 17, second = 53, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

nolabel = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

nolabel['Activity_Label'] = 'nolabel'
nolabel
# Out:
# /tmp/ipykernel_24612/1407731757.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nolabel['Activity_Label'] = 'nolabel'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 40749          1614122240012220     0.114321     0.853101     0.324285
# 40750          1614122240044020     0.068421     0.878004     0.337957
# 40751          1614122240075820     0.060609     0.949783     0.362371
# 40752          1614122240107620     0.046448     0.968826     0.321843
# 40753          1614122240139420     0.087953     0.961013     0.370672
# ...                         ...          ...          ...          ...
# 41782          1614122272856278     0.135805     1.304768     0.517159
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 18, second = 4, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 18, second = 32, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

running = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

running['Activity_Label'] = 'running'
running
# Out:
# /tmp/ipykernel_24612/168669328.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   running['Activity_Label'] = 'running'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 42133          1614122284015538    -0.016541     0.641184     0.183658
# 42134          1614122284047330    -0.007752     0.702220     0.262272
# 42135          1614122284079123    -0.050721     0.800855     0.324285
# 42136          1614122284110916    -0.091737     0.955154     0.384344
# 42137          1614122284142708    -0.128359     0.996658     0.494697
# ...                         ...          ...          ...          ...
# 43009          1614122311871699    -0.533150     0.297917    -0.537545
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 18, second = 40, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 19, second = 10, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing7 = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

boxing7['Activity_Label'] = 'boxing7'
boxing7
# Out:
# /tmp/ipykernel_24612/1805164774.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing7['Activity_Label'] = 'boxing7'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 43265          1614122320014857     0.058656     0.917556     0.494209
# 43266          1614122320046664    -0.021912     0.936110     0.057679
# 43267          1614122320078470    -0.062440     0.894118     0.219303
# 43268          1614122320110277    -0.050721     0.926345     0.222232
# 43269          1614122320142083    -0.090272     0.898512     0.065492
# ...                         ...          ...          ...          ...
# 44203          1614122349855142     0.274479     1.088457    -0.165957
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 19, second = 20, tz="US/Eastern" )
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 19, second = 50, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

freestyle = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

freestyle['Activity_Label'] = 'freestyle'
freestyle
# Out:
# /tmp/ipykernel_24612/2065430080.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   freestyle['Activity_Label'] = 'freestyle'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 44522          1614122360003383     0.182681     0.733471     0.320378
# 44523          1614122360035196     0.184634     0.761791     0.380438
# 44524          1614122360067009     0.060121     0.857008     0.307195
# 44525          1614122360098821    -0.006775     0.969802     0.280339
# 44526          1614122360130634    -0.089296     1.097734     0.307683
# ...                         ...          ...          ...          ...
# 45460          1614122389841833    -0.259220     1.144610     0.300359
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 20, second = 1, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 20, second = 29, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

B1 = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

B1['Activity_Label'] = 'B1'
B1
# Out:
# /tmp/ipykernel_24612/1885153704.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   B1['Activity_Label'] = 'B1'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 45811          1614122401006585    -0.234318     1.170001     0.293523
# 45812          1614122401038395    -0.171817     0.830152     0.171450
# 45813          1614122401070204    -0.023865     0.786206    -0.033143
# 45814          1614122401102014     0.011292     0.878492     0.044984
# 45815          1614122401133824     0.048890     1.025956     0.198306
# ...                         ...          ...          ...          ...
# 46687          1614122428872669     0.601144     0.749096    -0.198184
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 20, second = 40, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 23, hour = 18, minute = 21, second = 9, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

B2 = PD5_chest.loc[(PD5_chest['Timestamp (microseconds)'] >= start_ts) & (PD5_chest['Timestamp (microseconds)'] <= end_ts)]

B2['Activity_Label'] = 'B2'
B2
# Out:
# /tmp/ipykernel_24612/208642759.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   B2['Activity_Label'] = 'B2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 47037          1614122440006435     0.020569     1.038163     0.301823
# 47038          1614122440038246     0.030823     1.046464     0.291569
# 47039          1614122440070057     0.195377     1.163165     0.423896
# 47040          1614122440101806     0.140200     0.975174     0.057679
# 47041          1614122440133617     0.311101     0.934157     0.207095
# ...                         ...          ...          ...          ...
# 47944          1614122468859428    -0.484321     0.840406     0.660716
# ...

# %%
#merging all the activities
merged_PD5_chest = pd.concat([legstretch, sidestretch, splitleft, splitright, mountainclimber, plankpie, planktop, plankjacks, pushups, burpees, dips, sideplankright, sideplank, singlelegright, vshiftswift, boxing1, boxing2, boxing3, boxing4, boxing5, boxing6, downboxing, fastpunching, fastpunchingacc, nolabel, running, boxing7, freestyle, B1, B2 ], ignore_index=True)
merged_PD5_chest
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1614120945590210    -0.134218     0.844800     0.501534
# 1              1614120945622172    -0.167910     0.753979     0.409735
# 2              1614120945654134    -0.084901     0.724193     0.371649
# 3              1614120945686097    -0.058534     0.795483     0.380926
# 4              1614120945718059    -0.080995     0.802808     0.414618
# ...                         ...          ...          ...          ...
# 32488          1614122468859428    -0.484321     0.840406     0.660716
# 32489          1614122468891240    -0.432074     0.739330     0.461982
# 32490          1614122468923051    -0.418402     0.819409    -0.017029
# 32491          1614122468954863    -0.340764     0.805737     0.618723
# 32492          1614122468986675    -0.398383     0.944411     0.498604
#
#        Sample (V) Activity_Label
# 0       -0.006613     legstretch
# 1       -0.005628     legstretch
# ...

# %%
#combined(accel+gyro) .csv
merged_PD5_chest.to_csv('PD5chest.csv', sep=',',  index = False)

# %% [markdown]
# # PD6 chest

# %%
PD6_chest = pd.read_csv('pd6-accel-chest.csv')
PD6_elec = pd.read_csv('pd6-elec-chest.csv')
pd6a = PD6_chest['Timestamp (microseconds)'].to_numpy()
pd6e = PD6_elec['Timestamp (microseconds)'].to_numpy()
for i in range(len(PD6_chest)):
    PD6_chest.at[i, 'Sample (V)'] = PD6_elec['Sample (V)'].iloc[np.argmin(abs(pd6a[i] - pd6e))]
PD6_chest
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1614177284235595    -0.110780     0.976638     0.147524
# 1              1614177284267563    -0.105898     0.978103     0.171939
# 2              1614177284299532    -0.111757     1.000076     0.204166
# 3              1614177284331500    -0.069276     0.999588     0.247135
# 4              1614177284363468    -0.058534     0.971267     0.187564
# ...                         ...          ...          ...          ...
# 96435          1614180345226412    -0.379339     0.894118     0.021546
# 96436          1614180345258121    -0.361273     0.908278     0.046448
# 96437          1614180345289830    -0.369085     0.932692     0.074281
# 96438          1614180345321539    -0.356878     0.903883     0.059144
# 96439          1614180345353247    -0.348089     0.922438     0.048890
#
#        Sample (V)
# 0       -0.016128
# 1       -0.014958
# 2       -0.013069
# 3       -0.012097
# ...

# %%
print(PD6_chest['Timestamp (microseconds)'][0])
pd.Timestamp(PD6_chest['Timestamp (microseconds)'][0], unit='us', tz="US/Eastern")
# Out:
# 1614177284235595
# Timestamp('2021-02-24 09:34:44.235595-0500', tz='US/Eastern')

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 9, minute = 49, second = 51, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 9, minute = 50, second = 13, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

curl1 = PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

curl1['Activity_Label'] = 'curl1'
curl1
# Out:
# /tmp/ipykernel_24612/2021847039.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curl1['Activity_Label'] = 'curl1'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 28568          1614178191026847    -0.037049     0.977615     0.185611
# 28569          1614178191058581    -0.012634     0.982986     0.159243
# 28570          1614178191090314    -0.035096     1.014725     0.170962
# 28571          1614178191122048    -0.052186     0.968826     0.168521
# 28572          1614178191153782    -0.039002     0.975174     0.123110
# ...                         ...          ...          ...          ...
# 29256          1614178212859665    -0.075135     0.978103     0.201236
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 9, minute = 52, second = 47, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 9, minute = 53, second = 13, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

curl2 = PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

curl2['Activity_Label'] = 'curl2'
curl2
# Out:
# /tmp/ipykernel_24612/3819397356.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curl2['Activity_Label'] = 'curl2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 34113          1614178367027142     0.060609     0.958083     0.275456
# 34114          1614178367058893     0.082582     0.788647     0.226139
# 34115          1614178367090644     0.153872     0.910719     0.019104
# 34116          1614178367122394     0.037171     1.083085     0.235416
# 34117          1614178367154145     0.019593     0.977615     0.174868
# ...                         ...          ...          ...          ...
# 34927          1614178392871241     0.249088     0.793042    -0.041444
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 9, minute = 51, second = 17, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 9, minute = 51, second = 44, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

curl3 = PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

curl3['Activity_Label'] = 'curl3'
curl3
# Out:
# /tmp/ipykernel_24612/1624018023.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curl3['Activity_Label'] = 'curl3'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 31278          1614178277027626     0.151919     1.022049    -0.238224
# 31279          1614178277059360     0.219303     0.982010    -0.229435
# 31280          1614178277091125     0.103578     0.996170    -0.050721
# 31281          1614178277122859     0.092836     0.950271    -0.120546
# 31282          1614178277154593     0.138247     0.783764    -0.007263
# ...                         ...          ...          ...          ...
# 32123          1614178303847420    -0.041444     0.960525     0.223697
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 9, minute = 55, second = 0, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 9, minute = 55, second = 22, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

armraise1 = PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

armraise1['Activity_Label'] = 'armraise1'
armraise1
# Out:
# /tmp/ipykernel_24612/2993117981.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   armraise1['Activity_Label'] = 'armraise1'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 38301          1614178500004756     0.215396     0.866285     0.103090
# 38302          1614178500036508     0.229557     0.829175     0.146548
# 38303          1614178500068261     0.353094     0.942947     0.070863
# 38304          1614178500100013     0.350164     0.974197     0.233463
# 38305          1614178500131766     0.311589     1.208087     0.345769
# ...                         ...          ...          ...          ...
# 38989          1614178521849722    -0.009216     0.955642     0.209049
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 9, minute = 55, second = 40, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 9, minute = 56, second = 7, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

armraise2 = PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

armraise2['Activity_Label'] = 'armraise2'
armraise2
# Out:
# /tmp/ipykernel_24612/29593415.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   armraise2['Activity_Label'] = 'armraise2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 39561          1614178540011212     0.039612     0.939040     0.280827
# 39562          1614178540042963     0.125551     0.892653     0.298405
# 39563          1614178540074713     0.124086     0.902419     0.347234
# 39564          1614178540106464     0.121645     0.940017     0.410712
# 39565          1614178540138215     0.157290     0.982010     0.394110
# ...                         ...          ...          ...          ...
# 40407          1614178566872526     0.089418     0.951247     0.276921
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 9, minute = 56, second = 25, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 9, minute = 56, second = 52, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

armraise3 = PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

armraise3['Activity_Label'] = 'armraise3'
armraise3
# Out:
# /tmp/ipykernel_24612/1312972335.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   armraise3['Activity_Label'] = 'armraise3'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 40978          1614178585002328     0.055726     0.942458    -0.262150
# 40979          1614178585034079     0.070375     0.978592    -0.229435
# 40980          1614178585065830     0.123598     1.023514    -0.263615
# 40981          1614178585097581     0.106996     1.094804    -0.257755
# 40982          1614178585129331    -0.016541     1.108476    -0.245548
# ...                         ...          ...          ...          ...
# 41824          1614178611864692    -0.204044     1.152422     0.561593
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 1, second = 4, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 1, second = 52, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

squatpress1 = PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

squatpress1['Activity_Label'] = 'squatpress1'
squatpress1
# Out:
# /tmp/ipykernel_24612/284315426.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   squatpress1['Activity_Label'] = 'squatpress1'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 49764          1614178864000640    -0.160098     0.444892    -0.778759
# 49765          1614178864032394    -0.145449     0.419501    -0.805615
# 49766          1614178864064148    -0.191348     0.378973    -0.866163
# 49767          1614178864095901    -0.221134     0.253971    -0.994583
# 49768          1614178864127655    -0.185977     0.214420    -1.084428
# ...                         ...          ...          ...          ...
# 51271          1614178911849141     0.079652     0.719799    -0.572702
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 2, second = 12, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 2, second = 51, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

squatpress2 = PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

squatpress2['Activity_Label'] = 'squatpress2'
squatpress2
# Out:
# /tmp/ipykernel_24612/2555615445.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   squatpress2['Activity_Label'] = 'squatpress2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 51906          1614178932010863    -0.062928     0.570382    -0.800244
# 51907          1614178932042614    -0.075624     0.457099    -0.866163
# 51908          1614178932074365    -0.093690     0.437079    -0.823682
# 51909          1614178932106116    -0.106386     0.428290    -0.811963
# 51910          1614178932137868    -0.100526     0.377020    -0.912551
# ...                         ...          ...          ...          ...
# 53129          1614178970842998    -0.185489     0.129458    -0.954543
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 3, second = 5, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 3, second = 31, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

squatpress3 = PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

squatpress3['Activity_Label'] = 'squatpress3'
squatpress3
# Out:
# /tmp/ipykernel_24612/2539191259.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   squatpress3['Activity_Label'] = 'squatpress3'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 53575          1614178985002431    -0.049744     0.951736     0.186587
# 53576          1614178985034179    -0.043397     0.967849     0.188052
# 53577          1614178985065927    -0.028748     0.980545     0.210025
# 53578          1614178985097675    -0.058534     0.979080     0.207095
# 53579          1614178985129423    -0.053162     1.012284     0.263249
# ...                         ...          ...          ...          ...
# 54389          1614179010847175    -0.069276     1.010330     0.096254
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 11, second = 30, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 12, second = 22, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing12 = PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

boxing12['Activity_Label'] = 'boxing12'
boxing12
# Out:
# /tmp/ipykernel_24612/3152250313.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing12['Activity_Label'] = 'boxing12'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 69479          1614179490016692    -0.055604     0.989334     0.178286
# 69480          1614179490048492    -0.062928     0.976150     0.204166
# 69481          1614179490080239    -0.077089     0.990799     0.198306
# 69482          1614179490111986    -0.077089     0.988846     0.185122
# 69483          1614179490143733    -0.064393     0.972732     0.202701
# ...                         ...          ...          ...          ...
# 71112          1614179541853332     0.007385     0.979568     0.193912
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 13, second = 46, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 14, second = 56, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxingopenchest = PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

boxingopenchest['Activity_Label'] = 'boxingopenchest'
boxingopenchest
# Out:
# /tmp/ipykernel_24612/3974875457.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxingopenchest['Activity_Label'] = 'boxingopenchest'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 73763          1614179626009330     0.332586     1.257893    -0.271427
# 73764          1614179626041076     0.312566     0.955642    -0.289006
# 73765          1614179626072822     0.359442     0.553780     0.037171
# 73766          1614179626104568     0.636790     1.108476     0.031800
# 73767          1614179626136314     0.372625     1.122637     0.100160
# ...                         ...          ...          ...          ...
# 75963          1614179695848407     0.176333     0.999100     0.297429
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 15, second = 48, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 17, second = 18, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxingbackmuscles= PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

boxingbackmuscles['Activity_Label'] = 'boxingbackmuscles'
boxingbackmuscles
# Out:
# /tmp/ipykernel_24612/2186465812.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxingbackmuscles['Activity_Label'] = 'boxingbackmuscles'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 77606          1614179748001759    -0.173770     0.961990     0.165591
# 77607          1614179748033501    -0.151308     0.766674     0.252995
# 77608          1614179748065242    -0.042908     0.672435     0.418036
# 77609          1614179748096984    -0.059510     0.768139     0.578195
# 77610          1614179748128726     0.021546     0.604562     0.487373
# ...                         ...          ...          ...          ...
# 80437          1614179837848543     0.012757     1.324788    -0.499947
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 17, second = 46, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 18, second = 0, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxingbackleg = PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

boxingbackleg['Activity_Label'] = 'boxingbackleg'
boxingbackleg
# Out:
# /tmp/ipykernel_24612/4204368743.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxingbackleg['Activity_Label'] = 'boxingbackleg'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 81325          1614179866027587    -0.032166     0.727611    -0.039490
# 81326          1614179866059319     0.266178     0.701732     0.021057
# 81327          1614179866091051     0.270573     0.933669     0.214908
# 81328          1614179866122783     0.106020     1.225666     0.523507
# 81329          1614179866154515     0.108461     0.949783     0.394110
# ...                         ...          ...          ...          ...
# 81761          1614179879860982     0.390204     0.933669     0.399481
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 19, second = 41, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 20, second = 18, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxingsidekick= PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

boxingsidekick['Activity_Label'] = 'boxingsidekick'
boxingsidekick
# Out:
# /tmp/ipykernel_24612/1584372484.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxingsidekick['Activity_Label'] = 'boxingsidekick'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 84950          1614179981019594     0.220768     0.972732     0.211490
# 84951          1614179981051316     0.210025     0.963943     0.264225
# 84952          1614179981083038     0.191470     0.878492     0.158755
# 84953          1614179981114760     0.185122     0.914626     0.147036
# 84954          1614179981146482     0.232975     1.086503     0.128969
# ...                         ...          ...          ...          ...
# 86112          1614180017868972     0.096254     0.954665     0.194888
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 21, second = 50, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 22, second = 5, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

fingerflix = PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

fingerflix['Activity_Label'] = 'fingerflix'
fingerflix
# Out:
# /tmp/ipykernel_24612/2749747726.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fingerflix['Activity_Label'] = 'fingerflix'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 89018          1614180110023052    -0.039490     0.947341     0.374090
# 89019          1614180110054765    -0.056092     0.865797     0.342351
# 89020          1614180110086479    -0.091249     0.833570     0.336492
# 89021          1614180110118192    -0.136172     0.843336     0.251041
# 89022          1614180110149906    -0.068788     0.968338     0.239322
# ...                         ...          ...          ...          ...
# 89486          1614180124866043     0.167056     0.974685     0.220768
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 22, second = 49, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 23, second = 13, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

singleflix = PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

singleflix['Activity_Label'] = 'singleflix'
singleflix
# Out:
# /tmp/ipykernel_24612/3374347362.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   singleflix['Activity_Label'] = 'singleflix'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 90878          1614180169009068     0.030335     0.957595     0.252018
# 90879          1614180169040779     0.044007     0.955154     0.251041
# 90880          1614180169072418     0.036194     0.973220     0.243229
# 90881          1614180169104128     0.039612     0.974685     0.238834
# 90882          1614180169135839     0.030823     0.966384     0.283268
# ...                         ...          ...          ...          ...
# 91630          1614180192852113     0.052796     0.993240     0.134340
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 23, second = 44, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 24, second = 16, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

getoffmybag = PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

getoffmybag['Activity_Label'] = 'getoffmybag'
getoffmybag
# Out:
# /tmp/ipykernel_24612/3351051933.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   getoffmybag['Activity_Label'] = 'getoffmybag'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 92613          1614180224019610    -0.007263     0.971756     0.205631
# 92614          1614180224051317    -0.013123     0.965896     0.206119
# 92615          1614180224083024    -0.008728     0.965896     0.213443
# 92616          1614180224114730    -0.011658     0.982986     0.217350
# 92617          1614180224146437    -0.016052     0.981033     0.211978
# ...                         ...          ...          ...          ...
# 93617          1614180255856632    -0.033631     0.996658     0.103578
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 24, second = 48, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 10, minute = 25, second = 13, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

welcome = PD6_chest.loc[(PD6_chest['Timestamp (microseconds)'] >= start_ts) & (PD6_chest['Timestamp (microseconds)'] <= end_ts)]

welcome['Activity_Label'] = 'welcome'
welcome
# Out:
# /tmp/ipykernel_24612/1214833641.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   welcome['Activity_Label'] = 'welcome'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 94631          1614180288015937     0.018616     0.935622     0.291569
# 94632          1614180288047653     0.035706     0.934646     0.304753
# 94633          1614180288079369     0.047913     0.926833     0.286198
# 94634          1614180288111085     0.053285     0.910719     0.257877
# 94635          1614180288142800     0.053773     0.908278     0.256901
# ...                         ...          ...          ...          ...
# 95414          1614180312849875    -0.043397     0.991775     0.209049
# ...

# %%
#merging all the activities
merged_PD6_chest = pd.concat([curl1, curl2, curl3, armraise1, armraise2, armraise3, squatpress1, squatpress2, squatpress3, boxing12, boxingopenchest, boxingbackmuscles, boxingbackleg, boxingsidekick, fingerflix, singleflix, getoffmybag, welcome], ignore_index=True)
merged_PD6_chest
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1614178191026847    -0.037049     0.977615     0.185611
# 1              1614178191058581    -0.012634     0.982986     0.159243
# 2              1614178191090314    -0.035096     1.014725     0.170962
# 3              1614178191122048    -0.052186     0.968826     0.168521
# 4              1614178191153782    -0.039002     0.975174     0.123110
# ...                         ...          ...          ...          ...
# 19625          1614180312849875    -0.043397     0.991775     0.209049
# 19626          1614180312881591    -0.003357     0.986404     0.170962
# 19627          1614180312913307     0.002991     0.979568     0.226139
# 19628          1614180312945023     0.011780     0.982986     0.240787
# 19629          1614180312976739    -0.037049     0.951247     0.257877
#
#        Sample (V) Activity_Label
# 0       -0.010533          curl1
# 1       -0.010558          curl1
# ...

# %%
#combined(accel+gyro) .csv
merged_PD6_chest.to_csv('PD6chest.csv', sep=',',  index = False)

# %% [markdown]
# # PD 7 chest

# %%
PD7_chest = pd.read_csv('pd7-accel-chest.csv')
PD7_elec = pd.read_csv('pd7-elec-chest.csv')
pd7a = PD7_chest['Timestamp (microseconds)'].to_numpy()
pd7e = PD7_elec['Timestamp (microseconds)'].to_numpy()
for i in range(len(PD7_chest)):
    PD7_chest.at[i, 'Sample (V)'] = PD7_elec['Sample (V)'].iloc[np.argmin(abs(pd7a[i] - pd7e))]
PD7_chest
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1614206147078979    -0.500435     0.826734     0.415106
# 1              1614206147110965    -0.513130     0.834058     0.408759
# 2              1614206147142951    -0.500923     0.874586     0.402899
# 3              1614206147174936    -0.494575     0.876051     0.396063
# 4              1614206147206922    -0.476020     0.894118     0.399481
# ...                         ...          ...          ...          ...
# 88475          1614208968201029    -0.076600     0.635813     0.783764
# 88476          1614208968232914    -0.080507     0.622629     0.764233
# 88477          1614208968264798    -0.093690     0.612863     0.755932
# 88478          1614208968296682    -0.127871     0.588937     0.770581
# 88479          1614208968328566    -0.157168     0.575753     0.782300
#
#        Sample (V)
# 0        0.002428
# 1        0.002133
# 2        0.001893
# 3        0.001782
# ...

# %%
print(PD7_chest['Timestamp (microseconds)'][0])
pd.Timestamp(PD7_chest['Timestamp (microseconds)'][0], unit='us', tz="US/Eastern")
# Out:
# 1614206147078979
# Timestamp('2021-02-24 17:35:47.078979-0500', tz='US/Eastern')

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 40, second = 10, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 40, second = 41, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

curl1 = PD7_chest.loc[(PD7_chest['Timestamp (microseconds)'] >= start_ts) & (PD7_chest['Timestamp (microseconds)'] <= end_ts)]

curl1['Activity_Label'] = 'curl1'
curl1
# Out:
# /tmp/ipykernel_24612/4222698367.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curl1['Activity_Label'] = 'curl1'
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 8240          1614206410016143    -0.284611     0.773999     0.590890
# 8241          1614206410048043    -0.283635     0.767163     0.590890
# 8242          1614206410079943    -0.291447     0.754467     0.605051
# 8243          1614206410111843    -0.288029     0.753979     0.589914
# 8244          1614206410143743    -0.296818     0.760327     0.593332
# ...                        ...          ...          ...          ...
# 9207          1614206440862083    -0.366155     0.816968     0.497627
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 40, second = 50, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 41, second = 21, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

curl2 = PD7_chest.loc[(PD7_chest['Timestamp (microseconds)'] >= start_ts) & (PD7_chest['Timestamp (microseconds)'] <= end_ts)]

curl2['Activity_Label'] = 'curl2'
curl2
# Out:
# /tmp/ipykernel_24612/4239424730.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curl2['Activity_Label'] = 'curl2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 9494           1614206450016732    -0.371527     0.728099     0.483467
# 9495           1614206450048630    -0.372992     0.732006     0.528389
# 9496           1614206450080528    -0.390082     0.729564     0.527901
# 9497           1614206450112426    -0.382269     0.719310     0.567941
# 9498           1614206450144324    -0.397894     0.724193     0.583078
# ...                         ...          ...          ...          ...
# 10461          1614206480860542    -0.501900     1.021561     0.106020
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 41, second = 32, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 42, second = 2, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

curl3 = PD7_chest.loc[(PD7_chest['Timestamp (microseconds)'] >= start_ts) & (PD7_chest['Timestamp (microseconds)'] <= end_ts)]

curl3['Activity_Label'] = 'curl3'
curl3
# Out:
# /tmp/ipykernel_24612/2650054902.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curl3['Activity_Label'] = 'curl3'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 10811          1614206492024670     0.013733     0.627512     0.649973
# 10812          1614206492056568     0.006897     0.697826     0.646067
# 10813          1614206492088465     0.002014     0.769116     0.656809
# 10814          1614206492120363    -0.021912     0.797436     0.607492
# 10815          1614206492152260    -0.047791     0.782788     0.507881
# ...                         ...          ...          ...          ...
# 11746          1614206521847688    -0.146914     0.688548     0.722728
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 48, second = 2, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 48, second = 32, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

armraise1 = PD7_chest.loc[(PD7_chest['Timestamp (microseconds)'] >= start_ts) & (PD7_chest['Timestamp (microseconds)'] <= end_ts)]

armraise1['Activity_Label'] = 'armraise1'
armraise1
# Out:
# /tmp/ipykernel_24612/1090799684.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   armraise1['Activity_Label'] = 'armraise1'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 23040          1614206882018127    -0.198672     0.722240     0.677317
# 23041          1614206882050009    -0.196719     0.720287     0.671458
# 23042          1614206882081891    -0.191348     0.726146     0.670970
# 23043          1614206882113772    -0.190860     0.730541     0.669505
# 23044          1614206882145654    -0.198672     0.726146     0.662181
# ...                         ...          ...          ...          ...
# 23976          1614206911858307    -0.214786     0.758373     0.649485
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 48, second = 45, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 49, second = 11, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

armraise2 = PD7_chest.loc[(PD7_chest['Timestamp (microseconds)'] >= start_ts) & (PD7_chest['Timestamp (microseconds)'] <= end_ts)]

armraise2['Activity_Label'] = 'armraise2'
armraise2
# Out:
# /tmp/ipykernel_24612/3925920185.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   armraise2['Activity_Label'] = 'armraise2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 24389          1614206925023372    -0.208927     0.885328     0.417060
# 24390          1614206925055249    -0.206973     0.869703     0.488350
# 24391          1614206925087126    -0.196719     0.898024     0.501534
# 24392          1614206925119003    -0.218692     0.912184     0.569894
# 24393          1614206925150880    -0.198672     0.881910     0.464424
# ...                         ...          ...          ...          ...
# 25199          1614206950841481    -0.156191     0.883864     0.369207
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 49, second = 20, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 49, second = 52, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

armraise3 = PD7_chest.loc[(PD7_chest['Timestamp (microseconds)'] >= start_ts) & (PD7_chest['Timestamp (microseconds)'] <= end_ts)]

armraise3['Activity_Label'] = 'armraise3'
armraise3
# Out:
# /tmp/ipykernel_24612/3074088852.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   armraise3['Activity_Label'] = 'armraise3'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 25487          1614206960021028    -0.218692     0.792554     0.569894
# 25488          1614206960052902    -0.223087     0.802808     0.569406
# 25489          1614206960084776    -0.230900     0.786694     0.585519
# 25490          1614206960116649    -0.225040     0.811109     0.570871
# 25491          1614206960148523    -0.222599     0.803784     0.582101
# ...                         ...          ...          ...          ...
# 26486          1614206991860661    -0.067323     0.997635     0.148501
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 50, second = 42, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 51, second = 11, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

squatpress1 = PD7_chest.loc[(PD7_chest['Timestamp (microseconds)'] >= start_ts) & (PD7_chest['Timestamp (microseconds)'] <= end_ts)]

squatpress1['Activity_Label'] = 'squatpress1'
squatpress1
# Out:
# /tmp/ipykernel_24612/1679834987.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   squatpress1['Activity_Label'] = 'squatpress1'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 28060          1614207042020723     0.100160     0.774487     0.657298
# 28061          1614207042052590     0.090883     0.769116     0.665599
# 28062          1614207042084456     0.091371     0.770092     0.648508
# 28063          1614207042116323     0.086000     0.749584     0.657298
# 28064          1614207042148189     0.105043     0.734936     0.679759
# ...                         ...          ...          ...          ...
# 28965          1614207070859835    -0.110780     0.622629     0.815015
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 51, second = 21, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 51, second = 52, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

squatpress2 = PD7_chest.loc[(PD7_chest['Timestamp (microseconds)'] >= start_ts) & (PD7_chest['Timestamp (microseconds)'] <= end_ts)]

squatpress2['Activity_Label'] = 'squatpress2'
squatpress2
# Out:
# /tmp/ipykernel_24612/305538499.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   squatpress2['Activity_Label'] = 'squatpress2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 29284          1614207081025879    -0.069276     0.570871     0.777905
# 29285          1614207081057747    -0.073671     0.607492     0.789624
# 29286          1614207081089614    -0.098573     0.631418     0.797925
# 29287          1614207081121482    -0.094667     0.648508     0.807202
# 29288          1614207081153350    -0.104433     0.612863     0.768139
# ...                         ...          ...          ...          ...
# 30251          1614207111842618    -0.201114     0.579171     0.795483
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 52, second = 0, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 17, minute = 52, second = 37, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

squatpress3 = PD7_chest.loc[(PD7_chest['Timestamp (microseconds)'] >= start_ts) & (PD7_chest['Timestamp (microseconds)'] <= end_ts)]

squatpress3['Activity_Label'] = 'squatpress3'
squatpress3
# Out:
# /tmp/ipykernel_24612/2617913111.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   squatpress3['Activity_Label'] = 'squatpress3'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 30507          1614207120001012    -0.200626     0.621653     0.774487
# 30508          1614207120032880    -0.197696     0.614817     0.749096
# 30509          1614207120064749    -0.199161     0.635325     0.782300
# 30510          1614207120096617    -0.197208     0.613840     0.773999
# 30511          1614207120128486    -0.200137     0.627024     0.764233
# ...                         ...          ...          ...          ...
# 31664          1614207156872108    -0.113710     0.625071     0.727611
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 18, minute = 8, second = 3, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 24, hour = 18, minute = 8, second = 35, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

bike = PD7_chest.loc[(PD7_chest['Timestamp (microseconds)'] >= start_ts) & (PD7_chest['Timestamp (microseconds)'] <= end_ts)]

bike['Activity_Label'] = 'bike'
bike
# Out:
# /tmp/ipykernel_24612/2999874889.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bike['Activity_Label'] = 'bike'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 60719          1614208083012388    -0.120546     0.563546     0.732006
# 60720          1614208083044220    -0.112734     0.603586     0.774975
# 60721          1614208083076108    -0.104433     0.667063     0.813062
# 60722          1614208083107997    -0.118593     0.659251     0.802319
# 60723          1614208083139885    -0.159609     0.638743     0.793530
# ...                         ...          ...          ...          ...
# 61718          1614208114870404    -0.104433     0.541085     0.840894
# ...

# %%
#merging all the activities
merged_PD7_chest = pd.concat([curl1, curl2, curl3, armraise1, armraise2, armraise3, squatpress1, squatpress2, squatpress3, bike], ignore_index=True)
merged_PD7_chest
# Out:
#       Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0             1614206410016143    -0.284611     0.773999     0.590890
# 1             1614206410048043    -0.283635     0.767163     0.590890
# 2             1614206410079943    -0.291447     0.754467     0.605051
# 3             1614206410111843    -0.288029     0.753979     0.589914
# 4             1614206410143743    -0.296818     0.760327     0.593332
# ...                        ...          ...          ...          ...
# 9687          1614208114870404    -0.104433     0.541085     0.840894
# 9688          1614208114902294    -0.118593     0.518135     0.859449
# 9689          1614208114934234    -0.120546     0.519600     0.838453
# 9690          1614208114966125    -0.106874     0.542061     0.857496
# 9691          1614208114998016    -0.129824     0.545968     0.856519
#
#       Sample (V) Activity_Label
# 0       0.001542          curl1
# 1       0.001566          curl1
# ...

# %%
#combined(accel+elec) .csv
merged_PD7_chest.to_csv('PD7chest.csv', sep=',',  index = False)

# %% [markdown]
# # PD 8 chest

# %%
PD8_chest = pd.read_csv('pd8-accel-chest.csv')
PD8_elec = pd.read_csv('pd8-elec-chest.csv')
pd8a = PD8_chest['Timestamp (microseconds)'].to_numpy()
pd8e = PD8_elec['Timestamp (microseconds)'].to_numpy()
for i in range(len(PD8_chest)):
    PD8_chest.at[i, 'Sample (V)'] = PD8_elec['Sample (V)'].iloc[np.argmin(abs(pd8a[i] - pd8e))]
PD8_chest
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1614292980392608    -0.256779     0.957595    -0.033631
# 1              1614292980424577    -0.268009     0.924880    -0.041444
# 2              1614292980456546    -0.264591     0.919020    -0.053162
# 3              1614292980488515    -0.270939     0.927321    -0.049256
# 4              1614292980520485    -0.310002     0.921950    -0.049256
# ...                         ...          ...          ...          ...
# 75995          1614295388036533    -0.038025     0.972244     0.015686
# 75996          1614295388068185    -0.136172     0.908766     0.076234
# 75997          1614295388099838    -0.240177     0.896559     0.045960
# 75998          1614295388131491    -0.248478     0.892164     0.061097
# 75999          1614295388163144    -0.240177     1.044999     0.096254
#
#        Sample (V)
# 0       -0.013641
# 1       -0.013026
# 2       -0.011924
# 3       -0.011364
# ...

# %%
print(PD8_chest['Timestamp (microseconds)'][0])
pd.Timestamp(PD8_chest['Timestamp (microseconds)'][0], unit='us', tz="US/Eastern")
# Out:
# 1614292980392608
# Timestamp('2021-02-25 17:43:00.392608-0500', tz='US/Eastern')

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 49, second = 10, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 50, second = 12, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

stepup = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

stepup['Activity_Label'] = 'stepup'
stepup
# Out:
# /tmp/ipykernel_24612/1115123584.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stepup['Activity_Label'] = 'stepup'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 11644          1614293350018497    -0.502388    -0.018494    -1.026810
# 11645          1614293350050198    -0.485298    -0.063905    -1.001907
# 11646          1614293350081899    -0.420356    -0.086366    -1.086870
# 11647          1614293350113600    -0.405219    -0.039002    -1.089799
# 11648          1614293350145301    -0.407660    -0.025818    -1.025345
# ...                         ...          ...          ...          ...
# 13595          1614293411872838     0.065492     0.722728    -0.152773
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 50, second = 21, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 50, second = 40, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

sidesteps = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

sidesteps['Activity_Label'] = 'sidesteps'
sidesteps
# Out:
# /tmp/ipykernel_24612/1870166298.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sidesteps['Activity_Label'] = 'sidesteps'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 13883          1614293421003681    -0.563424     0.065003    -1.054643
# 13884          1614293421035385    -0.539010     0.002014    -1.030716
# 13885          1614293421067089    -0.480903     0.006409    -1.132769
# 13886          1614293421098793    -0.428656     0.083070    -1.093217
# 13887          1614293421130497    -0.450141     0.086488    -1.052201
# ...                         ...          ...          ...          ...
# 14478          1614293439866390    -0.452094     1.149004    -0.091737
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 50, second = 56, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 51, second = 22, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

squatpress = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

squatpress['Activity_Label'] = 'squatpress'
squatpress
# Out:
# /tmp/ipykernel_24612/3007780040.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   squatpress['Activity_Label'] = 'squatpress'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 14987          1614293456002187    -0.111757     0.788159    -0.030213
# 14988          1614293456033887    -0.097108     0.701244     0.082582
# 14989          1614293456065588    -0.117617     0.678294     0.220279
# 14990          1614293456097289    -0.123964     0.573312     0.225162
# 14991          1614293456128989    -0.026795     0.666575     0.273014
# ...                         ...          ...          ...          ...
# 15803          1614293481866846    -0.275822     0.983474     0.114809
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 51, second = 33, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 51, second = 52, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

squatjump = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

squatjump['Activity_Label'] = 'squatjump'
squatjump
# Out:
# /tmp/ipykernel_24612/1408116982.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   squatjump['Activity_Label'] = 'squatjump'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 16155          1614293493023153    -0.192325     0.979568     0.136294
# 16156          1614293493054847    -0.150332     0.961501     0.111879
# 16157          1614293493086542    -0.142031     0.840894     0.054749
# 16158          1614293493118236    -0.122988     0.895583     0.071351
# 16159          1614293493149931    -0.147402     0.943923     0.148501
# ...                         ...          ...          ...          ...
# 16749          1614293511848662    -0.030213     0.826734    -0.080018
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 51, second = 58, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 52, second = 20, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

s = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

s['Activity_Label'] = 's'
s
# Out:
# /tmp/ipykernel_24612/3554076376.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s['Activity_Label'] = 's'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 16944          1614293518028492     0.295964     0.793530     0.412177
# 16945          1614293518060184     0.262272     0.842847     0.416083
# 16946          1614293518091876     0.200259     0.766674     0.446357
# 16947          1614293518123568     0.243229     0.764233     0.347234
# 16948          1614293518155260     0.131899     0.711986     0.405829
# ...                         ...          ...          ...          ...
# 17633          1614293539862423     0.229068     0.799878     0.493721
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 52, second = 35, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 53, second = 38, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

bike = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

bike['Activity_Label'] = 'bike'
bike
# Out:
# /tmp/ipykernel_24612/1432748018.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bike['Activity_Label'] = 'bike'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 18111          1614293555009830    -0.073671     0.658762     0.549386
# 18112          1614293555041519    -0.115663     0.888746     0.559640
# 18113          1614293555073208    -0.167422     0.825269     0.512764
# 18114          1614293555104897    -0.070741     0.656321     0.526925
# 18115          1614293555136586    -0.127382     0.836500     0.768627
# ...                         ...          ...          ...          ...
# 20094          1614293617855939    -0.121035     0.773022     0.593332
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day =25, hour = 17, minute = 54, second = 48, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 55, second = 20, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

handraise = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

handraise['Activity_Label'] = 'handraise'
handraise
# Out:
# /tmp/ipykernel_24612/407544494.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   handraise['Activity_Label'] = 'handraise'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 22308          1614293688014255    -0.386175     1.002029     0.057679
# 22309          1614293688045939    -0.341253     0.998611     0.085023
# 22310          1614293688077623    -0.350530     0.919997     0.091371
# 22311          1614293688109307    -0.336858     0.898024     0.042054
# 22312          1614293688140991    -0.327581     0.959060     0.185122
# ...                         ...          ...          ...          ...
# 23313          1614293719852174    -0.164004     0.953689    -0.147890
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 57, second = 43, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 58, second = 10, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

weightlifts1 = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

weightlifts1['Activity_Label'] = 'weightlifts1'
weightlifts1
# Out:
# /tmp/ipykernel_24612/2136203448.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weightlifts1['Activity_Label'] = 'weightlifts1'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 27833          1614293863015025    -0.201602     0.933181     0.278386
# 27834          1614293863046698    -0.213321     0.913649     0.283268
# 27835          1614293863078371    -0.213321     0.970779     0.282780
# 27836          1614293863110044    -0.235782     0.945876     0.271061
# 27837          1614293863141717    -0.243595     0.940017     0.285222
# ...                         ...          ...          ...          ...
# 28680          1614293889848480    -0.209415     0.948806     0.253483
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 58, second = 20, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 59, second = 3, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

weightlifts2 = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

weightlifts2['Activity_Label'] = 'weightlifts2'
weightlifts2
# Out:
# /tmp/ipykernel_24612/1406487.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weightlifts2['Activity_Label'] = 'weightlifts2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 29001          1614293900018131    -0.268986     0.947341     0.330632
# 29002          1614293900049812    -0.250919     0.899977     0.342351
# 29003          1614293900081493    -0.233341     0.888746     0.305730
# 29004          1614293900113174    -0.243595     0.940017     0.323796
# 29005          1614293900144855    -0.247013     0.922438     0.311589
# ...                         ...          ...          ...          ...
# 30353          1614293942849582    -0.134707     0.978103     0.321843
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 59, second = 18, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 59, second = 45, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

weightlifts3 = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

weightlifts3['Activity_Label'] = 'weightlifts3'
weightlifts3
# Out:
# /tmp/ipykernel_24612/2615873835.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weightlifts3['Activity_Label'] = 'weightlifts3'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 30832          1614293958025329    -0.194278     0.984451     0.149477
# 30833          1614293958057011    -0.193301     0.935622     0.104067
# 30834          1614293958088693    -0.182071     0.992752     0.185611
# 30835          1614293958120375    -0.205509     1.002518     0.187564
# 30836          1614293958152057    -0.216739     0.947829     0.155337
# ...                         ...          ...          ...          ...
# 31679          1614293984858327    -0.018006     0.939528     0.314519
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 17, minute = 59, second = 47, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 0, second = 10, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

sidestrecth1 = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

sidestrecth1['Activity_Label'] = 'sidestrecth1'
sidestrecth1
# Out:
# /tmp/ipykernel_24612/1445929087.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sidestrecth1['Activity_Label'] = 'sidestrecth1'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 31747          1614293987012454    -0.018982     0.946365     0.245670
# 31748          1614293987044134     0.039612     0.927321     0.268132
# 31749          1614293987075813     0.034730     0.949294     0.293034
# 31750          1614293987107493    -0.028748     0.924392     0.273991
# 31751          1614293987139173     0.008850     0.989334     0.282292
# ...                         ...          ...          ...          ...
# 32468          1614294009852640    -0.089296     1.000076     0.222232
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 0, second = 12, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 0, second = 43, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

sidestrecth2 = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

sidestrecth2['Activity_Label'] = 'sidestrecth2'
sidestrecth2
# Out:
# /tmp/ipykernel_24612/590120363.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sidestrecth2['Activity_Label'] = 'sidestrecth2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 32536          1614294012006797    -0.167910     0.976150     0.161685
# 32537          1614294012038476    -0.152773     0.962966     0.169986
# 32538          1614294012070155    -0.152773     0.966873     0.171939
# 32539          1614294012101833    -0.145937     0.977127     0.172915
# 32540          1614294012133512    -0.155703     0.982498     0.175357
# ...                         ...          ...          ...          ...
# 33510          1614294042857506    -0.250431     0.960525     0.332097
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 1, second = 6, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 1, second = 22, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

weightlifts4 = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

weightlifts4['Activity_Label'] = 'weightlifts4'
weightlifts4
# Out:
# /tmp/ipykernel_24612/1227735060.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weightlifts4['Activity_Label'] = 'weightlifts4'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 34241          1614294066006244    -0.051698     0.899001     0.199771
# 34242          1614294066037910    -0.056092     0.899977     0.243229
# 34243          1614294066069576    -0.074647     0.879469     0.311101
# 34244          1614294066101242    -0.005798     0.833570     0.306706
# 34245          1614294066132907     0.010315     0.777905     0.323308
# ...                         ...          ...          ...          ...
# 34742          1614294081873184     0.122621     0.831128     0.611398
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 1, second = 40, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 1, second = 51, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

weightlifts5 = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

weightlifts5['Activity_Label'] = 'weightlifts5'
weightlifts5
# Out:
# /tmp/ipykernel_24612/411338015.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weightlifts5['Activity_Label'] = 'weightlifts5'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 35315          1614294100021667     0.005921     1.335042    -0.376410
# 35316          1614294100053339     0.005432     1.404379    -0.414984
# 35317          1614294100085011     0.023499     1.450278    -0.432074
# 35318          1614294100116683    -0.022400     1.463951    -0.387152
# 35319          1614294100148355    -0.005798     1.381430    -0.397406
# ...                         ...          ...          ...          ...
# 35657          1614294110854091    -0.084901     0.861891     0.245182
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 2, second = 40, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 3, second = 16, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

bosopushup = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

bosopushup['Activity_Label'] = 'bosopushup'
bosopushup
# Out:
# /tmp/ipykernel_24612/3746422775.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bosopushup['Activity_Label'] = 'bosopushup'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 37209          1614294160012630    -0.235782     0.878981    -0.592233
# 37210          1614294160044304    -0.362737     0.806226    -0.608835
# 37211          1614294160075977    -0.298772     0.770581    -0.536568
# 37212          1614294160107650    -0.323674     0.878981    -0.496529
# 37213          1614294160139324    -0.163516     0.900954    -0.534615
# ...                         ...          ...          ...          ...
# 38341          1614294195863304    -0.097597     0.744701    -0.645945
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 3, second = 20, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 3, second = 32, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

sideside = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

sideside['Activity_Label'] = 'sideside'
sideside
# Out:
# /tmp/ipykernel_24612/4185309924.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sideside['Activity_Label'] = 'sideside'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 38472          1614294200011917     0.169497     0.792065    -0.576608
# 38473          1614294200043586     0.243717     0.836500    -0.564889
# 38474          1614294200075255     0.218326     0.789624    -0.507759
# 38475          1614294200106924     0.235904     0.809155    -0.543893
# 38476          1614294200138593     0.227115     0.864820    -0.518013
# ...                         ...          ...          ...          ...
# 38846          1614294211855628     0.019593     0.834546    -0.502388
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 3, second = 43, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 4, second = 2, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boso = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

boso['Activity_Label'] = 'boso'
boso
# Out:
# /tmp/ipykernel_24612/4013043795.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boso['Activity_Label'] = 'boso'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 39198          1614294223002457    -0.204044     0.508370    -0.779736
# 39199          1614294223034124    -0.189395     0.444404    -0.881788
# 39200          1614294223065704    -0.154726     0.479072    -0.827100
# 39201          1614294223097371    -0.078065     0.510323    -0.903273
# 39202          1614294223129038    -0.091737     0.526925    -0.979446
# ...                         ...          ...          ...          ...
# 39793          1614294241843035    -0.210880     0.712474    -0.691356
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 4, second = 16, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 4, second = 43, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

stepper = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

stepper['Activity_Label'] = 'stepper'
stepper
# Out:
# /tmp/ipykernel_24612/1289171303.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stepper['Activity_Label'] = 'stepper'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 40241          1614294256028490    -0.226505     1.099199     0.089418
# 40242          1614294256060154    -0.200137     1.052811     0.068910
# 40243          1614294256091817    -0.216739     0.969802     0.044495
# 40244          1614294256123481    -0.211856     0.890700     0.021057
# 40245          1614294256155145    -0.215763     0.912673     0.001526
# ...                         ...          ...          ...          ...
# 41088          1614294282854457    -0.245060     0.970291     0.145083
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 4, second = 45, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 5, second = 15, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

onelegdown = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

onelegdown['Activity_Label'] = 'onelegdown'
onelegdown
# Out:
# /tmp/ipykernel_24612/3894152973.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   onelegdown['Activity_Label'] = 'onelegdown'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 41156          1614294285008316    -0.004822     0.979568    -0.061952
# 41157          1614294285039989    -0.059510     1.023514    -0.018006
# 41158          1614294285071663    -0.058045     0.955154    -0.032654
# 41159          1614294285103336    -0.131777     0.903883    -0.015564
# 41160          1614294285135040    -0.066346     0.947341    -0.039002
# ...                         ...          ...          ...          ...
# 42098          1614294314845085     0.011780     0.865309    -0.009216
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 5, second = 23, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 5, second = 45, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

sidestepper = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

sidestepper['Activity_Label'] = 'sidestepper'
sidestepper
# Out:
# /tmp/ipykernel_24612/128893765.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sidestepper['Activity_Label'] = 'sidestepper'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 42356          1614294323017231    -0.103944     0.834058     0.091371
# 42357          1614294323048905    -0.091249     0.792554     0.106508
# 42358          1614294323080579    -0.123476     0.745678     0.086488
# 42359          1614294323112254    -0.115175     0.777417     0.103090
# 42360          1614294323143951    -0.101015     0.810620     0.108461
# ...                         ...          ...          ...          ...
# 43046          1614294344872724    -0.080018     1.079179    -0.092226
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 5, second = 55, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 6, second = 21, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

biking = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

biking['Activity_Label'] = 'biking'
biking
# Out:
# /tmp/ipykernel_24612/2401799136.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   biking['Activity_Label'] = 'biking'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 43366          1614294355008494    -0.145449     0.568917     0.699290
# 43367          1614294355040168    -0.137636     0.671458     0.731029
# 43368          1614294355071842    -0.088808     0.729076     0.736400
# 43369          1614294355103516    -0.142031     0.691966     0.746166
# 43370          1614294355135190    -0.132265     0.632883     0.746166
# ...                         ...          ...          ...          ...
# 44182          1614294380852453    -0.207950     0.717357     0.668528
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 6, second = 30, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 6, second = 50, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

chair1 = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

chair1['Activity_Label'] = 'chair1'
chair1
# Out:
# /tmp/ipykernel_24612/272946683.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chair1['Activity_Label'] = 'chair1'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 44471          1614294390004601    -0.080018     1.045975     0.117250
# 44472          1614294390036270    -0.105409     1.029374     0.110414
# 44473          1614294390067939    -0.111757     1.030838     0.146059
# 44474          1614294390099608    -0.160586     0.993240     0.159243
# 44475          1614294390131277    -0.235782     0.973220     0.196353
# ...                         ...          ...          ...          ...
# 45098          1614294409857883    -0.202579     0.884352     0.505928
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 7, second = 55, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 8, second = 7, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

chair2 = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

chair2['Activity_Label'] = 'chair2'
chair2
# Out:
# /tmp/ipykernel_24612/3754297644.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chair2['Activity_Label'] = 'chair2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 47156          1614294475026260    -0.350042     0.892164     0.389227
# 47157          1614294475057926    -0.360784     0.878981     0.417548
# 47158          1614294475089592    -0.353460     0.914626     0.471748
# 47159          1614294475121257    -0.352483     0.838941     0.463447
# 47160          1614294475152893    -0.368597     0.799390     0.470283
# ...                         ...          ...          ...          ...
# 47530          1614294486868981    -0.177676     0.998611    -0.070253
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 11, second = 53, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 12, second = 27, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

boxing['Activity_Label'] = 'boxing'
boxing
# Out:
# /tmp/ipykernel_24612/1695745304.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing['Activity_Label'] = 'boxing'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 54674          1614294713029720    -0.259220     1.001541     0.024475
# 54675          1614294713061380    -0.339300     1.065995    -0.014099
# 54676          1614294713093040    -0.410590     1.113848     0.131899
# 54677          1614294713124700    -0.300725     1.049882     0.155825
# 54678          1614294713156360    -0.283146     0.930739     0.168521
# ...                         ...          ...          ...          ...
# 55742          1614294746848565    -0.031678     0.927321     0.036194
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 12, second = 45, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 13, second = 3, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

squat = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

squat['Activity_Label'] = 'squat'
squat
# Out:
# /tmp/ipykernel_24612/153001188.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   squat['Activity_Label'] = 'squat'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 56316          1614294765026407    -0.062440     0.794507    -0.581979
# 56317          1614294765058075    -0.068788     0.801343    -0.584421
# 56318          1614294765089743    -0.114199     0.754467    -0.565377
# 56319          1614294765121411    -0.047303     0.878004    -0.579538
# 56320          1614294765153015    -0.105898     0.821363    -0.565377
# ...                         ...          ...          ...          ...
# 56879          1614294782852450    -0.081971     0.786206    -0.533639
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 13, second = 10, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 13, second = 46, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing2 = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

boxing2['Activity_Label'] = 'boxing2'
boxing2
# Out:
# /tmp/ipykernel_24612/3478737104.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing2['Activity_Label'] = 'boxing2'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 57105          1614294790006145    -0.668894     0.924880    -0.892042
# 57106          1614294790037803    -0.645945     0.991287    -0.856886
# 57107          1614294790069461    -0.770947     1.078691     0.032288
# 57108          1614294790101120    -0.351019     0.900465    -0.061463
# 57109          1614294790132778    -0.057557     1.212970     0.097230
# ...                         ...          ...          ...          ...
# 58237          1614294825850001    -0.286076     1.057694     0.100649
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 14, second = 2, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 14, second = 28, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing3 = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

boxing3['Activity_Label'] = 'boxing3'
boxing3
# Out:
# /tmp/ipykernel_24612/29226163.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing3['Activity_Label'] = 'boxing3'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 58747          1614294842001930     0.167544     1.051835    -0.092226
# 58748          1614294842033599     0.156802     1.032792    -0.214786
# 58749          1614294842065269     0.009827     1.001053    -0.358831
# 58750          1614294842096939    -0.089296     0.786694    -1.002884
# 58751          1614294842128608    -0.636179     0.696849    -0.680613
# ...                         ...          ...          ...          ...
# 59563          1614294867846203    -0.094667     0.959548    -0.377874
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 14, second = 28, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 15, second = 7, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

rollinghands = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

rollinghands['Activity_Label'] = 'rollinghands'
rollinghands
# Out:
# /tmp/ipykernel_24612/2488377658.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rollinghands['Activity_Label'] = 'rollinghands'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 59568          1614294868004558     0.554269     0.678294    -0.521920
# 59569          1614294868036229     0.313542     0.906813    -0.436469
# 59570          1614294868067900     0.139712     0.917067    -0.578073
# 59571          1614294868099571    -0.291936     0.751537    -0.453071
# 59572          1614294868131242    -0.305608     0.930739    -0.425238
# ...                         ...          ...          ...          ...
# 60795          1614294906858216     0.049866     0.904372     0.372625
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 15, second = 30, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 15, second = 46, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing4 = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

boxing4['Activity_Label'] = 'boxing4'
boxing4
# Out:
# /tmp/ipykernel_24612/2824697213.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing4['Activity_Label'] = 'boxing4'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 61526          1614294930000407    -0.413519     0.949294     0.249088
# 61527          1614294930032065    -0.281193     1.023514     0.278386
# 61528          1614294930063724    -0.209903     0.894118     0.236393
# 61529          1614294930095383    -0.231388     0.855543     0.229068
# 61530          1614294930127041    -0.150332     0.873121     0.206607
# ...                         ...          ...          ...          ...
# 62027          1614294945862495    -1.164508     0.575265    -0.650340
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 16, second = 1, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 16, second = 55, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing5 = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

boxing5['Activity_Label'] = 'boxing3'
boxing5
# Out:
# /tmp/ipykernel_24612/1567246227.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing5['Activity_Label'] = 'boxing3'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 62506          1614294961029052    -0.289982     0.992264     0.154360
# 62507          1614294961060714    -0.286564     0.858961     0.149966
# 62508          1614294961092376    -0.180606     0.883375     0.057191
# 62509          1614294961124038    -0.368597     1.065019     0.105531
# 62510          1614294961155700    -0.414984     0.862867     0.068421
# ...                         ...          ...          ...          ...
# 64206          1614295014848937    -0.089784     0.980056    -0.211856
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 16, second = 55, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 17, second = 9, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

boxing6 = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

boxing6['Activity_Label'] = 'boxing6'
boxing6
# Out:
# /tmp/ipykernel_24612/708944892.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxing6['Activity_Label'] = 'boxing6'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 64211          1614295015007220    -0.236759     0.950271    -0.115175
# 64212          1614295015038877    -0.172305     0.971756    -0.060975
# 64213          1614295015070534    -0.080995     0.995682    -0.055604
# 64214          1614295015102191    -0.096620     1.145098     0.051820
# 64215          1614295015133847    -0.063416     1.116777    -0.033143
# ...                         ...          ...          ...          ...
# 64649          1614295028871594    -0.307073     0.919997     0.031800
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 17, second = 25, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 17, second = 48, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

kicking = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

kicking['Activity_Label'] = 'kicking'
kicking
# Out:
# /tmp/ipykernel_24612/258203881.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kicking['Activity_Label'] = 'kicking'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 65159          1614295045015269    -0.021424     1.067460     0.115785
# 65160          1614295045046936    -0.026307     1.094316     0.108461
# 65161          1614295045078590    -0.037537     1.131914     0.123598
# 65162          1614295045110245    -0.025330     1.057694     0.092348
# 65163          1614295045141900    -0.059022     0.940017     0.176333
# ...                         ...          ...          ...          ...
# 65881          1614295067870339    -0.340764     0.914137     0.045960
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 18, second = 10, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 18, second = 29, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

legstretch = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

legstretch['Activity_Label'] = 'legstretch'
legstretch
# Out:
# /tmp/ipykernel_24612/16094153.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   legstretch['Activity_Label'] = 'legstretch'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 66581          1614295090026477    -0.087343     0.998611     0.150942
# 66582          1614295090058129    -0.140566     0.955642     0.113344
# 66583          1614295090089781    -0.176211     0.974685     0.145083
# 66584          1614295090121433    -0.106874     0.980545     0.150942
# 66585          1614295090153085    -0.114199     0.971756     0.037171
# ...                         ...          ...          ...          ...
# 67176          1614295108860054    -0.070253     1.006912     0.047913
# ...

# %%
# These values are obtained from the Meta Data and converted to UTC from Est

start = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 18, second = 32, tz="US/Eastern")
start_ts = int(start.timestamp() * 1e6)

end = pd.Timestamp(year = 2021, month = 2, day = 25, hour = 18, minute = 19, second = 1, tz="US/Eastern")
end_ts = int(end.timestamp() * 1e6)

legkicking = PD8_chest.loc[(PD8_chest['Timestamp (microseconds)'] >= start_ts) & (PD8_chest['Timestamp (microseconds)'] <= end_ts)]

legkicking['Activity_Label'] = 'legkicking'
legkicking
# Out:
# /tmp/ipykernel_24612/3273033890.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   legkicking['Activity_Label'] = 'legkicking'
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 67276          1614295112025278     0.143130     1.129961     0.354070
# 67277          1614295112056931     0.045472     0.886793     0.350164
# 67278          1614295112088584     0.068910     0.464912     0.254948
# 67279          1614295112120236     0.188052     0.238346     0.191470
# 67280          1614295112151855     0.299870     0.441474     0.271061
# ...                         ...          ...          ...          ...
# 68187          1614295140864737    -0.297795     0.888746    -0.048768
# ...

# %%
#merging all the activities
merged_PD8_chest = pd.concat([stepup, sidesteps, squatpress, s, bike, handraise, weightlifts1, weightlifts2, weightlifts3, sidestrecth1, sidestrecth2, weightlifts4, weightlifts5, bosopushup, sideside, boso, stepper, onelegdown, biking, chair1, chair2, boxing, squat, boxing2, boxing3, boxing4, boxing5, boxing6, kicking, legstretch, legkicking], ignore_index=True)
merged_PD8_chest
# Out:
#        Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0              1614293350018497    -0.502388    -0.018494    -1.026810
# 1              1614293350050198    -0.485298    -0.063905    -1.001907
# 2              1614293350081899    -0.420356    -0.086366    -1.086870
# 3              1614293350113600    -0.405219    -0.039002    -1.089799
# 4              1614293350145301    -0.407660    -0.025818    -1.025345
# ...                         ...          ...          ...          ...
# 26926          1614295140864737    -0.297795     0.888746    -0.048768
# 26927          1614295140896394    -0.286564     0.937575    -0.034119
# 26928          1614295140928052    -0.303166     0.894118     0.033265
# 26929          1614295140959710    -0.310491     0.842359     0.020081
# 26930          1614295140991367    -0.289982     0.826734    -0.032166
#
#        Sample (V) Activity_Label
# 0       -0.010521         stepup
# 1       -0.010675         stepup
# ...

# %%
#combined(accel+gyro) .csv
merged_PD8_chest.to_csv('PD8chest.csv', sep=',',  index = False)

# %% [markdown]
# # merging chest data of 8 PD subjects

# %%
PD1chest = pd.read_csv('PD1chest.csv')
PD2chest = pd.read_csv('PD2chest.csv')
PD3chest = pd.read_csv('PD3chest.csv')
PD4chest = pd.read_csv('PD4chest.csv')
PD5chest = pd.read_csv('PD5chest.csv')
PD6chest = pd.read_csv('PD6chest.csv')
PD7chest = pd.read_csv('PD7chest.csv')
PD8chest = pd.read_csv('PD8chest.csv')

# %%
PD1chest['Subject ID'] = 1
PD2chest['Subject ID'] = 2
PD3chest['Subject ID'] = 3
PD4chest['Subject ID'] = 4
PD5chest['Subject ID'] = 5
PD6chest['Subject ID'] = 6
PD7chest['Subject ID'] = 7
PD8chest['Subject ID'] = 8

# %%
PDchest = pd.concat([PD1chest, PD2chest, PD3chest, PD4chest, PD5chest, PD6chest, PD7chest, PD8chest], ignore_index = True)

# %%
PDchest
# Out:
#         Timestamp (microseconds)  Accel X (g)  Accel Y (g)  Accel Z (g)  \
# 0               1613575026030946    -0.027771     0.902419    -0.315862
# 1               1613575026062884    -0.011170     0.953689    -0.340276
# 2               1613575026094822    -0.026307     0.907790    -0.341253
# 3               1613575026126760    -0.049744     0.877028    -0.303166
# 4               1613575026158698    -0.020447     0.885817    -0.337346
# ...                          ...          ...          ...          ...
# 191843          1614295140864737    -0.297795     0.888746    -0.048768
# 191844          1614295140896394    -0.286564     0.937575    -0.034119
# 191845          1614295140928052    -0.303166     0.894118     0.033265
# 191846          1614295140959710    -0.310491     0.842359     0.020081
# 191847          1614295140991367    -0.289982     0.826734    -0.032166
#
#         Sample (V) Activity_Label  Subject ID
# 0        -0.006521  Medicine Ball           1
# ...

# %%
PDchest.to_csv('PDchest.csv', sep=',',  index = False)
