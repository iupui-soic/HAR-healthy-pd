# %%
import pandas as pd
df = pd.read_csv('upscaled_CR_PDdata.csv')

# %%
df
# Out:
#         Subject ID  Timestamp (microseconds)  Accel X (g)_leg  \
# 0                1          1613575026007263        -0.621653
# 1                1          1613575026023239        -0.621653
# 2                1          1613575026039215        -0.622751
# 3                1          1613575026055191        -0.625437
# 4                1          1613575026071167        -0.621164
# ...            ...                       ...              ...
# 382297           8          1614295140928869        -1.160723
# 382298           8          1614295140944846        -1.077592
# 382299           8          1614295140960823        -1.013016
# 382300           8          1614295140976800        -0.677317
# 382301           8          1614295140992776        -0.248234
#
#         Accel Y (g)_leg  Accel Z (g)_leg  Gyro X (°/s)_leg  Gyro Y (°/s)_leg  \
# 0              0.469306        -0.509712        -24.017700         13.641566
# ...

# %%
df=df.replace({"Activity_Label":{ 'sidestep': 'step',
                                 'FBstep': 'step',
                                 'hipstep': 'step',
                                 'stepup': 'step',
                                 'stepper': 'step',
                                 'stepweight': 'weights',
                                 'squatweights': 'weights',
                                 'squatpress': 'weights',
                                 'lightweights': 'weights',
                                 'weightlifts': 'weights',
                                 'heavyweights': 'weights',
                                 'bellyscooter' : 'scooter', 
                                 'circularscooter': 'scooter', 
                                 'kneescooter': 'scooter', 
                                 'FBscooter': 'scooter', 
                                 'fingerflix': 'flix',
                                 'singleflix': 'flix',
                                 'bike': 'cycling',
                                 'handcycling': 'cycling',
                                 'completecycling': 'cycling',
                                 'fastcycling': 'cycling',
                                 'mountainclimber': 'plank',
                                 'plankpie': 'plank',
                                 'planktop': 'plank',
                                 'plankjacks': 'plank',
                                 'sideplankright': 'plank',
                                 'splitleft': 'split',
                                 'splitright': 'split',
                                 
       
                                                     
                                 
    }})

# %%
df['Activity_Label'].unique()
# Out:
# array(['Medicine Ball', 'Burpees', 'step', 'scooter', 'boxing', 'cycling',
#        'pushups', 'punchball', 'highraise', 'hammerthrows', 'weights',
#        'throws', 'exercise', 'ridgeplunges', 'sidestretch', 'split',
#        'plank', 'dips', 'singlelegright', 'vshiftswift', 'nolabel',
#        'running', 'freestyle', 'B1', 'curl', 'armraise', 'flix',
#        'getoffmybag', 'welcome', 's', 'bosopushup', 'sideside', 'boso',
#        'onelegdown', 'chair', 'squat', 'kicking'], dtype=object)

# %%
df
# Out:
#         Subject ID  Timestamp (microseconds)  Accel X (g)_leg  \
# 0                1          1613575026007263        -0.621653
# 1                1          1613575026023239        -0.621653
# 2                1          1613575026039215        -0.622751
# 3                1          1613575026055191        -0.625437
# 4                1          1613575026071167        -0.621164
# ...            ...                       ...              ...
# 382297           8          1614295140928869        -1.160723
# 382298           8          1614295140944846        -1.077592
# 382299           8          1614295140960823        -1.013016
# 382300           8          1614295140976800        -0.677317
# 382301           8          1614295140992776        -0.248234
#
#         Accel Y (g)_leg  Accel Z (g)_leg  Gyro X (°/s)_leg  Gyro Y (°/s)_leg  \
# 0              0.469306        -0.509712        -24.017700         13.641566
# ...

# %%
len(df['Activity_Label'].unique())
# Out:
# 37

# %%
len(df['Activity_Label'])
# Out:
# 367981

# %%
#df=df.drop("Activity_Label == ['s', 'nolabel','B1','getoffmybag', 'welcome','exercise']")
df=df.drop(df[df['Activity_Label']=='s'].index)
df=df.drop(df[df['Activity_Label']=='nolabel'].index)
df=df.drop(df[df['Activity_Label']=='B1'].index)
df=df.drop(df[df['Activity_Label']=='getoffmybag'].index)
df=df.drop(df[df['Activity_Label']=='welcome'].index)
df=df.drop(df[df['Activity_Label']=='exercise'].index)

# %%
df
# Out:
#         Subject ID  Timestamp (microseconds)  Accel X (g)_leg  \
# 0                1          1613575026007263        -0.621653
# 1                1          1613575026023239        -0.621653
# 2                1          1613575026039215        -0.622751
# 3                1          1613575026055191        -0.625437
# 4                1          1613575026071167        -0.621164
# ...            ...                       ...              ...
# 382297           8          1614295140928869        -1.160723
# 382298           8          1614295140944846        -1.077592
# 382299           8          1614295140960823        -1.013016
# 382300           8          1614295140976800        -0.677317
# 382301           8          1614295140992776        -0.248234
#
#         Accel Y (g)_leg  Accel Z (g)_leg  Gyro X (°/s)_leg  Gyro Y (°/s)_leg  \
# 0              0.469306        -0.509712        -24.017700         13.641566
# ...

# %%
len(df['Activity_Label'].unique())
# Out:
# 31

# %%
df['Activity_Label'].unique()
# Out:
# array(['Medicine Ball', 'Burpees', 'step', 'scooter', 'boxing', 'cycling',
#        'pushups', 'punchball', 'highraise', 'hammerthrows', 'weights',
#        'throws', 'ridgeplunges', 'sidestretch', 'split', 'plank', 'dips',
#        'singlelegright', 'vshiftswift', 'running', 'freestyle', 'curl',
#        'armraise', 'flix', 'bosopushup', 'sideside', 'boso', 'onelegdown',
#        'chair', 'squat', 'kicking'], dtype=object)

# %%
df.to_csv('PDdata_31activities.csv', sep=',', index = False)

# %%
df
# Out:
#         Subject ID  Timestamp (microseconds)  Accel X (g)_leg  \
# 0                1          1613575026007263        -0.621653
# 1                1          1613575026023239        -0.621653
# 2                1          1613575026039215        -0.622751
# 3                1          1613575026055191        -0.625437
# 4                1          1613575026071167        -0.621164
# ...            ...                       ...              ...
# 382297           8          1614295140928869        -1.160723
# 382298           8          1614295140944846        -1.077592
# 382299           8          1614295140960823        -1.013016
# 382300           8          1614295140976800        -0.677317
# 382301           8          1614295140992776        -0.248234
#
#         Accel Y (g)_leg  Accel Z (g)_leg  Gyro X (°/s)_leg  Gyro Y (°/s)_leg  \
# 0              0.469306        -0.509712        -24.017700         13.641566
# ...
